# %% [markdown]
# # Imports

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Loading

# %%
df = pd.read_csv("/home/data/ull.csv")
df = df.set_index("id_student")
df
# Out:
# /tmp/ipykernel_523/416373339.py:1: DtypeWarning: Columns (171,172,390) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("/home/data/ull.csv")
#             id_student_original  id_year  id_grade id_class_group  id_school  \
# id_student
# 1                       33613.0     2016         3              A     2415.0
# 2                       19294.0     2016         3              A     1842.0
# 3                       19587.0     2016         3            NaN     1432.0
# 4                       29985.0     2016         3              A     2280.0
# 5                        6982.0     2016         3              A     2040.0
# ...                         ...      ...       ...            ...        ...
# 83853                    2500.0     2019         6              B     1278.0
# 83854                    5784.0     2019         6              A     1079.0
# 83855                    7708.0     2019         6              X     1486.0
# ...
