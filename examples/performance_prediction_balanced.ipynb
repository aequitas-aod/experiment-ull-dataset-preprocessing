# %% [markdown]
# # School performance predictions:
# # Ensuring fairness for disadvantaged students

# %% [markdown]
# ## 0) Imports

# %%
import os
import copy
import math
import json
import collections
from IPython.display import display, HTML
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import OrdinalEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split, cross_validate, StratifiedKFold
from sklearn.metrics import get_scorer
from sklearn.preprocessing import KBinsDiscretizer
from fairlearn import metrics
from fairlearn.metrics import demographic_parity_difference, demographic_parity_ratio
import ipywidgets as widgets

# %%
import torch

#if torch.cuda.is_available():
#    device = torch.device("cuda")
#else:
device = torch.device("cpu")

print(f"Using device: {device}")
# Out:
# Using device: cpu

# %% [markdown]
# ## 1) Data Loading, Cleaning and Understanding

# %% [markdown]
# ### Preliminary Observations

# %%
df = pd.read_csv("students-dataset/benchmark/dataset.csv", low_memory=False)
df = df.set_index("id_questionnaire")
print(df.shape)
df.head()
# Out:
# (80174, 159)
#                   id_student_original  id_year  id_grade id_class_group  \
# id_questionnaire
# 1                             33613.0     2016         3              A
# 2                             19294.0     2016         3              A
# 3                             19587.0     2016         3            NaN
# 4                             29985.0     2016         3              A
# 5                              6982.0     2016         3              A
#
#                   id_school  id_student_16_19  id_school_16_19  score_MAT  \
# id_questionnaire
# 1                    2415.0           14374.0            569.0     564.87
# 2                    1842.0            8001.0            273.0     388.34
# 3                    1432.0            8142.0             82.0     386.59
# 4                    2280.0           12800.0            505.0     487.76
# 5                    2040.0            2606.0            390.0     709.79
#
#                   level_MAT  score_LEN  ...  \
# id_questionnaire                        ...
# 1                       3.0     535.15  ...
# 2                       1.0     293.70  ...
# 3                       1.0     514.81  ...
# 4                       2.0     449.25  ...
# 5                       4.0     598.72  ...
#
#                   t_extent_of_student_involvement_during_class  \
# id_questionnaire
# 1                                                          NaN
# 2                                                          NaN
# 3                                                          NaN
# 4                                                     0.555556
# 5                                                     0.666667
#
#                   t_extent_of_teaching_methods_variety  \
# id_questionnaire
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                             0.666667
# 5                                             0.733333
#
#                   t_extent_of_opinion_on_school t_extent_of_class_behaviour  \
# id_questionnaire
# 1                                           NaN                         NaN
# 2                                           NaN                         NaN
# 3                                           NaN                         NaN
# 4                                           1.0                    0.500000
# 5                                           1.0                    0.833333
#
#                   t_extent_of_resource_variety  \
# id_questionnaire
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                     0.458333
# 5                                     0.625000
#
#                  t_extent_of_good_work_by_non_teachers  \
# id_questionnaire
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                             0.555556
# 5                                             0.888889
#
#                  t_number_of_individual_training_topics  \
# id_questionnaire
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# 5                                                   1.0
#
#                  t_number_of_subjects_taught  \
# id_questionnaire
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# 5                                        NaN
#
#                  t_extent_of_satisfaction_job_and_school  \
# id_questionnaire
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# 5                                                    NaN
#
#                  t_extent_of_results_satisfaction
# id_questionnaire
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                        0.666667
# 5                                        1.000000
#
# [5 rows x 159 columns]

# %%
df.groupby(by=["id_year", "id_grade"])[["id_year", "id_grade"]].count()
# Out:
#                   id_year  id_grade
# id_year id_grade
# 2016    3           19466     19466
#         6           19928     19928
# 2017    3            3056      3056
#         4            2931      2931
#         6            3110      3110
# 2018    3            3238      3238
#         4            3106      3106
#         6            3277      3277
# 2019    4            3199      3199
#         6           18863     18863

# %%
df.groupby(by=["id_year", "id_grade"])[["id_year", "id_grade"]].count().plot.barh()
# Out:
# <Axes: ylabel='id_year,id_grade'>

# %%
TARGET = widgets.Dropdown(
    options=['level_MAT', 'level_ENG', 'level_LEN'],
    value='level_MAT',
    description='Target:',
    disabled=False,
)
display(TARGET)
# Out:
# Dropdown(description='Target:', options=('level_MAT', 'level_ENG', 'level_LEN'), value='level_MAT')

# %%
SENSITIVE = widgets.Dropdown(
    options=['f_ESCS', 'gender'],
    value='f_ESCS',
    description='Sensitive:',
    disabled=False,
)
display(SENSITIVE)
# Out:
# Dropdown(description='Sensitive:', options=('f_ESCS', 'gender'), value='f_ESCS')

# %%
YEAR = widgets.Dropdown(
    options=[('2016', 2016), ('2017', 2017), ('2018', 2018), ('2019', 2019)],
    value= 2016,
    description='Year:',
    disabled=False,
)
display(YEAR)
# Out:
# Dropdown(description='Year:', options=(('2016', 2016), ('2017', 2017), ('2018', 2018), ('2019', 2019)), value=…

# %%
GRADE = widgets.Dropdown(
    options=df[df['id_year']==YEAR.value]['id_grade'].unique().tolist(),
    value=6,
    description='Grade:',
    disabled=False,
)
display(GRADE)
# Out:
# Dropdown(description='Grade:', index=1, options=(3, 6), value=6)

# %%
style = {'description_width': 'initial', 'width':'750px'}
MISS_THRESH_S = widgets.FloatSlider(
    value=0.1,
    min=0,
    max=1,
    step=0.1,
    description='Max % missing in student:',
    disabled=False,
    continuous_update=False,
    orientation='horizontal',
    readout=True,
    readout_format='.1f',
    style=style,
    layout=widgets.Layout(width='500px', height='50px')
)
MISS_THRESH_F = widgets.FloatSlider(
    value=0.3,
    min=0,
    max=1,
    step=0.1,
    description='Max % missing in family:',
    disabled=False,
    continuous_update=False,
    orientation='horizontal',
    readout=True,
    readout_format='.1f',
    style=style,
    layout=widgets.Layout(width='500px', height='50px')
)
MISS_THRESH_T = widgets.FloatSlider(
    value=0.3,
    min=0,
    max=1,
    step=0.1,
    description='Max % missing in teacher:',
    disabled=False,
    continuous_update=False,
    orientation='horizontal',
    readout=True,
    readout_format='.1f',
    style=style,
    layout=widgets.Layout(width='500px', height='50px')
)
MISS_THRESH_P = widgets.FloatSlider(
    value=0.1,
    min=0,
    max=1,
    step=0.1,
    description='Max % missing in principal:',
    disabled=False,
    continuous_update=False,
    orientation='horizontal',
    readout=True,
    readout_format='.1f',
    style=style,
    layout=widgets.Layout(width='500px', height='50px')
)
MISS_THRESH_FINAL = widgets.FloatSlider(
    value=0.1,
    min=0,
    max=1,
    step=0.1,
    description='Max % missing in final:',
    disabled=False,
    continuous_update=False,
    orientation='horizontal',
    readout=True,
    readout_format='.1f',
    style=style,
    layout=widgets.Layout(width='500px', height='50px')
)

display(MISS_THRESH_S)
display(MISS_THRESH_F)
display(MISS_THRESH_T)
display(MISS_THRESH_P)
display(MISS_THRESH_FINAL)
# Out:
# FloatSlider(value=0.1, continuous_update=False, description='Max % missing in student:', layout=Layout(height=…
# FloatSlider(value=0.3, continuous_update=False, description='Max % missing in family:', layout=Layout(height='…
# FloatSlider(value=0.3, continuous_update=False, description='Max % missing in teacher:', layout=Layout(height=…
# FloatSlider(value=0.1, continuous_update=False, description='Max % missing in principal:', layout=Layout(heigh…
# FloatSlider(value=0.1, continuous_update=False, description='Max % missing in final:', layout=Layout(height='5…

# %%
RAND_STATE = 42
SENSITIVE = SENSITIVE.value
TARGET = TARGET.value
YEAR = YEAR.value
GRADE = GRADE.value
MISS_THRESH_S = MISS_THRESH_S.value
MISS_THRESH_F = MISS_THRESH_F.value
MISS_THRESH_T = MISS_THRESH_T.value
MISS_THRESH_P = MISS_THRESH_P.value
MISS_THRESH_FINAL = MISS_THRESH_FINAL.value

# %%
df[["id_year", "id_grade", SENSITIVE]].groupby(by=["id_year", "id_grade"])[SENSITIVE].count()
# Out:
# id_year  id_grade
# 2016     3           13964
#          6           14702
# 2017     3            1549
#          4            2889
#          6            1872
# 2018     3            2929
#          4            3030
#          6            2922
# 2019     4            3116
#          6           11784
# Name: f_ESCS, dtype: int64

# %%
df[["id_year", "id_grade", TARGET]].groupby(by=["id_year", "id_grade"])[TARGET].count()
# Out:
# id_year  id_grade
# 2016     3           17806
#          6           17916
# 2017     3            2995
#          4            2362
#          6            3031
# 2018     3            3102
#          4            2397
#          6            3186
# 2019     4            2385
#          6           18019
# Name: level_MAT, dtype: int64

# %%
df_sel = df[(df["id_year"] == YEAR) & (df["id_grade"] == GRADE)]
df_sel = df_sel[df_sel[TARGET].notna()]
print(df_sel.shape)
print(df_sel[SENSITIVE].isna().sum())
# Out:
# (17916, 159)
# 4471

# %%
df_sel[SENSITIVE].describe()
# Out:
# count    13445.000000
# mean         0.036848
# std          0.990857
# min         -2.648533
# 25%         -0.708813
# 50%          0.019550
# 75%          0.664128
# max          3.062709
# Name: f_ESCS, dtype: float64

# %% [markdown]
# ### Feature Study

# %% [markdown]
# #### Utility Functions

# %% [markdown]
# Filtering dataset based on questionnaire scope.

# %%
def filter_columns_starting_with(temp_df, pattern):
    df = copy.deepcopy(temp_df)
    if pattern is not None:
        return df[[col for col in df.columns if col.startswith(pattern)] + [col for col in df.columns if col.startswith("level_")]]
    else:
        return df

# %% [markdown]
# Extracting the percentage of missing values.

# %%
def get_missing_values(temp_df):
    df = copy.deepcopy(temp_df)
    return df.isna().sum()/df.shape[0]

# %% [markdown]
# Discretizing columns value when necessary.

# %%
def discretize_columns(temp_df):
    df = copy.deepcopy(temp_df)
    categorical_features = df.select_dtypes(include=['object', 'category']).columns
    # Apply Ordinal Encoding
    encoder = OrdinalEncoder()
    df[categorical_features] = encoder.fit_transform(df[categorical_features])
    return df

# %% [markdown]
# Showing correlation matrix.

# %%
def compute_correlation_matrix(temp_df, annot=True):
    df = copy.deepcopy(temp_df)
    correlation_matrix = df.corr()
    ax = sns.heatmap(correlation_matrix, annot=annot, cmap='coolwarm', fmt=".2f")
    ax.collections[0].set_clim(-1, 1)
    plt.title("Correlation Matrix Heatmap")
    plt.show()
    return correlation_matrix

# %% [markdown]
# Full method to analyse data.

# %%
def compute_analysis(df, column_pattern, missing_threshold=0.1, annot=True):
    df_filtered = filter_columns_starting_with(df, column_pattern)
    missings = get_missing_values(df_filtered)
    good_missings = missings[missings < missing_threshold]
    print(f"FEATURES WITH ENOUGH VALUES: {good_missings.shape[0]}")
    print(good_missings)
    print()
    bad_missings = missings[missings > missing_threshold]
    print(f"BAD FEATURES: {bad_missings.shape[0]}")
    print(bad_missings)
    print()
    df_without_bad_cols = df_filtered.drop(bad_missings.index, axis=1)
    df_discretized = discretize_columns(df_without_bad_cols)
    correlation_matrix = compute_correlation_matrix(df_discretized, annot)
    return df_without_bad_cols, correlation_matrix

# %%
df_sel_gen, correlation_matrix_general = compute_analysis(df=df_sel, column_pattern="id_", missing_threshold=1.0, annot=True)
# Out:
# FEATURES WITH ENOUGH VALUES: 9
# id_student_original    0.000000
# id_year                0.000000
# id_grade               0.000000
# id_class_group         0.149978
# id_school              0.000000
# id_school_16_19        0.054253
# level_MAT              0.000000
# level_LEN              0.012391
# level_ING              0.015908
# dtype: float64
#
# BAD FEATURES: 0
# Series([], dtype: float64)

# %%
df_sel_students, correlation_matrix_sel_students = compute_analysis(df=df_sel, column_pattern="s_",
                                                                     missing_threshold=MISS_THRESH_S, annot=False)
# Out:
# FEATURES WITH ENOUGH VALUES: 18
# s_gender                             0.000000
# s_birth_year                         0.045825
# s_is_living_with_mother              0.072003
# s_frequency_of_skips                 0.051797
# s_homeworks_day_per_week             0.039071
# s_extent_of_teachers_affinity        0.060728
# s_frequency_of_computer_usage        0.048560
# s_frequency_of_internet_usage        0.049620
# s_frequency_of_work_with_teachers    0.048392
# s_frequency_of_materials_in_class    0.052244
# s_frequency_of_evaluations           0.050625
# s_extent_of_teacher_performance      0.050904
# s_extent_of_class_env                0.053695
# s_extent_of_classmates_affinity      0.053360
# s_extent_of_school_satisfaction      0.050011
# level_MAT                            0.000000
# level_LEN                            0.012391
# level_ING                            0.015908
# dtype: float64
#
# BAD FEATURES: 9
# s_is_living_with_father             0.152657
# s_is_living_with_siblings           0.381670
# s_is_living_with_other_relatives    0.850022
# s_has_repeated                      0.121623
# s_birth_country                     1.000000
# s_nazionality_country               1.000000
# s_weight                            1.000000
# s_extent_of_math_affinity           1.000000
# s_extent_of_reading_affinity        1.000000
# dtype: float64

# %%
df_sel_families, correlation_matrix_sel_families = compute_analysis(df=df_sel, column_pattern="f_",
                                                                     missing_threshold=MISS_THRESH_F, annot=False)
# Out:
# FEATURES WITH ENOUGH VALUES: 27
# f_respondent                                           0.266633
# f_number_of_people_in_household                        0.275675
# f_mother_age                                           0.259600
# f_mother_education_level                               0.268922
# f_mother_employment_status                             0.286615
# f_mother_place_of_birth                                0.299732
# f_student_place_of_birth                               0.269871
# f_language_spoken_at_home                              0.260772
# f_degree_of_start_schooling_age                        0.269926
# f_number_of_tech_at_home                               0.256698
# f_extent_of_books_at_home                              0.248828
# f_visits_in_school_by_mother                           0.265070
# f_has_been_recommended_school                          0.255526
# f_number_of_homework_hours_a_week                      0.254186
# f_mother_occupation                                    0.281034
# f_ESCS                                                 0.249553
# f_frequency_of_books_at_home                           0.265349
# f_frequency_of_tech_at_home                            0.261777
# f_frequency_of_see_adult_read                          0.248046
# f_extent_of_interest_in_interview                      0.251730
# f_frequency_of_support_at_home                         0.249442
# f_frequency_of_parent_involved_in_school_activities    0.252512
# f_extent_of_family_satisfaction                        0.250614
# f_extent_of_teacher_satisfaction                       0.252512
# level_MAT                                              0.000000
# level_LEN                                              0.012391
# level_ING                                              0.015908
# dtype: float64
#
# BAD FEATURES: 11
# f_father_age                                     0.311677
# f_father_education_level                         0.331212
# f_father_employment_status                       0.346562
# f_father_place_of_birth                          0.344831
# f_degree_of_years_in_spanish_education_system    0.650368
# f_visits_in_school_by_father                     0.358953
# f_parental_education_expectations                0.338747
# f_father_occupation                              0.333891
# f_number_of_children_in_household                1.000000
# f_type_of_family_unit                            1.000000
# f_monthly_household_income                       1.000000
# dtype: float64

# %%
df_sel_teachers, correlation_matrix_sel_teachers = compute_analysis(df=df_sel, column_pattern="t_",
                                                                     missing_threshold=MISS_THRESH_T, annot=False)
# Out:
# FEATURES WITH ENOUGH VALUES: 3
# level_MAT    0.000000
# level_LEN    0.012391
# level_ING    0.015908
# dtype: float64
#
# BAD FEATURES: 37
# t_gender                                                 0.317816
# t_age                                                    0.324291
# t_number_of_years_as_teacher                             0.317872
# t_number_of_years_in_school                              0.323510
# t_has_taught_same_group_last_two_years                   0.315640
# t_number_of_students_in_group                            0.320496
# t_number_of_students_disadvanteged_economic_situation    0.688770
# t_number_of_foreign_students_speaking_spanish            0.510828
# t_number_of_foreign_students_not_speaking_spanish        0.483367
# t_number_of_teaching_hours_per_week                      0.324291
# t_average_explanation_time                               0.314747
# t_degree_of_individual_training_incidence                0.356944
# t_seat_configuration                                     0.317537
# t_behaviour_problems_solution                            0.316812
# t_number_of_meetings_with_families                       0.351418
# t_is_enrolled_in_school_training_plan                    0.321277
# t_number_of_training_hours_last_six_years                0.353427
# t_number_of_training_hours_ceu_offer                     1.000000
# t_main_topic_of_pfc                                      1.000000
# t_extent_of_evaluation_variety                           0.316589
# t_extent_of_pfc_incidence                                0.363809
# t_extent_of_work_hampered                                0.317482
# t_extent_of_family_interest                              0.315640
# t_extent_of_family_support                               0.317593
# t_extent_of_work_facilitated_by_management               0.318486
# t_extent_of_positive_relationships                       0.315919
# t_number_of_special_attention_students                   0.388870
# t_extent_of_student_involvement_during_class             0.319547
# t_extent_of_teaching_methods_variety                     0.314747
# t_extent_of_opinion_on_school                            0.337464
# t_extent_of_class_behaviour                              0.320942
# t_extent_of_resource_variety                             0.315919
# t_extent_of_good_work_by_non_teachers                    0.318542
# t_number_of_individual_training_topics                   0.386526
# t_number_of_subjects_taught                              1.000000
# t_extent_of_satisfaction_job_and_school                  1.000000
# t_extent_of_results_satisfaction                         0.314747
# dtype: float64

# %%
df_sel_principals, correlation_matrix_sel_principals = compute_analysis(df=df_sel, column_pattern="p_",
                                                                         missing_threshold=MISS_THRESH_P, annot=False)
# Out:
# FEATURES WITH ENOUGH VALUES: 36
# p_gender                                             0.042141
# p_number_of_teachers_in_school                       0.048169
# p_percentage_of_teachers_changed_school_last_year    0.042532
# p_attitude_teacher_training_courses                  0.050737
# p_age                                                0.045044
# p_group_criteria_random                              0.000000
# p_group_criteria_subjects                            0.000000
# p_group_criteria_other                               0.000000
# p_group_criteria_alphabet                            0.000000
# p_group_criteria_gender                              0.000000
# p_group_criteria_language                            0.000000
# p_group_criteria_performance                         0.000000
# p_group_criteria_homogeneity                         0.000000
# p_group_criteria_heterogeneity                       0.000000
# p_number_of_years_of_teaching                        0.052523
# p_number_of_years_in_school                          0.046718
# p_number_of_years_as_principal                       0.055202
# p_number_of_years_as_principal_in_school             0.046997
# p_number_of_class_hours_per_week                     0.093269
# p_number_of_principlas_10_years                      0.049955
# p_number_of_preschool_students                       0.059053
# p_number_of_preschool_groups                         0.066868
# p_number_of_primary_students                         0.048504
# p_number_of_primary_groups                           0.061007
# p_extent_of_agreement                                0.040076
# p_extent_of_factors_limiting_effectiveness           0.042141
# p_extent_of_inconveniences                           0.040076
# p_extent_of_management                               0.040076
# p_extent_of_problems                                 0.040076
# p_extent_of_satisfaction                             0.040076
# p_island                                             0.000000
# p_number_of_school_tech_resources                    0.000000
# p_public_or_private                                  0.000000
# level_MAT                                            0.000000
# level_LEN                                            0.012391
# level_ING                                            0.015908
# dtype: float64
#
# BAD FEATURES: 17
# p_number_of_abroad_students_country_no_spanish                         0.110683
# p_number_of_abroad_students_country_spanish                            0.121065
# p_number_of_teachers_1_education                                       1.000000
# p_number_of_mandatory_teachers_2_education                             1.000000
# p_number_of_teachers_1_education_more_5_years                          1.000000
# p_number_of_mandatory_teachers_2_education_more_5_years                1.000000
# p_extent_of_satisfaction_students_results                              1.000000
# p_extent_of_expected_students_results                                  1.000000
# p_extent_of_students_improvement_expectation                           1.000000
# p_school_teacher_training_plan                                         1.000000
# p_school_teacher_training_plan_main_theme                              1.000000
# p_number_of_students                                                   0.247991
# p_number_of_groups                                                     0.224660
# p_number_of_groups_evaluated_grade                                     1.000000
# p_rate_4_grade_mandatory_2_education_students_different_nationality    1.000000
# p_rate_3_grade_mandatory_2_education_students_different_nationality    1.000000
# p_rate_6_grade_mandatory_2_education_students_different_nationality    1.000000
# dtype: float64

# %% [markdown]
# ### Feature Importance

# %%
get_features = lambda curr_df: [col for col in curr_df.columns if not col.startswith("level_")]
concatenated_df = pd.concat(
    [
    df_sel_gen[["id_class_group", "id_school", TARGET]],
    df_sel_students[get_features(df_sel_students)],
    df_sel_families[get_features(df_sel_families)],
    df_sel_teachers[get_features(df_sel_teachers)],
    df_sel_principals[get_features(df_sel_principals)]
    ],
    axis=1
    )
X, y = concatenated_df[get_features(concatenated_df)],concatenated_df[TARGET]

# %%
forest = RandomForestClassifier(random_state=RAND_STATE)
forest.fit(discretize_columns(X), y)
# Out:
# RandomForestClassifier(random_state=42)

# %%
importances = forest.feature_importances_
std = np.std([tree.feature_importances_ for tree in forest.estimators_], axis=0)

# %%
forest_importances = pd.Series(importances, index=get_features(concatenated_df))
forest_std = pd.Series(std, index=get_features(concatenated_df))
forest_df = pd.concat([forest_importances, forest_std], axis=1)
forest_df.columns = ["importance", "std"]
forest_df = forest_df[forest_df["importance"] > 0.015]
forest_df = forest_df.sort_values("importance", ascending=False)
forest_importances = forest_df["importance"]
std = forest_df["std"].to_numpy()
fig, ax = plt.subplots()
forest_importances.plot.bar(yerr=std, ax=ax)
ax.set_title("Feature importances using MDI")
ax.set_ylabel("Mean decrease in impurity")
# Out:
# Text(0, 0.5, 'Mean decrease in impurity')

# %% [markdown]
# ## 2) Bias and Proxy Detection

# %% [markdown]
# ### Bias detection

# %%
final_features = [col for col in list(forest_importances.index) if col != "id_school"]
final_features
# Out:
# ['s_frequency_of_work_with_teachers',
#  's_frequency_of_evaluations',
#  's_frequency_of_internet_usage',
#  's_extent_of_class_env',
#  's_frequency_of_materials_in_class',
#  's_extent_of_teacher_performance',
#  's_extent_of_classmates_affinity',
#  'f_ESCS',
#  's_extent_of_school_satisfaction',
#  's_frequency_of_computer_usage',
#  'f_mother_age',
#  'f_number_of_homework_hours_a_week',
#  'p_number_of_preschool_students',
#  'p_number_of_primary_students',
#  'p_number_of_school_tech_resources',
#  'f_number_of_tech_at_home',
#  'f_frequency_of_books_at_home',
#  'f_extent_of_family_satisfaction',
#  'p_extent_of_problems',
#  'p_number_of_class_hours_per_week',
#  'p_extent_of_inconveniences',
#  'f_frequency_of_parent_involved_in_school_activities',
#  'p_number_of_teachers_in_school',
#  'p_number_of_years_of_teaching',
#  'p_age',
#  'p_number_of_years_in_school',
#  'p_number_of_years_as_principal',
#  'f_mother_education_level',
#  'f_frequency_of_see_adult_read',
#  'p_number_of_years_as_principal_in_school',
#  'p_extent_of_factors_limiting_effectiveness']

# %%
final_df = concatenated_df[final_features + [TARGET]]

# %%
favorable_sensitive_label = "ADVANTAGED"
unfavorable_sensitive_label = "DISADVANTAGED"
favorable_class_label = "PASSED"
unfavorable_class_label = "NOT PASSED"
trial_df = final_df[[TARGET, SENSITIVE]]
trial_df = trial_df.dropna()
trial_df[SENSITIVE] = trial_df[SENSITIVE].apply(lambda elem: favorable_sensitive_label if elem > 0.0 else unfavorable_sensitive_label)
trial_df[TARGET] = trial_df[TARGET].apply(lambda elem: favorable_class_label if elem >= 2.5 else unfavorable_class_label)
col_a = trial_df[TARGET]
col_b = trial_df[SENSITIVE]
crosstab = pd.crosstab(col_a, col_b)
# Heatmap of Frequency
plt.figure(figsize=(10, 6))
sns.heatmap(crosstab, annot=True, fmt='d', cmap='Blues')
plt.title(f'Heatmap of {TARGET} vs {SENSITIVE}')
plt.xlabel(SENSITIVE)
plt.ylabel(TARGET)
plt.show()
# Clustered Bar Plot
crosstab.plot(kind='bar', stacked=False, figsize=(10, 6))
plt.title(f'Stacked Bar Plot of {TARGET} vs {SENSITIVE}')
plt.xlabel(TARGET)
plt.ylabel('Frequency')
plt.legend(title=SENSITIVE)
plt.show()

# %%
trial_df = final_df[[TARGET, SENSITIVE]]
trial_df = trial_df.dropna()
col_a = trial_df[TARGET]
col_b = trial_df[SENSITIVE]
# Scatter Plot
plt.figure(figsize=(10, 6))
plt.scatter(col_a, col_b, alpha=0.5)
plt.title(f"Scatter Plot of {TARGET} vs {SENSITIVE}")
plt.xlabel(TARGET)
plt.ylabel(SENSITIVE)
plt.grid()
plt.show()
# 2D Histogram (Heatmap)
plt.figure(figsize=(10, 6))
plt.hist2d(col_a, col_b, bins=(30, 30), cmap=plt.cm.viridis)
plt.colorbar(label='Frequency')
plt.title(f"2D Histogram of {TARGET} vs {SENSITIVE}")
plt.xlabel(TARGET)
plt.ylabel(SENSITIVE)
plt.grid()
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.violinplot(x=TARGET, y=SENSITIVE, data=trial_df, inner="quartile")
plt.title(f'Distribution of {SENSITIVE} for Each Value of {TARGET}')
plt.xlabel(TARGET)
plt.ylabel(SENSITIVE)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
# Box Plot
plt.figure(figsize=(10, 6))
sns.boxplot(x=TARGET, y=SENSITIVE, data=trial_df)
plt.title(f'Box Plot of {SENSITIVE} for Each Value of {TARGET}')
plt.xlabel(TARGET)
plt.ylabel(SENSITIVE)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
final_df.head()
# Out:
#                   s_frequency_of_work_with_teachers  \
# id_questionnaire
# 20431                                      0.700000
# 20432                                      0.777778
# 20433                                      0.733333
# 20434                                      0.633333
# 20435                                      0.666667
#
#                   s_frequency_of_evaluations  s_frequency_of_internet_usage  \
# id_questionnaire
# 20431                               0.629630                       0.666667
# 20432                               0.814815                       0.266667
# 20433                               0.703704                       0.400000
# 20434                               0.629630                       0.266667
# 20435                               0.629630                       0.266667
#
#                   s_extent_of_class_env  s_frequency_of_materials_in_class  \
# id_questionnaire
# 20431                          0.583333                           0.666667
# 20432                          0.875000                           0.476190
# 20433                          0.916667                           0.476190
# 20434                          0.750000                           0.476190
# 20435                          0.666667                           0.523810
#
#                   s_extent_of_teacher_performance  \
# id_questionnaire
# 20431                                    0.700000
# 20432                                    0.900000
# 20433                                    1.000000
# 20434                                    0.766667
# 20435                                    0.833333
#
#                   s_extent_of_classmates_affinity    f_ESCS  \
# id_questionnaire
# 20431                                    0.761905  1.702062
# 20432                                    0.761905 -0.541375
# 20433                                    1.000000  0.943191
# 20434                                    0.904762 -0.759225
# 20435                                    0.809524  1.938398
#
#                   s_extent_of_school_satisfaction  \
# id_questionnaire
# 20431                                    0.722222
# 20432                                    0.666667
# 20433                                    1.000000
# 20434                                    0.722222
# 20435                                    0.888889
#
#                   s_frequency_of_computer_usage  ...  \
# id_questionnaire                                 ...
# 20431                                  0.444444  ...
# 20432                                  0.222222  ...
# 20433                                  0.444444  ...
# 20434                                  0.666667  ...
# 20435                                  0.111111  ...
#
#                   p_number_of_teachers_in_school  \
# id_questionnaire
# 20431                                       41.0
# 20432                                       41.0
# 20433                                       29.0
# 20434                                        5.0
# 20435                                       57.0
#
#                   p_number_of_years_of_teaching  p_age  \
# id_questionnaire
# 20431                                      30.0   59.0
# 20432                                      23.0   50.0
# 20433                                      26.0   55.0
# 20434                                      20.0   57.0
# 20435                                      26.0   55.0
#
#                   p_number_of_years_in_school  p_number_of_years_as_principal  \
# id_questionnaire
# 20431                                    25.0                            16.0
# 20432                                    17.0                             9.0
# 20433                                    13.0                             3.0
# 20434                                     1.0                             2.0
# 20435                                     4.0                            14.0
#
#                   f_mother_education_level  f_frequency_of_see_adult_read  \
# id_questionnaire
# 20431                                  4.0                          0.500
# 20432                                  3.0                          0.125
# 20433                                  3.0                          1.000
# 20434                                  3.0                          0.250
# 20435                                  6.0                          0.125
#
#                   p_number_of_years_as_principal_in_school  \
# id_questionnaire
# 20431                                                 16.0
# 20432                                                  9.0
# 20433                                                  3.0
# 20434                                                  1.0
# 20435                                                  2.0
#
#                   p_extent_of_factors_limiting_effectiveness  level_MAT
# id_questionnaire
# 20431                                               0.291667        3.0
# 20432                                               0.375000        3.0
# 20433                                               0.291667        3.0
# 20434                                               0.625000        1.0
# 20435                                               0.500000        3.0
#
# [5 rows x 32 columns]

# %% [markdown]
# ### Analysis of final dataset

# %%
final_df = final_df[~final_df.isnull().any(axis=1)]

# %%
_, final_correlation = compute_analysis(df=final_df, column_pattern=None, missing_threshold=MISS_THRESH_FINAL, annot=False)
# Out:
# FEATURES WITH ENOUGH VALUES: 32
# s_frequency_of_work_with_teachers                      0.0
# s_frequency_of_evaluations                             0.0
# s_frequency_of_internet_usage                          0.0
# s_extent_of_class_env                                  0.0
# s_frequency_of_materials_in_class                      0.0
# s_extent_of_teacher_performance                        0.0
# s_extent_of_classmates_affinity                        0.0
# f_ESCS                                                 0.0
# s_extent_of_school_satisfaction                        0.0
# s_frequency_of_computer_usage                          0.0
# f_mother_age                                           0.0
# f_number_of_homework_hours_a_week                      0.0
# p_number_of_preschool_students                         0.0
# p_number_of_primary_students                           0.0
# p_number_of_school_tech_resources                      0.0
# f_number_of_tech_at_home                               0.0
# f_frequency_of_books_at_home                           0.0
# f_extent_of_family_satisfaction                        0.0
# p_extent_of_problems                                   0.0
# p_number_of_class_hours_per_week                       0.0
# p_extent_of_inconveniences                             0.0
# f_frequency_of_parent_involved_in_school_activities    0.0
# p_number_of_teachers_in_school                         0.0
# p_number_of_years_of_teaching                          0.0
# p_age                                                  0.0
# p_number_of_years_in_school                            0.0
# p_number_of_years_as_principal                         0.0
# f_mother_education_level                               0.0
# f_frequency_of_see_adult_read                          0.0
# p_number_of_years_as_principal_in_school               0.0
# p_extent_of_factors_limiting_effectiveness             0.0
# level_MAT                                              0.0
# dtype: float64
#
# BAD FEATURES: 0
# Series([], dtype: float64)

# %%
final_df.to_csv("final_df.csv")

# %% [markdown]
# ### Proxy Detection

# %%
def find_proxies(feature, correlation, threshold=0.8):

    proxies = []
    proxy_header = True
    for i in correlation[feature].index:
        if (correlation[feature][i]>=threshold or correlation[feature][i]<=-threshold) and i!=feature:
            if proxy_header:
                print(f"\nProxy detected for {feature}:")
                proxy_header=False
                proxies.append(i)
            print(f"-----> {i} correlation: {round(correlation[feature][i],2)}")
    if not proxies:
        print(f"\nNo proxies detected for {feature}.")
    return proxies

# %%
target_proxies = find_proxies(TARGET, final_correlation, threshold=0.8)
sensitive_proxies = find_proxies(SENSITIVE, final_correlation, threshold=0.8)
# Out:
# No proxies detected for level_MAT.
#
# No proxies detected for f_ESCS.

# %%
def compute_demographic_parity_difference(df):
    dpd = demographic_parity_difference(y_true=df[TARGET], y_pred=df[TARGET], sensitive_features=df[SENSITIVE])
    print(f"Demographic parity difference of {TARGET} on {SENSITIVE}: {dpd}")
    return dpd

# %%
def compute_demographic_parity_ratio(df):
    dpr = demographic_parity_ratio(y_true=df[TARGET], y_pred=df[TARGET], sensitive_features=df[SENSITIVE])
    print(f"Demographic parity ratio of {TARGET} on {SENSITIVE}: {dpr}")
    return dpr

# %%
dpd = compute_demographic_parity_difference(final_df)
dpr = compute_demographic_parity_ratio(final_df)
# Out:
# Demographic parity difference of level_MAT on f_ESCS: 1.0
# Demographic parity ratio of level_MAT on f_ESCS: 0.0

# %% [markdown]
# ## 3) Training and Testing

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, roc_auc_score, classification_report, confusion_matrix
from sklearn.model_selection import GridSearchCV
import torch
np.random.seed(42)
torch.manual_seed(42)
from torch import nn
from fairlib.preprocessing import Reweighing, DisparateImpactRemover, LFR
from fairlib.inprocessing import Fauci, AdversarialDebiasing, PrejudiceRemover
from fairlib import DataFrame as DataFrameFL

# %%
final_df = pd.read_csv('final_df.csv', low_memory=False, index_col='id_questionnaire')
final_df.head()
# Out:
#                   s_frequency_of_work_with_teachers  \
# id_questionnaire
# 20431                                      0.700000
# 20432                                      0.777778
# 20433                                      0.733333
# 20434                                      0.633333
# 20435                                      0.666667
#
#                   s_frequency_of_evaluations  s_frequency_of_internet_usage  \
# id_questionnaire
# 20431                               0.629630                       0.666667
# 20432                               0.814815                       0.266667
# 20433                               0.703704                       0.400000
# 20434                               0.629630                       0.266667
# 20435                               0.629630                       0.266667
#
#                   s_extent_of_class_env  s_frequency_of_materials_in_class  \
# id_questionnaire
# 20431                          0.583333                           0.666667
# 20432                          0.875000                           0.476190
# 20433                          0.916667                           0.476190
# 20434                          0.750000                           0.476190
# 20435                          0.666667                           0.523810
#
#                   s_extent_of_teacher_performance  \
# id_questionnaire
# 20431                                    0.700000
# 20432                                    0.900000
# 20433                                    1.000000
# 20434                                    0.766667
# 20435                                    0.833333
#
#                   s_extent_of_classmates_affinity    f_ESCS  \
# id_questionnaire
# 20431                                    0.761905  1.702062
# 20432                                    0.761905 -0.541375
# 20433                                    1.000000  0.943191
# 20434                                    0.904762 -0.759225
# 20435                                    0.809524  1.938398
#
#                   s_extent_of_school_satisfaction  \
# id_questionnaire
# 20431                                    0.722222
# 20432                                    0.666667
# 20433                                    1.000000
# 20434                                    0.722222
# 20435                                    0.888889
#
#                   s_frequency_of_computer_usage  ...  \
# id_questionnaire                                 ...
# 20431                                  0.444444  ...
# 20432                                  0.222222  ...
# 20433                                  0.444444  ...
# 20434                                  0.666667  ...
# 20435                                  0.111111  ...
#
#                   p_number_of_teachers_in_school  \
# id_questionnaire
# 20431                                       41.0
# 20432                                       41.0
# 20433                                       29.0
# 20434                                        5.0
# 20435                                       57.0
#
#                   p_number_of_years_of_teaching  p_age  \
# id_questionnaire
# 20431                                      30.0   59.0
# 20432                                      23.0   50.0
# 20433                                      26.0   55.0
# 20434                                      20.0   57.0
# 20435                                      26.0   55.0
#
#                   p_number_of_years_in_school  p_number_of_years_as_principal  \
# id_questionnaire
# 20431                                    25.0                            16.0
# 20432                                    17.0                             9.0
# 20433                                    13.0                             3.0
# 20434                                     1.0                             2.0
# 20435                                     4.0                            14.0
#
#                   f_mother_education_level  f_frequency_of_see_adult_read  \
# id_questionnaire
# 20431                                  4.0                          0.500
# 20432                                  3.0                          0.125
# 20433                                  3.0                          1.000
# 20434                                  3.0                          0.250
# 20435                                  6.0                          0.125
#
#                   p_number_of_years_as_principal_in_school  \
# id_questionnaire
# 20431                                                 16.0
# 20432                                                  9.0
# 20433                                                  3.0
# 20434                                                  1.0
# 20435                                                  2.0
#
#                   p_extent_of_factors_limiting_effectiveness  level_MAT
# id_questionnaire
# 20431                                               0.291667        3.0
# 20432                                               0.375000        3.0
# 20433                                               0.291667        3.0
# 20434                                               0.625000        1.0
# 20435                                               0.500000        3.0
#
# [5 rows x 32 columns]

# %%
final_df[TARGET].value_counts()
# Out:
# level_MAT
# 3.0    3627
# 2.0    3309
# 4.0    1766
# 1.0    1424
# Name: count, dtype: int64

# %%
final_df[SENSITIVE] = final_df[SENSITIVE].apply(lambda elem: 1 if elem > 0.0 else 0)
final_df[TARGET] = final_df[TARGET].apply(lambda elem: 1 if elem >= 2.5 else 0)

# %%
display(final_df[TARGET].value_counts())
display(final_df[SENSITIVE].value_counts())
# Out:
# level_MAT
# 1    5393
# 0    4733
# Name: count, dtype: int64
# f_ESCS
# 1    5241
# 0    4885
# Name: count, dtype: int64

# %%
final_df.to_csv('preprocessed_df.csv')

# %%
final_df= pd.read_csv('preprocessed_df.csv', low_memory=False, index_col='id_questionnaire')

# %%
X = final_df.drop(columns=[TARGET])
Y = final_df[TARGET]

# %%
col_map = {name: i for i, name in enumerate(X.columns)}
inv_map = {v: k for k, v in col_map.items()}

# %% [markdown]
# We notice that there are no categorical columns left after the pre-processing.

# %%
class BaseModel(nn.Module):
    def __init__(self, input_dim, hidden_dim=64):
        super().__init__()
        self.net = nn.Sequential(
        nn.Linear(input_dim, hidden_dim),
        #nn.Dropout(0.2),
        #nn.BatchNorm1d(hidden_dim),
        nn.ReLU(),
        nn.Linear(hidden_dim, hidden_dim),
        #nn.Dropout(0.2),
        #nn.BatchNorm1d(hidden_dim),
         nn.ReLU(),
         nn.Linear(hidden_dim, hidden_dim//2),
        # #nn.Dropout(0.2),
         nn.ReLU(),
         nn.Linear(hidden_dim//2, hidden_dim//4),
        #nn.Dropout(0.2),
        nn.ReLU(),
        nn.Linear(hidden_dim//4, 1),
    )

    def forward(self, x):
        return self.net(x)

# %%
def prepare_data_for_NN(X_train, Y_train, X_test=None, Y_test=None, imputer=None, scaler=None):
        
    if scaler:    
        X_train = scaler.transform(X_train)
    else:
        scaler = MinMaxScaler()#StandardScaler()
        X_train = scaler.fit_transform(X_train)

    X_train = pd.DataFrame(X_train, columns = inv_map)

    X_train_tensor = torch.tensor(X_train.values, dtype=torch.float32)
    X_train_tensor = X_train_tensor.to(device)

    Y_train_tensor = torch.tensor(Y_train.values, dtype=torch.float32).view(-1, 1)
    Y_train_tensor = Y_train_tensor.to(device)

    if X_test:
        X_test_tensor = torch.tensor(X_test.values, dtype=torch.float32)
        X_test_tensor = X_test_tensor.to(device)

        Y_test_tensor = torch.tensor(Y_test.values, dtype=torch.float32).view(-1, 1)
    else:
        X_test_tensor = None
        Y_test_tensor = None

    return X_train_tensor, Y_train_tensor, X_test_tensor, Y_test_tensor, imputer, scaler

# %%
def evaluate_model(Y_true, Y_pred, show=False):
    acc = 100 * accuracy_score(Y_true, Y_pred)
    f1 = 100 * f1_score(Y_true, Y_pred)
    prec = 100 * precision_score(Y_true, Y_pred, zero_division=0.0)
    rec = 100 * recall_score(Y_true, Y_pred)
    roc_auc = 100 * roc_auc_score(Y_true, Y_pred)
    
    if show:
        print("ACCURACY:", acc)
        print("F1-SCORE:", f1)
        print("Precision:", prec)
        print("Recall:", rec)
        print("ROC-AUC:", roc_auc)
        sns.heatmap(confusion_matrix(Y_true, Y_pred, normalize='true'), annot=True, vmin=0, vmax=1)
        plt.show()

        #return

    return acc, f1, prec, rec, roc_auc

# %%
def evaluate_model_fairness(X, Y_true, Y_pred, sensitive_feature=SENSITIVE,  show=False):
    print(f"Sensitive feature is {sensitive_feature}")
    if type(X) == pd.DataFrame:
        sensitive = X[sensitive_feature]
    else:
        sensitive = X.T[col_map[sensitive_feature]]
    dpd = demographic_parity_difference(y_true=Y_true, y_pred=Y_pred, sensitive_features=sensitive, method='to_overall')
    dpr = demographic_parity_ratio(y_true=Y_true, y_pred=Y_pred, sensitive_features=sensitive, method='to_overall')
    if show:
        print(f"Demographic parity difference: {dpd}")
        print(f"Demographic parity ratio: {dpr}")
    return dpd, dpr

# %%
def train_loop(epochs, base_model, optimizer, scheduler, X_train, Y_train, X_val, Y_val, batch_size, weights=None, sensitive_feature=None):
    
    # Initialise empty lists to store losses
    train_losses = []
    val_losses = []
    
    # Loop over epochs
    for epoch in range(epochs):
        print(f"Epoch {epoch + 1:02d}")
        # Set model to training mode
        base_model.train()
        # Initialize epoch losses
        epoch_train_loss = 0.0
        epoch_val_loss = 0.0

        # Initialize lists to store predictions and labels    
        all_predictions = []
        all_labels = []

        # Iterate over batches
        for i in range(0, len(X_train), batch_size):
            # Extract current batch for X and Y
            batch_X = X_train[i:i + batch_size]
            batch_y = Y_train[i:i + batch_size]
            batch_weights = weights[i:i + batch_size] if weights is not None else None

            # Forward pass
            batch_outputs = base_model(batch_X)

            batch_loss = nn.functional.binary_cross_entropy_with_logits(batch_outputs, batch_y, reduction='none', weight=batch_weights.unsqueeze(1)).mean()#criterion(batch_outputs, batch_y).mean()
            epoch_train_loss += batch_loss.item()
            # Backward pass and optimization    
            optimizer.zero_grad()
            batch_loss.backward()
            optimizer.step()
            
            # Store predictions and labels
            batch_predictions = (torch.sigmoid(batch_outputs) > 0.5).float()
            all_predictions.append(batch_predictions.detach().cpu())
            all_labels.append(batch_y.detach().cpu())

        # Update learning rate scheduler
        scheduler.step()

        # Udpdate and normalize epoch loss
        epoch_train_loss /= (len(X_train) // batch_size)
        train_losses.append(epoch_train_loss)

        # Convert list of tensors → single flat tensor
        all_labels = torch.cat(all_labels)
        all_predictions = torch.cat(all_predictions)

        # Convert to 1D integer numpy arrays
        y_true = all_labels.view(-1).numpy().astype(int)
        y_pred = all_predictions.view(-1).numpy().astype(int)
        accuracy, f1, precision, recall, roc_auc = evaluate_model(y_true, y_pred, show=False)
        dpd, dpr = evaluate_model_fairness(X_train, y_true, y_pred, sensitive_feature=sensitive_feature, show=False)
            
        # Print current epoch training metrics
        print(f"Training General Metrics - loss: {epoch_train_loss:.4f} – acc: {accuracy:.2f}% – f1: {f1:.2f}% – precision: {precision:.2f}% – recall: {recall:.2f}% – roc_auc: {roc_auc:.2f}%")
        print(f"Training Fairness Metrics - DPD: {dpd:.4f} – DPR: {dpr:.4f}")   
        # Begin evaluation mode
        base_model.eval()
        with torch.no_grad():
            # Forward pass on validation set
            val_outputs = base_model(X_val)
                
            epoch_val_loss = nn.functional.binary_cross_entropy_with_logits(val_outputs.to(device), Y_val.to(device), reduction='none').mean()#criterion(val_outputs.to(device), Y_val.to(device)).mean()
            val_losses.append(epoch_val_loss)

            val_predictions = (torch.sigmoid(val_outputs) > 0.5).float()
            Y_val = Y_val.detach().cpu()
                
            # Get predictions and evaluate
            val_predictions = val_predictions#.detach().cpu()
            y_true_val = Y_val.view(-1).numpy().astype(int)
            y_pred_val = val_predictions.view(-1).numpy().astype(int)

            #Compute validation metrics
            accuracy, f1, precision, recall, roc_auc = evaluate_model(y_true_val, y_pred_val, show=False)
            dpd, dpr = evaluate_model_fairness(X_val, y_true_val, y_pred_val, sensitive_feature=sensitive_feature, show=False)   
            # Print current epoch validation metrics
            print(f"Validation General Metrics - loss: {epoch_val_loss:.4f} acc: {accuracy:.2f}% – f1: {f1:.2f}% – precision: {precision:.2f}% – recall: {recall:.2f}% – roc_auc: {roc_auc:.2f}%")
            print(f"Validation Fairness Metrics - DPD: {dpd:.4f} – DPR: {dpr:.4f}")
    
    return accuracy, f1, precision, recall, roc_auc, dpd, dpr,train_losses, val_losses

# %%
def initialise_model_and_hyperparameters(input_size):
    base_model = BaseModel(input_size)
    base_model.to(device)
    #criterion = nn.BCEWithLogitsLoss(reduction='none', weight=weights)
    #criterion = nn.functional.binary_cross_entropy_with_logits
    optimizer = torch.optim.Adam(base_model.parameters(), lr=0.005, weight_decay=1e-4)
    scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=10)
    epochs = 20
    batch_size = 32
    return base_model, optimizer, scheduler, epochs, batch_size, #criterion

# %%
def plot_kfold_results(res):
    sns.barplot(x='metric', y='avg', data=res, hue='metric')
    plt.errorbar(x=range(len(res)), y=res['avg'], yerr=res['std'], fmt='none', ecolor='black', capsize=10)
    plt.ylabel('Score')
    plt.show()

# %%
def preprocess_with_reweighing(X, Y, sensitive=SENSITIVE, target=TARGET):
    rw_df = pd.concat([X, Y], axis=1)
    rw_df = DataFrameFL(rw_df)
    rw_df.targets=target
    rw_df.sensitive=sensitive
    rw = Reweighing()
    rw_df = rw.fit_transform(rw_df)
    weights = rw_df['weights']
    return weights

# %%
def preprocess_with_dir(X, Y, sensitive=SENSITIVE, target=TARGET, repair_level=1.0):
    dir_df = pd.concat([X, Y], axis=1)
    dir_df = DataFrameFL(dir_df)
    dir_df.targets=target
    dir_df.sensitive=sensitive
    dir = DisparateImpactRemover(repair_level=repair_level)
    dir_df = dir.fit_transform(dir_df, sensitive_features=sensitive, target=[target])
    return dir_df

# %%
def preprocess_with_lfr(X, Y, X_val, Y_val, sensitive=SENSITIVE, target=TARGET, epochs=50, learning_rate=0.001):
    lfr_df = pd.concat([X, Y], axis=1)
    lfr_df = DataFrameFL(lfr_df)
    lfr_df.targets=target
    lfr_df.sensitive=sensitive

    latent_dim = 31
    lfr = LFR(input_dim=X.shape[1], latent_dim=latent_dim, output_dim=X.shape[1])

    lrf_train_df = lfr.fit_transform(lfr_df, epochs=epochs, learning_rate=learning_rate)
    lrf_train_df = pd.DataFrame(lrf_train_df.values, columns=lrf_train_df.columns)

    lfr_val_df = pd.concat([X_val, Y_val], axis=1)
    lfr_val_df = DataFrameFL(lfr_val_df)
    lfr_val_df.targets=target
    lfr_val_df.sensitive=sensitive

    lrf_val_df = lfr.transform(lfr_val_df)
    lrf_val_df = pd.DataFrame(lrf_val_df.values, columns=lrf_val_df.columns)

    return lrf_train_df, lrf_val_df

# %%
def train_with_fauci(simple_net, X, Y, X_val, Y_val, sensitive_feature):
    REGULARIZATION_WEIGHT = 0.1
    fauci = Fauci(torchModel=simple_net, loss=nn.BCEWithLogitsLoss(), fairness_regularization="spd", regularization_weight=REGULARIZATION_WEIGHT)
    fauci.fit(X, torch.tensor(Y.values, dtype=torch.float32).unsqueeze(1), epochs=20, batch_size=64, learning_rate=0.005)
    
    fauci_val_probs = fauci.predict(X_val)
    fauci_pred = (fauci_val_probs > 0.5).int().cpu().numpy()
    fauci_accuracy, fauci_f1, fauci_precision, fauci_recall, fauci_roc_auc = evaluate_model(Y_val.values, fauci_pred, show=False)
    fauci_dpd, fauci_dpr = evaluate_model_fairness(X_val, Y_val.values, fauci_pred, sensitive_feature=sensitive_feature, show=False)
    print(f"Validation General Metrics -  acc: {fauci_accuracy:.2f}% – f1: {fauci_f1:.2f}% – precision: {fauci_precision:.2f}% – recall: {fauci_recall:.2f}% – roc_auc: {fauci_roc_auc:.2f}%")
    print(f"Validation Fairness Metrics - DPD: {fauci_dpd:.4f} – DPR: {fauci_dpr:.4f}")
    return fauci_accuracy, fauci_f1, fauci_precision, fauci_recall, fauci_roc_auc, fauci_dpd, fauci_dpr, [], []

# %%
def train_with_pr(simple_net, X, Y, X_val, Y_val, sensitive_feature):
    ETA = 0.1
    pr = PrejudiceRemover(torchModel=simple_net, loss=nn.BCEWithLogitsLoss(), eta=ETA)
    pr.fit(X, torch.tensor(Y.values, dtype=torch.float32).unsqueeze(1), epochs=20, batch_size=64, learning_rate=0.005)
    pr_val_probs = pr.predict(X_val)
    pr_pred = (pr_val_probs > 0.5).int().cpu().numpy()
    pr_accuracy, pr_f1, pr_precision, pr_recall, pr_roc_auc = evaluate_model(Y_val.values, pr_pred, show=False)
    pr_dpd, pr_dpr = evaluate_model_fairness(X_val, Y_val.values, pr_pred, sensitive_feature=sensitive_feature, show=False)
    print(f"Validation General Metrics -  acc: {pr_accuracy:.2f}% – f1: {pr_f1:.2f}% – precision: {pr_precision:.2f}% – recall: {pr_recall:.2f}% – roc_auc: {pr_roc_auc:.2f}%")
    print(f"Validation Fairness Metrics - DPD: {pr_dpd:.4f} – DPR: {pr_dpr:.4f}")
    return pr_accuracy, pr_f1, pr_precision, pr_recall, pr_roc_auc, pr_dpd, pr_dpr, [], []

# %%
def train_with_ad(X, Y, X_val, Y_val, sensitive_feature):
    LAMBDA_ADV = 0.1
    ad = AdversarialDebiasing(input_dim=X.shape[1], hidden_dim=64, output_dim=1, sensitive_dim=1, lambda_adv=LAMBDA_ADV)
    ad.fit(X, Y, epochs=20, batch_size=64, learning_rate=0.005)

    adv_pred = ad.predict(X_val).cpu().numpy().astype(int).flatten()
    ad_accuracy, ad_f1, ad_precision, ad_recall, ad_roc_auc = evaluate_model(Y_val.values, adv_pred, show=False)
    ad_dpd, ad_dpr = evaluate_model_fairness(X_val, Y_val.values, adv_pred, sensitive_feature=sensitive_feature, show=False)
    print(f"Validation General Metrics -  acc: {ad_accuracy:.2f}% – f1: {ad_f1:.2f}% – precision: {ad_precision:.2f}% – recall: {ad_recall:.2f}% – roc_auc: {ad_roc_auc:.2f}%")
    print(f"Validation Fairness Metrics - DPD: {ad_dpd:.4f} – DPR: {ad_dpr:.4f}")
    return ad_accuracy, ad_f1, ad_precision, ad_recall, ad_roc_auc, ad_dpd, ad_dpr, [], []

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.utils.class_weight import compute_class_weight

def kfold_cross_validation(k, X, Y, sensitive_feature=SENSITIVE, preprocessing=None, inprocessing=None):
    kfold = StratifiedKFold(n_splits=k, shuffle=True, random_state=42)

    accuracies = []
    f1s = []
    precisions = []
    recalls = []
    roc_aucs = []
    dpds = []
    dprs = []

    res = {
        'metric': ['accuracy', 'f1', 'precision', 'recall', 'roc_auc'],
        'avg': [],
        'std': []
    }

    fairness_res = {
        'metric': ['dpd', 'dpr'],
        'avg': [],
        'std': []
    }


    for fold, (train_idx, val_idx) in enumerate(kfold.split(X, Y)):
        print(f"Fold {fold + 1}")
        
        X_train_fold, Y_train_fold = X.iloc[train_idx], Y.iloc[train_idx]
        X_val_fold, Y_val_fold = X.iloc[val_idx], Y.iloc[val_idx]

        class_weights = compute_class_weight(class_weight='balanced', classes=np.unique(Y_train_fold), y=Y_train_fold)
        #print(f"Class weights: {class_weights}")
        train_weights = np.array([class_weights[int(label)] for label in Y_train_fold])

        # Adjustments for preprocessing mitigation
        if preprocessing == 'reweighing':
            X_train_copy = X_train_fold.copy().reset_index(drop=True)
            Y_train_copy = Y_train_fold.copy().reset_index(drop=True)
            
            weights = preprocess_with_reweighing(X_train_copy, Y_train_copy, sensitive=sensitive_feature, target=TARGET)
            train_weights = np.array(weights)
        elif preprocessing == 'dir':
            X_train_fold= preprocess_with_dir(X_train_fold, Y_train_fold, sensitive=sensitive_feature, target=TARGET, repair_level=1.0)
        elif preprocessing == 'lfr':
            X_train_fold, X_val_fold = preprocess_with_lfr(X_train_fold, Y_train_fold, X_val_fold, Y_val_fold, sensitive=sensitive_feature, target=TARGET, epochs=50, learning_rate=0.001)
        else:
            pass
         #----------------------------------------------   

        train_weights = torch.tensor(train_weights, dtype=torch.float32, device=device)
        X_train_tensor, Y_train_tensor, _, _, imputer, scaler = prepare_data_for_NN(X_train_fold, Y_train_fold)
        X_val_tensor, Y_val_tensor, _, _, _, _ = prepare_data_for_NN(X_val_fold, Y_val_fold, imputer=imputer, scaler=scaler)
    
        # Adjustments for in-processing mitigation
        if inprocessing == 'adversarial_debiasing':
            X_train_ad = DataFrameFL(X_train_tensor.cpu().numpy(), columns=X_train_fold.columns)
            X_train_ad.sensitive = sensitive_feature
            X_val_ad = DataFrameFL(X_val_tensor.cpu().numpy(), columns=X_val_fold.columns)
            X_val_ad.sensitive = sensitive_feature  
            fold_accuracy, fold_f1, fold_precision, fold_recall, fold_roc_auc, dpd, dpr, losses, val_losses = train_with_ad(X_train_ad, Y_train_fold, X_val_ad, Y_val_fold, sensitive_feature=sensitive_feature)
        elif inprocessing == 'FaUCI':
            X_train_fauci = DataFrameFL(X_train_tensor.cpu().numpy(), columns=X_train_fold.columns)
            X_train_fauci.sensitive = sensitive_feature
            X_val_fauci = DataFrameFL(X_val_tensor.cpu().numpy(), columns=X_val_fold.columns)
            X_val_fauci.sensitive = sensitive_feature

            simple_net = BaseModel(input_dim=X_train_tensor.shape[1])
            simple_net.to(device)
            fold_accuracy, fold_f1, fold_precision, fold_recall, fold_roc_auc, dpd, dpr, losses, val_losses = train_with_fauci(simple_net, X_train_fauci, Y_train_fold, X_val_fauci, Y_val_fold, sensitive_feature=sensitive_feature)
        elif inprocessing == 'prejudice_remover':
            X_train_pr = DataFrameFL(X_train_tensor.cpu().numpy(), columns=X_train_fold.columns)
            X_train_pr.sensitive = sensitive_feature
            X_val_pr = DataFrameFL(X_val_tensor.cpu().numpy(), columns=X_val_fold.columns)
            X_val_pr.sensitive = sensitive_feature
            
            simple_net = BaseModel(input_dim=X_train_tensor.shape[1])
            simple_net.to(device)
            fold_accuracy, fold_f1, fold_precision, fold_recall, fold_roc_auc, dpd, dpr, losses, val_losses = train_with_pr(simple_net, X_train_pr, Y_train_fold, X_val_pr, Y_val_fold, sensitive_feature=sensitive_feature)
        else:
            base_model, optimizer, scheduler, epochs, batch_size = initialise_model_and_hyperparameters(X_train_tensor.shape[1])
            fold_accuracy, fold_f1, fold_precision, fold_recall, fold_roc_auc, dpd, dpr, losses, val_losses = train_loop(epochs, base_model, optimizer, scheduler, X_train_tensor, Y_train_tensor, X_val_tensor, Y_val_tensor, batch_size, sensitive_feature=sensitive_feature, weights=train_weights)
        #----------------------------------------------

        if losses and val_losses:
            x = [i for i in range(1,len(losses)+1)]
            # Plot both lists on the same graph
            plt.plot(x, losses, label='Trainging Loss', marker='o')
            plt.plot(x, val_losses, label='Validation Loss', marker='s')

            # Add title and labels
            plt.title('Loss Progression')
            plt.xlabel('Epochs')
            plt.ylabel('Loss')

            # Add legend
            plt.legend()

            # Show the graph
            plt.show()

        accuracies.append(fold_accuracy)
        f1s.append(fold_f1)
        precisions.append(fold_precision)
        recalls.append(fold_recall)
        roc_aucs.append(fold_roc_auc)
        dpds.append(dpd)
        dprs.append(dpr) 


        
    avgs = []
    stds = []
    avgs.append(np.mean(accuracies))
    stds.append(np.std(accuracies))
    avgs.append(np.mean(f1s))
    stds.append(np.std(f1s))
    avgs.append(np.mean(precisions))
    stds.append(np.std(precisions))
    avgs.append(np.mean(recalls))
    stds.append(np.std(recalls))
    avgs.append(np.mean(roc_aucs))
    stds.append(np.std(roc_aucs))    
    res['avg'] = avgs
    res['std'] = stds

    print("FINAL RESULTS ACROSS ALL FOLDS:")
    print("Accuracy: ", avgs[0], "±", stds[0])
    print("F1-Score: ", avgs[1], "±", stds[1])
    print("Precision: ", avgs[2], "±", stds[2])
    print("Recall: ", avgs[3], "±", stds[3])
    print("ROC-AUC: ", avgs[4], "±", stds[4])

    fair_avgs= []
    fair_stds= []
    fair_avgs.append(np.mean(dpds))
    fair_stds.append(np.std(dpds))
    fair_avgs.append(np.mean(dprs))
    fair_stds.append(np.std(dprs))
    fairness_res['avg'] = fair_avgs
    fairness_res['std'] = fair_stds

    print("FINAL FAIRNESS RESULTS ACROSS ALL FOLDS:")
    print("Demographic Parity Difference: ", fair_avgs[0], "±", fair_stds[0])
    print("Demographic Parity Ratio: ", fair_avgs[1], "±", fair_stds[1])

    res = pd.DataFrame(res)
    fairness_res = pd.DataFrame(fairness_res)

    plot_kfold_results(res)
    plot_kfold_results(fairness_res)

    return res, fairness_res

# %% [markdown]
# ### Training baseline model

# %%
res_base, fair_res_base = kfold_cross_validation(5, X, Y, sensitive_feature=SENSITIVE)
# Out:
# Fold 1
# Epoch 01
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6839 – acc: 56.33% – f1: 56.48% – precision: 60.19% – recall: 53.20% – roc_auc: 56.55%
# Training Fairness Metrics - DPD: 0.2823 – DPR: 0.4003
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6792 acc: 57.65% – f1: 53.77% – precision: 64.22% – recall: 46.25% – roc_auc: 58.45%
# Validation Fairness Metrics - DPD: 0.3501 – DPR: 0.0871
# Epoch 02
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6719 – acc: 58.85% – f1: 60.00% – precision: 62.20% – recall: 57.95% – roc_auc: 58.91%
# Training Fairness Metrics - DPD: 0.3503 – DPR: 0.2941
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6777 acc: 57.01% – f1: 49.27% – precision: 66.30% – recall: 39.20% – roc_auc: 58.25%
# Validation Fairness Metrics - DPD: 0.2763 – DPR: 0.1226
# Epoch 03
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6686 – acc: 59.42% – f1: 59.85% – precision: 63.26% – recall: 56.79% – roc_auc: 59.60%
# Training Fairness Metrics - DPD: 0.3404 – DPR: 0.2881
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6694 acc: 59.03% – f1: 56.59% – precision: 64.95% – recall: 50.14% – roc_auc: 59.65%
# Validation Fairness Metrics - DPD: 0.3130 – DPR: 0.2386
# Epoch 04
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6664 – acc: 59.80% – f1: 59.94% – precision: 63.87% – recall: 56.47% – roc_auc: 60.04%
# Training Fairness Metrics - DPD: 0.3155 – DPR: 0.3299
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6693 acc: 58.64% – f1: 54.90% – precision: 65.47% – recall: 47.27% – roc_auc: 59.43%
# Validation Fairness Metrics - DPD: 0.2864 – DPR: 0.2552
# Epoch 05
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6649 – acc: 59.91% – f1: 59.84% – precision: 64.15% – recall: 56.07% – roc_auc: 60.18%
# Training Fairness Metrics - DPD: 0.3074 – DPR: 0.3397
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6683 acc: 58.69% – f1: 55.17% – precision: 65.36% – recall: 47.73% – roc_auc: 59.45%
# Validation Fairness Metrics - DPD: 0.2835 – DPR: 0.2711
# Epoch 06
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6640 – acc: 59.96% – f1: 59.84% – precision: 64.24% – recall: 56.00% – roc_auc: 60.24%
# Training Fairness Metrics - DPD: 0.3062 – DPR: 0.3406
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6668 acc: 59.03% – f1: 55.94% – precision: 65.47% – recall: 48.84% – roc_auc: 59.74%
# Validation Fairness Metrics - DPD: 0.2898 – DPR: 0.2706
# Epoch 07
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6632 – acc: 60.05% – f1: 60.17% – precision: 64.15% – recall: 56.65% – roc_auc: 60.29%
# Training Fairness Metrics - DPD: 0.3005 – DPR: 0.3611
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6655 acc: 58.84% – f1: 56.06% – precision: 64.96% – recall: 49.30% – roc_auc: 59.50%
# Validation Fairness Metrics - DPD: 0.2842 – DPR: 0.2970
# Epoch 08
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6625 – acc: 60.02% – f1: 59.69% – precision: 64.47% – recall: 55.56% – roc_auc: 60.34%
# Training Fairness Metrics - DPD: 0.3032 – DPR: 0.3395
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6686 acc: 58.93% – f1: 54.39% – precision: 66.58% – recall: 45.97% – roc_auc: 59.84%
# Validation Fairness Metrics - DPD: 0.2738 – DPR: 0.2555
# Epoch 09
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6618 – acc: 60.23% – f1: 60.12% – precision: 64.52% – recall: 56.28% – roc_auc: 60.51%
# Training Fairness Metrics - DPD: 0.3085 – DPR: 0.3360
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6666 acc: 58.98% – f1: 55.68% – precision: 65.58% – recall: 48.38% – roc_auc: 59.72%
# Validation Fairness Metrics - DPD: 0.2843 – DPR: 0.2763
# Epoch 10
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6616 – acc: 60.27% – f1: 60.14% – precision: 64.57% – recall: 56.28% – roc_auc: 60.55%
# Training Fairness Metrics - DPD: 0.3033 – DPR: 0.3467
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6689 acc: 58.88% – f1: 54.36% – precision: 66.49% – recall: 45.97% – roc_auc: 59.78%
# Validation Fairness Metrics - DPD: 0.2732 – DPR: 0.2580
# Epoch 11
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6565 – acc: 60.85% – f1: 61.14% – precision: 64.86% – recall: 57.83% – roc_auc: 61.06%
# Training Fairness Metrics - DPD: 0.3132 – DPR: 0.3405
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6603 acc: 59.62% – f1: 62.55% – precision: 61.81% – recall: 63.30% – roc_auc: 59.37%
# Validation Fairness Metrics - DPD: 0.3189 – DPR: 0.4153
# Epoch 12
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6549 – acc: 60.90% – f1: 61.69% – precision: 64.51% – recall: 59.11% – roc_auc: 61.03%
# Training Fairness Metrics - DPD: 0.3113 – DPR: 0.3621
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6602 acc: 59.77% – f1: 62.49% – precision: 62.07% – recall: 62.93% – roc_auc: 59.55%
# Validation Fairness Metrics - DPD: 0.3124 – DPR: 0.4214
# Epoch 13
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6545 – acc: 61.04% – f1: 61.66% – precision: 64.78% – recall: 58.83% – roc_auc: 61.19%
# Training Fairness Metrics - DPD: 0.3090 – DPR: 0.3611
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6601 acc: 59.77% – f1: 62.36% – precision: 62.15% – recall: 62.56% – roc_auc: 59.58%
# Validation Fairness Metrics - DPD: 0.3106 – DPR: 0.4206
# Epoch 14
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6541 – acc: 61.07% – f1: 61.69% – precision: 64.82% – recall: 58.85% – roc_auc: 61.23%
# Training Fairness Metrics - DPD: 0.3069 – DPR: 0.3655
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6601 acc: 59.92% – f1: 62.51% – precision: 62.28% – recall: 62.74% – roc_auc: 59.72%
# Validation Fairness Metrics - DPD: 0.3090 – DPR: 0.4241
# Epoch 15
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6537 – acc: 61.14% – f1: 61.72% – precision: 64.91% – recall: 58.83% – roc_auc: 61.30%
# Training Fairness Metrics - DPD: 0.3050 – DPR: 0.3682
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6601 acc: 59.87% – f1: 62.31% – precision: 62.34% – recall: 62.28% – roc_auc: 59.70%
# Validation Fairness Metrics - DPD: 0.3056 – DPR: 0.4257
# Epoch 16
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6535 – acc: 61.23% – f1: 61.83% – precision: 65.01% – recall: 58.95% – roc_auc: 61.39%
# Training Fairness Metrics - DPD: 0.3014 – DPR: 0.3759
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6601 acc: 59.87% – f1: 62.24% – precision: 62.38% – recall: 62.09% – roc_auc: 59.72%
# Validation Fairness Metrics - DPD: 0.3046 – DPR: 0.4253
# Epoch 17
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6532 – acc: 61.09% – f1: 61.61% – precision: 64.91% – recall: 58.62% – roc_auc: 61.26%
# Training Fairness Metrics - DPD: 0.2997 – DPR: 0.3770
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6601 acc: 59.87% – f1: 62.13% – precision: 62.45% – recall: 61.82% – roc_auc: 59.74%
# Validation Fairness Metrics - DPD: 0.3038 – DPR: 0.4238
# Epoch 18
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6530 – acc: 61.12% – f1: 61.59% – precision: 64.99% – recall: 58.53% – roc_auc: 61.30%
# Training Fairness Metrics - DPD: 0.2983 – DPR: 0.3780
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6603 acc: 59.77% – f1: 61.83% – precision: 62.50% – recall: 61.17% – roc_auc: 59.68%
# Validation Fairness Metrics - DPD: 0.2989 – DPR: 0.4266
# Epoch 19
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6527 – acc: 61.10% – f1: 61.53% – precision: 65.00% – recall: 58.41% – roc_auc: 61.29%
# Training Fairness Metrics - DPD: 0.2950 – DPR: 0.3836
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6604 acc: 59.58% – f1: 61.39% – precision: 62.48% – recall: 60.33% – roc_auc: 59.52%
# Validation Fairness Metrics - DPD: 0.2941 – DPR: 0.4282
# Epoch 20
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6525 – acc: 61.27% – f1: 61.66% – precision: 65.21% – recall: 58.48% – roc_auc: 61.47%
# Training Fairness Metrics - DPD: 0.2920 – DPR: 0.3886
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6605 acc: 59.43% – f1: 61.30% – precision: 62.30% – recall: 60.33% – roc_auc: 59.36%
# Validation Fairness Metrics - DPD: 0.2903 – DPR: 0.4371
# Fold 2
# Epoch 01
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6807 – acc: 57.40% – f1: 60.27% – precision: 59.87% – recall: 60.69% – roc_auc: 57.17%
# Training Fairness Metrics - DPD: 0.3431 – DPR: 0.3643
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6958 acc: 56.79% – f1: 47.51% – precision: 67.35% – recall: 36.70% – roc_auc: 58.20%
# Validation Fairness Metrics - DPD: 0.2742 – DPR: 0.0557
# Epoch 02
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6712 – acc: 59.68% – f1: 60.04% – precision: 63.58% – recall: 56.88% – roc_auc: 59.88%
# Training Fairness Metrics - DPD: 0.3378 – DPR: 0.2910
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6731 acc: 57.73% – f1: 53.22% – precision: 64.85% – recall: 45.13% – roc_auc: 58.61%
# Validation Fairness Metrics - DPD: 0.2981 – DPR: 0.1961
# Epoch 03
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6678 – acc: 60.60% – f1: 61.12% – precision: 64.40% – recall: 58.16% – roc_auc: 60.77%
# Training Fairness Metrics - DPD: 0.3176 – DPR: 0.3395
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6683 acc: 58.07% – f1: 54.72% – precision: 64.45% – recall: 47.54% – roc_auc: 58.81%
# Validation Fairness Metrics - DPD: 0.3062 – DPR: 0.2210
# Epoch 04
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6670 – acc: 60.17% – f1: 60.61% – precision: 64.01% – recall: 57.56% – roc_auc: 60.35%
# Training Fairness Metrics - DPD: 0.2968 – DPR: 0.3802
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6668 acc: 57.93% – f1: 54.97% – precision: 63.96% – recall: 48.19% – roc_auc: 58.61%
# Validation Fairness Metrics - DPD: 0.3065 – DPR: 0.2365
# Epoch 05
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6653 – acc: 60.63% – f1: 61.31% – precision: 64.32% – recall: 58.58% – roc_auc: 60.78%
# Training Fairness Metrics - DPD: 0.2917 – DPR: 0.3986
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6688 acc: 57.73% – f1: 53.43% – precision: 64.69% – recall: 45.51% – roc_auc: 58.59%
# Validation Fairness Metrics - DPD: 0.2879 – DPR: 0.2318
# Epoch 06
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6645 – acc: 60.70% – f1: 61.19% – precision: 64.52% – recall: 58.18% – roc_auc: 60.87%
# Training Fairness Metrics - DPD: 0.2915 – DPR: 0.3930
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6674 acc: 57.98% – f1: 54.76% – precision: 64.21% – recall: 47.73% – roc_auc: 58.70%
# Validation Fairness Metrics - DPD: 0.2950 – DPR: 0.2550
# Epoch 07
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6641 – acc: 60.65% – f1: 61.35% – precision: 64.31% – recall: 58.65% – roc_auc: 60.79%
# Training Fairness Metrics - DPD: 0.2897 – DPR: 0.4034
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6666 acc: 58.17% – f1: 54.73% – precision: 64.65% – recall: 47.45% – roc_auc: 58.93%
# Validation Fairness Metrics - DPD: 0.2911 – DPR: 0.2557
# Epoch 08
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6635 – acc: 60.65% – f1: 61.33% – precision: 64.33% – recall: 58.60% – roc_auc: 60.79%
# Training Fairness Metrics - DPD: 0.2923 – DPR: 0.3974
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6658 acc: 58.22% – f1: 54.81% – precision: 64.69% – recall: 47.54% – roc_auc: 58.97%
# Validation Fairness Metrics - DPD: 0.2926 – DPR: 0.2528
# Epoch 09
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6629 – acc: 60.61% – f1: 61.19% – precision: 64.36% – recall: 58.32% – roc_auc: 60.77%
# Training Fairness Metrics - DPD: 0.2951 – DPR: 0.3884
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6649 acc: 58.62% – f1: 55.89% – precision: 64.68% – recall: 49.21% – roc_auc: 59.28%
# Validation Fairness Metrics - DPD: 0.2963 – DPR: 0.2691
# Epoch 10
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6629 – acc: 60.52% – f1: 61.13% – precision: 64.26% – recall: 58.30% – roc_auc: 60.68%
# Training Fairness Metrics - DPD: 0.2906 – DPR: 0.3985
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6813 acc: 57.38% – f1: 51.92% – precision: 65.08% – recall: 43.19% – roc_auc: 58.38%
# Validation Fairness Metrics - DPD: 0.2708 – DPR: 0.2343
# Epoch 11
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6577 – acc: 60.82% – f1: 62.26% – precision: 63.92% – recall: 60.69% – roc_auc: 60.83%
# Training Fairness Metrics - DPD: 0.3059 – DPR: 0.3950
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6602 acc: 59.51% – f1: 60.46% – precision: 63.02% – recall: 58.11% – roc_auc: 59.60%
# Validation Fairness Metrics - DPD: 0.2974 – DPR: 0.3947
# Epoch 12
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6567 – acc: 60.97% – f1: 62.25% – precision: 64.18% – recall: 60.43% – roc_auc: 61.01%
# Training Fairness Metrics - DPD: 0.3060 – DPR: 0.3897
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6599 acc: 59.60% – f1: 60.48% – precision: 63.17% – recall: 58.02% – roc_auc: 59.72%
# Validation Fairness Metrics - DPD: 0.2995 – DPR: 0.3880
# Epoch 13
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6564 – acc: 61.00% – f1: 62.06% – precision: 64.39% – recall: 59.90% – roc_auc: 61.08%
# Training Fairness Metrics - DPD: 0.3036 – DPR: 0.3872
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6597 acc: 59.41% – f1: 60.29% – precision: 62.97% – recall: 57.83% – roc_auc: 59.52%
# Validation Fairness Metrics - DPD: 0.2995 – DPR: 0.3880
# Epoch 14
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6562 – acc: 60.98% – f1: 61.94% – precision: 64.45% – recall: 59.62% – roc_auc: 61.07%
# Training Fairness Metrics - DPD: 0.3027 – DPR: 0.3856
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6595 acc: 59.56% – f1: 60.34% – precision: 63.18% – recall: 57.74% – roc_auc: 59.68%
# Validation Fairness Metrics - DPD: 0.2990 – DPR: 0.3859
# Epoch 15
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6560 – acc: 60.96% – f1: 61.81% – precision: 64.50% – recall: 59.34% – roc_auc: 61.07%
# Training Fairness Metrics - DPD: 0.3015 – DPR: 0.3846
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6595 acc: 59.80% – f1: 60.52% – precision: 63.48% – recall: 57.83% – roc_auc: 59.94%
# Validation Fairness Metrics - DPD: 0.2965 – DPR: 0.3891
# Epoch 16
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6558 – acc: 60.99% – f1: 61.84% – precision: 64.55% – recall: 59.34% – roc_auc: 61.11%
# Training Fairness Metrics - DPD: 0.2998 – DPR: 0.3875
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6594 acc: 59.85% – f1: 60.48% – precision: 63.60% – recall: 57.65% – roc_auc: 60.01%
# Validation Fairness Metrics - DPD: 0.2951 – DPR: 0.3890
# Epoch 17
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6557 – acc: 61.07% – f1: 61.86% – precision: 64.66% – recall: 59.30% – roc_auc: 61.19%
# Training Fairness Metrics - DPD: 0.2976 – DPR: 0.3906
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6596 acc: 59.90% – f1: 60.43% – precision: 63.72% – recall: 57.46% – roc_auc: 60.07%
# Validation Fairness Metrics - DPD: 0.2946 – DPR: 0.3868
# Epoch 18
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6556 – acc: 61.13% – f1: 61.88% – precision: 64.76% – recall: 59.25% – roc_auc: 61.26%
# Training Fairness Metrics - DPD: 0.2970 – DPR: 0.3905
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6594 acc: 59.80% – f1: 60.29% – precision: 63.65% – recall: 57.28% – roc_auc: 59.98%
# Validation Fairness Metrics - DPD: 0.2936 – DPR: 0.3876
# Epoch 19
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6554 – acc: 61.21% – f1: 61.91% – precision: 64.90% – recall: 59.18% – roc_auc: 61.36%
# Training Fairness Metrics - DPD: 0.2959 – DPR: 0.3907
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6596 acc: 59.80% – f1: 60.06% – precision: 63.82% – recall: 56.72% – roc_auc: 60.02%
# Validation Fairness Metrics - DPD: 0.2908 – DPR: 0.3861
# Epoch 20
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6553 – acc: 61.13% – f1: 61.85% – precision: 64.78% – recall: 59.18% – roc_auc: 61.26%
# Training Fairness Metrics - DPD: 0.2960 – DPR: 0.3916
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6595 acc: 59.90% – f1: 60.12% – precision: 63.95% – recall: 56.72% – roc_auc: 60.12%
# Validation Fairness Metrics - DPD: 0.2898 – DPR: 0.3869
# Fold 3
# Epoch 01
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6837 – acc: 56.60% – f1: 60.41% – precision: 58.73% – recall: 62.19% – roc_auc: 56.21%
# Training Fairness Metrics - DPD: 0.3123 – DPR: 0.4462
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6847 acc: 56.59% – f1: 49.51% – precision: 65.11% – recall: 39.94% – roc_auc: 57.76%
# Validation Fairness Metrics - DPD: 0.3015 – DPR: 0.0776
# Epoch 02
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6718 – acc: 59.02% – f1: 58.63% – precision: 63.39% – recall: 54.54% – roc_auc: 59.33%
# Training Fairness Metrics - DPD: 0.3054 – DPR: 0.3335
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6808 acc: 58.12% – f1: 54.41% – precision: 64.79% – recall: 46.90% – roc_auc: 58.91%
# Validation Fairness Metrics - DPD: 0.2958 – DPR: 0.2330
# Epoch 03
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6688 – acc: 59.30% – f1: 57.83% – precision: 64.51% – recall: 52.41% – roc_auc: 59.78%
# Training Fairness Metrics - DPD: 0.2687 – DPR: 0.3791
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6756 acc: 58.47% – f1: 55.24% – precision: 64.88% – recall: 48.10% – roc_auc: 59.20%
# Validation Fairness Metrics - DPD: 0.2936 – DPR: 0.2569
# Epoch 04
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6657 – acc: 59.49% – f1: 58.32% – precision: 64.49% – recall: 53.22% – roc_auc: 59.92%
# Training Fairness Metrics - DPD: 0.2696 – DPR: 0.3865
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6801 acc: 58.27% – f1: 52.98% – precision: 66.30% – recall: 44.11% – roc_auc: 59.27%
# Validation Fairness Metrics - DPD: 0.2700 – DPR: 0.2385
# Epoch 05
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6643 – acc: 60.02% – f1: 60.64% – precision: 63.73% – recall: 57.83% – roc_auc: 60.17%
# Training Fairness Metrics - DPD: 0.2657 – DPR: 0.4502
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6711 acc: 58.86% – f1: 57.04% – precision: 64.30% – recall: 51.25% – roc_auc: 59.40%
# Validation Fairness Metrics - DPD: 0.2915 – DPR: 0.3136
# Epoch 06
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6633 – acc: 60.03% – f1: 59.85% – precision: 64.35% – recall: 55.93% – roc_auc: 60.31%
# Training Fairness Metrics - DPD: 0.2702 – DPR: 0.4163
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6726 acc: 58.62% – f1: 55.80% – precision: 64.75% – recall: 49.03% – roc_auc: 59.29%
# Validation Fairness Metrics - DPD: 0.2925 – DPR: 0.2751
# Epoch 07
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6623 – acc: 60.05% – f1: 59.51% – precision: 64.65% – recall: 55.12% – roc_auc: 60.40%
# Training Fairness Metrics - DPD: 0.2682 – DPR: 0.4093
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6682 acc: 59.36% – f1: 58.24% – precision: 64.35% – recall: 53.20% – roc_auc: 59.79%
# Validation Fairness Metrics - DPD: 0.2936 – DPR: 0.3336
# Epoch 08
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6615 – acc: 60.00% – f1: 59.42% – precision: 64.63% – recall: 54.98% – roc_auc: 60.35%
# Training Fairness Metrics - DPD: 0.2702 – DPR: 0.4035
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6674 acc: 59.75% – f1: 59.43% – precision: 64.19% – recall: 55.33% – roc_auc: 60.06%
# Validation Fairness Metrics - DPD: 0.3092 – DPR: 0.3268
# Epoch 09
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6612 – acc: 60.41% – f1: 59.87% – precision: 65.05% – recall: 55.45% – roc_auc: 60.76%
# Training Fairness Metrics - DPD: 0.2698 – DPR: 0.4055
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6670 acc: 59.56% – f1: 59.19% – precision: 64.01% – recall: 55.05% – roc_auc: 59.87%
# Validation Fairness Metrics - DPD: 0.3092 – DPR: 0.3252
# Epoch 10
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6604 – acc: 60.34% – f1: 59.75% – precision: 65.00% – recall: 55.29% – roc_auc: 60.69%
# Training Fairness Metrics - DPD: 0.2668 – DPR: 0.4109
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6684 acc: 59.60% – f1: 58.48% – precision: 64.65% – recall: 53.38% – roc_auc: 60.04%
# Validation Fairness Metrics - DPD: 0.2910 – DPR: 0.3387
# Epoch 11
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6552 – acc: 60.96% – f1: 61.36% – precision: 64.87% – recall: 58.21% – roc_auc: 61.15%
# Training Fairness Metrics - DPD: 0.2849 – DPR: 0.4038
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6682 acc: 59.80% – f1: 59.62% – precision: 64.14% – recall: 55.70% – roc_auc: 60.09%
# Validation Fairness Metrics - DPD: 0.2999 – DPR: 0.3518
# Epoch 12
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6540 – acc: 60.93% – f1: 61.28% – precision: 64.88% – recall: 58.07% – roc_auc: 61.13%
# Training Fairness Metrics - DPD: 0.2872 – DPR: 0.3974
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6679 acc: 59.56% – f1: 59.31% – precision: 63.92% – recall: 55.33% – roc_auc: 59.85%
# Validation Fairness Metrics - DPD: 0.2984 – DPR: 0.3529
# Epoch 13
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6535 – acc: 60.92% – f1: 61.15% – precision: 64.96% – recall: 57.77% – roc_auc: 61.14%
# Training Fairness Metrics - DPD: 0.2864 – DPR: 0.3951
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6679 acc: 59.31% – f1: 58.92% – precision: 63.75% – recall: 54.77% – roc_auc: 59.63%
# Validation Fairness Metrics - DPD: 0.2950 – DPR: 0.3556
# Epoch 14
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6531 – acc: 60.91% – f1: 60.98% – precision: 65.08% – recall: 57.37% – roc_auc: 61.15%
# Training Fairness Metrics - DPD: 0.2818 – DPR: 0.3996
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6680 acc: 59.01% – f1: 58.46% – precision: 63.55% – recall: 54.12% – roc_auc: 59.36%
# Validation Fairness Metrics - DPD: 0.2910 – DPR: 0.3587
# Epoch 15
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6528 – acc: 60.94% – f1: 60.97% – precision: 65.16% – recall: 57.28% – roc_auc: 61.20%
# Training Fairness Metrics - DPD: 0.2790 – DPR: 0.4041
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6683 acc: 59.26% – f1: 58.65% – precision: 63.86% – recall: 54.22% – roc_auc: 59.61%
# Validation Fairness Metrics - DPD: 0.2896 – DPR: 0.3599
# Epoch 16
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6525 – acc: 61.03% – f1: 61.03% – precision: 65.28% – recall: 57.30% – roc_auc: 61.29%
# Training Fairness Metrics - DPD: 0.2758 – DPR: 0.4100
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6681 acc: 59.36% – f1: 58.91% – precision: 63.85% – recall: 54.68% – roc_auc: 59.69%
# Validation Fairness Metrics - DPD: 0.2872 – DPR: 0.3707
# Epoch 17
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6523 – acc: 61.14% – f1: 61.15% – precision: 65.39% – recall: 57.42% – roc_auc: 61.40%
# Training Fairness Metrics - DPD: 0.2741 – DPR: 0.4137
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6683 acc: 59.26% – f1: 58.73% – precision: 63.80% – recall: 54.40% – roc_auc: 59.60%
# Validation Fairness Metrics - DPD: 0.2852 – DPR: 0.3723
# Epoch 18
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6521 – acc: 61.17% – f1: 61.08% – precision: 65.49% – recall: 57.23% – roc_auc: 61.44%
# Training Fairness Metrics - DPD: 0.2719 – DPR: 0.4157
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6685 acc: 59.31% – f1: 58.80% – precision: 63.84% – recall: 54.49% – roc_auc: 59.65%
# Validation Fairness Metrics - DPD: 0.2846 – DPR: 0.3742
# Epoch 19
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6520 – acc: 61.12% – f1: 61.04% – precision: 65.43% – recall: 57.21% – roc_auc: 61.39%
# Training Fairness Metrics - DPD: 0.2689 – DPR: 0.4226
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6686 acc: 59.41% – f1: 58.78% – precision: 64.04% – recall: 54.31% – roc_auc: 59.77%
# Validation Fairness Metrics - DPD: 0.2806 – DPR: 0.3790
# Epoch 20
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6517 – acc: 61.17% – f1: 61.05% – precision: 65.52% – recall: 57.14% – roc_auc: 61.45%
# Training Fairness Metrics - DPD: 0.2669 – DPR: 0.4253
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6688 acc: 59.46% – f1: 58.76% – precision: 64.14% – recall: 54.22% – roc_auc: 59.83%
# Validation Fairness Metrics - DPD: 0.2791 – DPR: 0.3802
# Fold 4
# Epoch 01
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6888 – acc: 56.24% – f1: 62.99% – precision: 57.31% – recall: 69.92% – roc_auc: 55.28%
# Training Fairness Metrics - DPD: 0.2289 – DPR: 0.6477
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6738 acc: 59.41% – f1: 64.14% – precision: 60.54% – recall: 68.18% – roc_auc: 58.80%
# Validation Fairness Metrics - DPD: 0.4101 – DPR: 0.3159
# Epoch 02
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6728 – acc: 58.66% – f1: 58.75% – precision: 62.70% – recall: 55.27% – roc_auc: 58.90%
# Training Fairness Metrics - DPD: 0.3342 – DPR: 0.2882
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6660 acc: 60.00% – f1: 61.79% – precision: 62.86% – recall: 60.76% – roc_auc: 59.95%
# Validation Fairness Metrics - DPD: 0.3723 – DPR: 0.2765
# Epoch 03
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6675 – acc: 59.60% – f1: 61.16% – precision: 62.67% – recall: 59.72% – roc_auc: 59.59%
# Training Fairness Metrics - DPD: 0.3028 – DPR: 0.4034
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6656 acc: 60.00% – f1: 61.72% – precision: 62.91% – recall: 60.58% – roc_auc: 59.96%
# Validation Fairness Metrics - DPD: 0.3202 – DPR: 0.3753
# Epoch 04
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6651 – acc: 59.92% – f1: 60.79% – precision: 63.46% – recall: 58.33% – roc_auc: 60.03%
# Training Fairness Metrics - DPD: 0.2799 – DPR: 0.4283
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6646 acc: 59.80% – f1: 59.30% – precision: 64.32% – recall: 55.01% – roc_auc: 60.13%
# Validation Fairness Metrics - DPD: 0.3070 – DPR: 0.3257
# Epoch 05
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6640 – acc: 59.87% – f1: 60.21% – precision: 63.80% – recall: 57.01% – roc_auc: 60.07%
# Training Fairness Metrics - DPD: 0.2650 – DPR: 0.4432
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6671 acc: 60.44% – f1: 58.56% – precision: 66.20% – recall: 52.50% – roc_auc: 60.99%
# Validation Fairness Metrics - DPD: 0.2920 – DPR: 0.3085
# Epoch 06
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6629 – acc: 60.03% – f1: 61.01% – precision: 63.50% – recall: 58.70% – roc_auc: 60.12%
# Training Fairness Metrics - DPD: 0.2714 – DPR: 0.4488
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6677 acc: 60.54% – f1: 58.41% – precision: 66.55% – recall: 52.04% – roc_auc: 61.13%
# Validation Fairness Metrics - DPD: 0.2890 – DPR: 0.3057
# Epoch 07
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6622 – acc: 60.17% – f1: 60.82% – precision: 63.87% – recall: 58.05% – roc_auc: 60.31%
# Training Fairness Metrics - DPD: 0.2673 – DPR: 0.4480
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6653 acc: 60.59% – f1: 58.82% – precision: 66.28% – recall: 52.88% – roc_auc: 61.13%
# Validation Fairness Metrics - DPD: 0.2914 – DPR: 0.3138
# Epoch 08
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6618 – acc: 59.89% – f1: 60.29% – precision: 63.79% – recall: 57.15% – roc_auc: 60.09%
# Training Fairness Metrics - DPD: 0.2676 – DPR: 0.4394
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6634 acc: 60.35% – f1: 59.59% – precision: 65.13% – recall: 54.92% – roc_auc: 60.72%
# Validation Fairness Metrics - DPD: 0.3016 – DPR: 0.3281
# Epoch 09
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6610 – acc: 60.15% – f1: 61.04% – precision: 63.69% – recall: 58.61% – roc_auc: 60.26%
# Training Fairness Metrics - DPD: 0.2746 – DPR: 0.4398
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6669 acc: 60.20% – f1: 57.58% – precision: 66.55% – recall: 50.74% – roc_auc: 60.85%
# Validation Fairness Metrics - DPD: 0.2857 – DPR: 0.2962
# Epoch 10
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6614 – acc: 59.93% – f1: 60.38% – precision: 63.79% – recall: 57.31% – roc_auc: 60.11%
# Training Fairness Metrics - DPD: 0.2759 – DPR: 0.4236
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6642 acc: 60.35% – f1: 59.59% – precision: 65.13% – recall: 54.92% – roc_auc: 60.72%
# Validation Fairness Metrics - DPD: 0.3046 – DPR: 0.3214
# Epoch 11
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6583 – acc: 60.88% – f1: 62.40% – precision: 63.93% – recall: 60.95% – roc_auc: 60.88%
# Training Fairness Metrics - DPD: 0.2915 – DPR: 0.4260
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6603 acc: 60.10% – f1: 61.71% – precision: 63.08% – recall: 60.39% – roc_auc: 60.08%
# Validation Fairness Metrics - DPD: 0.3102 – DPR: 0.3913
# Epoch 12
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6571 – acc: 60.82% – f1: 62.77% – precision: 63.55% – recall: 62.02% – roc_auc: 60.74%
# Training Fairness Metrics - DPD: 0.2901 – DPR: 0.4420
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6602 acc: 59.95% – f1: 61.62% – precision: 62.90% – recall: 60.39% – roc_auc: 59.92%
# Validation Fairness Metrics - DPD: 0.3047 – DPR: 0.4039
# Epoch 13
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6569 – acc: 60.83% – f1: 62.70% – precision: 63.62% – recall: 61.81% – roc_auc: 60.76%
# Training Fairness Metrics - DPD: 0.2870 – DPR: 0.4455
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6603 acc: 59.95% – f1: 61.47% – precision: 63.00% – recall: 60.02% – roc_auc: 59.95%
# Validation Fairness Metrics - DPD: 0.3017 – DPR: 0.4050
# Epoch 14
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6567 – acc: 60.94% – f1: 62.77% – precision: 63.76% – recall: 61.81% – roc_auc: 60.88%
# Training Fairness Metrics - DPD: 0.2848 – DPR: 0.4484
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6604 acc: 59.90% – f1: 61.33% – precision: 63.01% – recall: 59.74% – roc_auc: 59.91%
# Validation Fairness Metrics - DPD: 0.2993 – DPR: 0.4070
# Epoch 15
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6566 – acc: 60.97% – f1: 62.75% – precision: 63.82% – recall: 61.71% – roc_auc: 60.92%
# Training Fairness Metrics - DPD: 0.2838 – DPR: 0.4490
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6602 acc: 59.80% – f1: 61.35% – precision: 62.84% – recall: 59.93% – roc_auc: 59.79%
# Validation Fairness Metrics - DPD: 0.2982 – DPR: 0.4125
# Epoch 16
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6564 – acc: 61.02% – f1: 62.73% – precision: 63.91% – recall: 61.60% – roc_auc: 60.98%
# Training Fairness Metrics - DPD: 0.2821 – DPR: 0.4505
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6606 acc: 60.00% – f1: 61.28% – precision: 63.21% – recall: 59.46% – roc_auc: 60.04%
# Validation Fairness Metrics - DPD: 0.2973 – DPR: 0.4062
# Epoch 17
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6564 – acc: 61.08% – f1: 62.79% – precision: 63.97% – recall: 61.65% – roc_auc: 61.04%
# Training Fairness Metrics - DPD: 0.2812 – DPR: 0.4521
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6599 acc: 59.90% – f1: 61.52% – precision: 62.89% – recall: 60.20% – roc_auc: 59.88%
# Validation Fairness Metrics - DPD: 0.2952 – DPR: 0.4208
# Epoch 18
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6563 – acc: 61.17% – f1: 62.87% – precision: 64.05% – recall: 61.74% – roc_auc: 61.13%
# Training Fairness Metrics - DPD: 0.2813 – DPR: 0.4520
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6599 acc: 59.85% – f1: 61.41% – precision: 62.88% – recall: 60.02% – roc_auc: 59.84%
# Validation Fairness Metrics - DPD: 0.2937 – DPR: 0.4220
# Epoch 19
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6561 – acc: 61.12% – f1: 62.79% – precision: 64.03% – recall: 61.60% – roc_auc: 61.08%
# Training Fairness Metrics - DPD: 0.2791 – DPR: 0.4554
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6599 acc: 59.80% – f1: 61.39% – precision: 62.82% – recall: 60.02% – roc_auc: 59.79%
# Validation Fairness Metrics - DPD: 0.2932 – DPR: 0.4235
# Epoch 20
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6560 – acc: 61.08% – f1: 62.71% – precision: 64.03% – recall: 61.44% – roc_auc: 61.05%
# Training Fairness Metrics - DPD: 0.2780 – DPR: 0.4561
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6599 acc: 59.75% – f1: 61.36% – precision: 62.75% – recall: 60.02% – roc_auc: 59.73%
# Validation Fairness Metrics - DPD: 0.2907 – DPR: 0.4290
# Fold 5
# Epoch 01
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6842 – acc: 56.81% – f1: 58.64% – precision: 59.85% – recall: 57.47% – roc_auc: 56.76%
# Training Fairness Metrics - DPD: 0.3176 – DPR: 0.3792
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6675 acc: 59.01% – f1: 57.57% – precision: 64.12% – recall: 52.23% – roc_auc: 59.48%
# Validation Fairness Metrics - DPD: 0.4014 – DPR: 0.0743
# Epoch 02
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6750 – acc: 58.88% – f1: 58.90% – precision: 62.98% – recall: 55.32% – roc_auc: 59.13%
# Training Fairness Metrics - DPD: 0.3309 – DPR: 0.2927
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6696 acc: 58.32% – f1: 52.37% – precision: 66.86% – recall: 43.04% – roc_auc: 59.38%
# Validation Fairness Metrics - DPD: 0.2974 – DPR: 0.1322
# Epoch 03
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6715 – acc: 59.38% – f1: 59.38% – precision: 63.52% – recall: 55.74% – roc_auc: 59.63%
# Training Fairness Metrics - DPD: 0.3129 – DPR: 0.3304
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6595 acc: 59.65% – f1: 56.80% – precision: 66.05% – recall: 49.81% – roc_auc: 60.33%
# Validation Fairness Metrics - DPD: 0.2907 – DPR: 0.2759
# Epoch 04
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6694 – acc: 59.93% – f1: 60.07% – precision: 64.01% – recall: 56.59% – roc_auc: 60.16%
# Training Fairness Metrics - DPD: 0.3196 – DPR: 0.3214
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6554 acc: 60.49% – f1: 61.43% – precision: 63.96% – recall: 59.09% – roc_auc: 60.59%
# Validation Fairness Metrics - DPD: 0.3307 – DPR: 0.3276
# Epoch 05
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6675 – acc: 59.72% – f1: 59.37% – precision: 64.16% – recall: 55.25% – roc_auc: 60.03%
# Training Fairness Metrics - DPD: 0.3094 – DPR: 0.3254
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6524 acc: 61.33% – f1: 61.06% – precision: 65.81% – recall: 56.96% – roc_auc: 61.64%
# Validation Fairness Metrics - DPD: 0.3198 – DPR: 0.3060
# Epoch 06
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6670 – acc: 59.76% – f1: 59.20% – precision: 64.35% – recall: 54.81% – roc_auc: 60.10%
# Training Fairness Metrics - DPD: 0.2949 – DPR: 0.3500
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6507 acc: 61.09% – f1: 62.76% – precision: 63.97% – recall: 61.60% – roc_auc: 61.05%
# Validation Fairness Metrics - DPD: 0.3142 – DPR: 0.3870
# Epoch 07
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6658 – acc: 59.63% – f1: 58.31% – precision: 64.81% – recall: 53.00% – roc_auc: 60.10%
# Training Fairness Metrics - DPD: 0.2941 – DPR: 0.3250
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6498 acc: 61.28% – f1: 63.05% – precision: 64.08% – recall: 62.06% – roc_auc: 61.23%
# Validation Fairness Metrics - DPD: 0.3172 – DPR: 0.3848
# Epoch 08
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6645 – acc: 59.78% – f1: 58.49% – precision: 64.96% – recall: 53.19% – roc_auc: 60.24%
# Training Fairness Metrics - DPD: 0.2956 – DPR: 0.3223
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6494 acc: 61.53% – f1: 61.98% – precision: 65.40% – recall: 58.91% – roc_auc: 61.71%
# Validation Fairness Metrics - DPD: 0.3043 – DPR: 0.3654
# Epoch 09
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6640 – acc: 59.89% – f1: 58.96% – precision: 64.80% – recall: 54.09% – roc_auc: 60.30%
# Training Fairness Metrics - DPD: 0.2956 – DPR: 0.3352
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6491 acc: 61.28% – f1: 62.49% – precision: 64.53% – recall: 60.58% – roc_auc: 61.33%
# Validation Fairness Metrics - DPD: 0.3114 – DPR: 0.3768
# Epoch 10
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6638 – acc: 60.12% – f1: 59.12% – precision: 65.11% – recall: 54.14% – roc_auc: 60.53%
# Training Fairness Metrics - DPD: 0.2954 – DPR: 0.3330
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6496 acc: 61.14% – f1: 62.43% – precision: 64.31% – recall: 60.67% – roc_auc: 61.17%
# Validation Fairness Metrics - DPD: 0.3099 – DPR: 0.3830
# Epoch 11
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6593 – acc: 60.14% – f1: 60.30% – precision: 64.22% – recall: 56.83% – roc_auc: 60.37%
# Training Fairness Metrics - DPD: 0.3192 – DPR: 0.3227
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6482 acc: 61.04% – f1: 61.83% – precision: 64.61% – recall: 59.28% – roc_auc: 61.16%
# Validation Fairness Metrics - DPD: 0.3122 – DPR: 0.3608
# Epoch 12
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6585 – acc: 60.36% – f1: 60.21% – precision: 64.70% – recall: 56.29% – roc_auc: 60.65%
# Training Fairness Metrics - DPD: 0.3211 – DPR: 0.3072
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6482 acc: 60.64% – f1: 61.52% – precision: 64.15% – recall: 59.09% – roc_auc: 60.75%
# Validation Fairness Metrics - DPD: 0.3111 – DPR: 0.3655
# Epoch 13
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6580 – acc: 60.39% – f1: 60.38% – precision: 64.61% – recall: 56.66% – roc_auc: 60.65%
# Training Fairness Metrics - DPD: 0.3209 – DPR: 0.3130
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6483 acc: 60.74% – f1: 61.61% – precision: 64.25% – recall: 59.18% – roc_auc: 60.85%
# Validation Fairness Metrics - DPD: 0.3081 – DPR: 0.3717
# Epoch 14
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6577 – acc: 60.52% – f1: 60.59% – precision: 64.70% – recall: 56.96% – roc_auc: 60.77%
# Training Fairness Metrics - DPD: 0.3186 – DPR: 0.3205
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6482 acc: 60.69% – f1: 61.58% – precision: 64.19% – recall: 59.18% – roc_auc: 60.80%
# Validation Fairness Metrics - DPD: 0.3056 – DPR: 0.3775
# Epoch 15
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6574 – acc: 60.50% – f1: 60.52% – precision: 64.71% – recall: 56.85% – roc_auc: 60.75%
# Training Fairness Metrics - DPD: 0.3159 – DPR: 0.3250
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6483 acc: 60.74% – f1: 61.50% – precision: 64.34% – recall: 58.91% – roc_auc: 60.87%
# Validation Fairness Metrics - DPD: 0.3021 – DPR: 0.3802
# Epoch 16
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6572 – acc: 60.54% – f1: 60.57% – precision: 64.73% – recall: 56.92% – roc_auc: 60.79%
# Training Fairness Metrics - DPD: 0.3126 – DPR: 0.3325
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6483 acc: 60.64% – f1: 61.40% – precision: 64.24% – recall: 58.81% – roc_auc: 60.77%
# Validation Fairness Metrics - DPD: 0.3001 – DPR: 0.3843
# Epoch 17
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6569 – acc: 60.49% – f1: 60.59% – precision: 64.63% – recall: 57.03% – roc_auc: 60.73%
# Training Fairness Metrics - DPD: 0.3105 – DPR: 0.3394
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6481 acc: 60.79% – f1: 61.57% – precision: 64.37% – recall: 59.00% – roc_auc: 60.91%
# Validation Fairness Metrics - DPD: 0.2976 – DPR: 0.3901
# Epoch 18
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6567 – acc: 60.47% – f1: 60.60% – precision: 64.60% – recall: 57.06% – roc_auc: 60.71%
# Training Fairness Metrics - DPD: 0.3065 – DPR: 0.3485
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6480 acc: 60.89% – f1: 61.74% – precision: 64.42% – recall: 59.28% – roc_auc: 61.00%
# Validation Fairness Metrics - DPD: 0.2955 – DPR: 0.3968
# Epoch 19
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6566 – acc: 60.56% – f1: 60.80% – precision: 64.60% – recall: 57.43% – roc_auc: 60.78%
# Training Fairness Metrics - DPD: 0.3047 – DPR: 0.3565
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6480 acc: 60.94% – f1: 61.88% – precision: 64.39% – recall: 59.55% – roc_auc: 61.03%
# Validation Fairness Metrics - DPD: 0.2919 – DPR: 0.4070
# Epoch 20
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6564 – acc: 60.67% – f1: 61.05% – precision: 64.61% – recall: 57.87% – roc_auc: 60.87%
# Training Fairness Metrics - DPD: 0.3016 – DPR: 0.3678
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6478 acc: 61.19% – f1: 62.21% – precision: 64.57% – recall: 60.02% – roc_auc: 61.27%
# Validation Fairness Metrics - DPD: 0.2894 – DPR: 0.4152
# FINAL RESULTS ACROSS ALL FOLDS:
# Accuracy:  59.9447479068407 ± 0.6454485411975632
# F1-Score:  60.749876919454266 ± 1.195604338218914
# Precision:  63.54333925618548 ± 0.8670698376613374
# Recall:  58.26135998253037 ± 2.416858816328743
# ROC-AUC:  60.06298876203569 ± 0.648581404990561
# FINAL FAIRNESS RESULTS ACROSS ALL FOLDS:
# Demographic Parity Difference:  0.2878575881219738 ± 0.004390837769274967
# Demographic Parity Ratio:  0.40968923751916864 ± 0.02256530782417746

# %%
final_df = pd.read_csv('preprocessed_df.csv', index_col=0)

# %%
final_df.head()
# Out:
#                   s_frequency_of_work_with_teachers  \
# id_questionnaire
# 20431                                      0.700000
# 20432                                      0.777778
# 20433                                      0.733333
# 20434                                      0.633333
# 20435                                      0.666667
#
#                   s_frequency_of_evaluations  s_frequency_of_internet_usage  \
# id_questionnaire
# 20431                               0.629630                       0.666667
# 20432                               0.814815                       0.266667
# 20433                               0.703704                       0.400000
# 20434                               0.629630                       0.266667
# 20435                               0.629630                       0.266667
#
#                   s_extent_of_class_env  s_frequency_of_materials_in_class  \
# id_questionnaire
# 20431                          0.583333                           0.666667
# 20432                          0.875000                           0.476190
# 20433                          0.916667                           0.476190
# 20434                          0.750000                           0.476190
# 20435                          0.666667                           0.523810
#
#                   s_extent_of_teacher_performance  \
# id_questionnaire
# 20431                                    0.700000
# 20432                                    0.900000
# 20433                                    1.000000
# 20434                                    0.766667
# 20435                                    0.833333
#
#                   s_extent_of_classmates_affinity  f_ESCS  \
# id_questionnaire
# 20431                                    0.761905       1
# 20432                                    0.761905       0
# 20433                                    1.000000       1
# 20434                                    0.904762       0
# 20435                                    0.809524       1
#
#                   s_extent_of_school_satisfaction  \
# id_questionnaire
# 20431                                    0.722222
# 20432                                    0.666667
# 20433                                    1.000000
# 20434                                    0.722222
# 20435                                    0.888889
#
#                   s_frequency_of_computer_usage  ...  \
# id_questionnaire                                 ...
# 20431                                  0.444444  ...
# 20432                                  0.222222  ...
# 20433                                  0.444444  ...
# 20434                                  0.666667  ...
# 20435                                  0.111111  ...
#
#                   p_number_of_teachers_in_school  \
# id_questionnaire
# 20431                                       41.0
# 20432                                       41.0
# 20433                                       29.0
# 20434                                        5.0
# 20435                                       57.0
#
#                   p_number_of_years_of_teaching  p_age  \
# id_questionnaire
# 20431                                      30.0   59.0
# 20432                                      23.0   50.0
# 20433                                      26.0   55.0
# 20434                                      20.0   57.0
# 20435                                      26.0   55.0
#
#                   p_number_of_years_in_school  p_number_of_years_as_principal  \
# id_questionnaire
# 20431                                    25.0                            16.0
# 20432                                    17.0                             9.0
# 20433                                    13.0                             3.0
# 20434                                     1.0                             2.0
# 20435                                     4.0                            14.0
#
#                   f_mother_education_level  f_frequency_of_see_adult_read  \
# id_questionnaire
# 20431                                  4.0                          0.500
# 20432                                  3.0                          0.125
# 20433                                  3.0                          1.000
# 20434                                  3.0                          0.250
# 20435                                  6.0                          0.125
#
#                   p_number_of_years_as_principal_in_school  \
# id_questionnaire
# 20431                                                 16.0
# 20432                                                  9.0
# 20433                                                  3.0
# 20434                                                  1.0
# 20435                                                  2.0
#
#                   p_extent_of_factors_limiting_effectiveness  level_MAT
# id_questionnaire
# 20431                                               0.291667          1
# 20432                                               0.375000          1
# 20433                                               0.291667          1
# 20434                                               0.625000          0
# 20435                                               0.500000          1
#
# [5 rows x 32 columns]

# %% [markdown]
# ### Pre-Processing Mitigation

# %% [markdown]
# #### Reweighing

# %%
# X_inverted = X.copy()
# X_inverted[SENSITIVE] = 1 - X_inverted[SENSITIVE]

# Y_inverted = Y.copy()
# Y_inverted = 1 - Y_inverted

# %%
rw_res, rew_fair_res = kfold_cross_validation(5, X, Y, sensitive_feature=SENSITIVE, preprocessing='reweighing')
# Out:
# Fold 1
# f_ESCS
# Epoch 01
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6940 – acc: 53.26% – f1: 69.50% – precision: 53.26% – recall: 100.00% – roc_auc: 50.00%
# Training Fairness Metrics - DPD: 0.0000 – DPR: 1.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6891 acc: 53.26% – f1: 69.50% – precision: 53.26% – recall: 100.00% – roc_auc: 50.00%
# Validation Fairness Metrics - DPD: 0.0000 – DPR: 1.0000
# Epoch 02
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6896 – acc: 54.98% – f1: 67.77% – precision: 54.76% – recall: 88.90% – roc_auc: 52.61%
# Training Fairness Metrics - DPD: 0.0405 – DPR: 0.9531
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6800 acc: 57.75% – f1: 59.77% – precision: 60.63% – recall: 58.94% – roc_auc: 57.67%
# Validation Fairness Metrics - DPD: 0.0647 – DPR: 0.8750
# Epoch 03
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6811 – acc: 57.20% – f1: 64.68% – precision: 57.70% – recall: 73.60% – roc_auc: 56.05%
# Training Fairness Metrics - DPD: 0.0160 – DPR: 0.9764
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6745 acc: 58.98% – f1: 66.32% – precision: 58.93% – recall: 75.81% – roc_auc: 57.81%
# Validation Fairness Metrics - DPD: 0.0101 – DPR: 0.9855
# Epoch 04
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6777 – acc: 57.65% – f1: 64.40% – precision: 58.31% – recall: 71.91% – roc_auc: 56.66%
# Training Fairness Metrics - DPD: 0.0049 – DPR: 0.9926
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6748 acc: 57.45% – f1: 60.53% – precision: 59.82% – recall: 61.26% – roc_auc: 57.19%
# Validation Fairness Metrics - DPD: 0.0350 – DPR: 0.9398
# Epoch 05
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6759 – acc: 57.90% – f1: 64.08% – precision: 58.73% – recall: 70.51% – roc_auc: 57.02%
# Training Fairness Metrics - DPD: 0.0152 – DPR: 0.9768
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6740 acc: 58.49% – f1: 64.47% – precision: 59.24% – recall: 70.71% – roc_auc: 57.64%
# Validation Fairness Metrics - DPD: 0.0386 – DPR: 0.9428
# Epoch 06
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6757 – acc: 58.21% – f1: 64.07% – precision: 59.10% – recall: 69.96% – roc_auc: 57.39%
# Training Fairness Metrics - DPD: 0.0089 – DPR: 0.9860
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6741 acc: 58.14% – f1: 63.26% – precision: 59.40% – recall: 67.66% – roc_auc: 57.48%
# Validation Fairness Metrics - DPD: 0.0291 – DPR: 0.9542
# Epoch 07
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6750 – acc: 58.47% – f1: 64.77% – precision: 59.08% – recall: 71.67% – roc_auc: 57.55%
# Training Fairness Metrics - DPD: 0.0001 – DPR: 0.9998
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6735 acc: 57.95% – f1: 62.40% – precision: 59.56% – recall: 65.52% – roc_auc: 57.42%
# Validation Fairness Metrics - DPD: 0.0164 – DPR: 0.9727
# Epoch 08
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6747 – acc: 58.63% – f1: 64.76% – precision: 59.27% – recall: 71.37% – roc_auc: 57.74%
# Training Fairness Metrics - DPD: 0.0039 – DPR: 0.9939
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6727 acc: 58.00% – f1: 62.85% – precision: 59.41% – recall: 66.73% – roc_auc: 57.39%
# Validation Fairness Metrics - DPD: 0.0281 – DPR: 0.9552
# Epoch 09
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6742 – acc: 58.37% – f1: 64.95% – precision: 58.88% – recall: 72.42% – roc_auc: 57.39%
# Training Fairness Metrics - DPD: 0.0063 – DPR: 0.9905
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6730 acc: 58.93% – f1: 64.47% – precision: 59.78% – recall: 69.97% – roc_auc: 58.16%
# Validation Fairness Metrics - DPD: 0.0238 – DPR: 0.9632
# Epoch 10
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6740 – acc: 58.46% – f1: 65.16% – precision: 58.88% – recall: 72.95% – roc_auc: 57.45%
# Training Fairness Metrics - DPD: 0.0098 – DPR: 0.9853
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6734 acc: 58.84% – f1: 65.02% – precision: 59.39% – recall: 71.83% – roc_auc: 57.93%
# Validation Fairness Metrics - DPD: 0.0354 – DPR: 0.9479
# Epoch 11
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6700 – acc: 58.95% – f1: 66.12% – precision: 58.99% – recall: 75.20% – roc_auc: 57.82%
# Training Fairness Metrics - DPD: 0.0168 – DPR: 0.9758
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6730 acc: 58.29% – f1: 66.19% – precision: 58.24% – recall: 76.65% – roc_auc: 57.01%
# Validation Fairness Metrics - DPD: 0.0298 – DPR: 0.9592
# Epoch 12
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6696 – acc: 59.00% – f1: 66.18% – precision: 59.02% – recall: 75.34% – roc_auc: 57.86%
# Training Fairness Metrics - DPD: 0.0128 – DPR: 0.9816
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6726 acc: 58.59% – f1: 66.48% – precision: 58.43% – recall: 77.11% – roc_auc: 57.30%
# Validation Fairness Metrics - DPD: 0.0237 – DPR: 0.9674
# Epoch 13
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6693 – acc: 59.12% – f1: 66.20% – precision: 59.15% – recall: 75.17% – roc_auc: 58.00%
# Training Fairness Metrics - DPD: 0.0096 – DPR: 0.9860
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6724 acc: 58.74% – f1: 66.53% – precision: 58.56% – recall: 77.02% – roc_auc: 57.46%
# Validation Fairness Metrics - DPD: 0.0219 – DPR: 0.9696
# Epoch 14
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6691 – acc: 59.30% – f1: 66.28% – precision: 59.30% – recall: 75.13% – roc_auc: 58.19%
# Training Fairness Metrics - DPD: 0.0062 – DPR: 0.9908
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6721 acc: 58.74% – f1: 66.59% – precision: 58.54% – recall: 77.20% – roc_auc: 57.45%
# Validation Fairness Metrics - DPD: 0.0200 – DPR: 0.9724
# Epoch 15
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6690 – acc: 59.26% – f1: 66.21% – precision: 59.30% – recall: 74.94% – roc_auc: 58.17%
# Training Fairness Metrics - DPD: 0.0050 – DPR: 0.9926
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6719 acc: 58.74% – f1: 66.53% – precision: 58.56% – recall: 77.02% – roc_auc: 57.46%
# Validation Fairness Metrics - DPD: 0.0178 – DPR: 0.9753
# Epoch 16
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6689 – acc: 59.33% – f1: 66.17% – precision: 59.40% – recall: 74.69% – roc_auc: 58.26%
# Training Fairness Metrics - DPD: 0.0024 – DPR: 0.9965
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6717 acc: 58.79% – f1: 66.56% – precision: 58.60% – recall: 77.02% – roc_auc: 57.52%
# Validation Fairness Metrics - DPD: 0.0151 – DPR: 0.9788
# Epoch 17
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6688 – acc: 59.35% – f1: 66.16% – precision: 59.42% – recall: 74.62% – roc_auc: 58.28%
# Training Fairness Metrics - DPD: 0.0004 – DPR: 0.9993
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6716 acc: 58.44% – f1: 66.29% – precision: 58.35% – recall: 76.74% – roc_auc: 57.17%
# Validation Fairness Metrics - DPD: 0.0125 – DPR: 0.9824
# Epoch 18
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6688 – acc: 59.38% – f1: 66.18% – precision: 59.46% – recall: 74.62% – roc_auc: 58.32%
# Training Fairness Metrics - DPD: 0.0002 – DPR: 0.9997
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6715 acc: 58.29% – f1: 66.13% – precision: 58.26% – recall: 76.46% – roc_auc: 57.03%
# Validation Fairness Metrics - DPD: 0.0119 – DPR: 0.9832
# Epoch 19
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6687 – acc: 59.43% – f1: 66.17% – precision: 59.52% – recall: 74.48% – roc_auc: 58.38%
# Training Fairness Metrics - DPD: 0.0002 – DPR: 0.9996
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6714 acc: 58.14% – f1: 66.00% – precision: 58.16% – recall: 76.27% – roc_auc: 56.88%
# Validation Fairness Metrics - DPD: 0.0124 – DPR: 0.9825
# Epoch 20
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6686 – acc: 59.44% – f1: 66.12% – precision: 59.56% – recall: 74.29% – roc_auc: 58.41%
# Training Fairness Metrics - DPD: 0.0006 – DPR: 0.9992
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6713 acc: 58.54% – f1: 65.99% – precision: 58.59% – recall: 75.53% – roc_auc: 57.35%
# Validation Fairness Metrics - DPD: 0.0180 – DPR: 0.9744
# Fold 2
# f_ESCS
# Epoch 01
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6893 – acc: 55.12% – f1: 66.41% – precision: 55.21% – recall: 83.31% – roc_auc: 53.15%
# Training Fairness Metrics - DPD: 0.0100 – DPR: 0.9875
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6730 acc: 57.78% – f1: 61.68% – precision: 59.72% – recall: 63.76% – roc_auc: 57.36%
# Validation Fairness Metrics - DPD: 0.0214 – DPR: 0.9624
# Epoch 02
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6813 – acc: 56.91% – f1: 61.65% – precision: 58.59% – recall: 65.04% – roc_auc: 56.34%
# Training Fairness Metrics - DPD: 0.0217 – DPR: 0.9646
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6739 acc: 57.83% – f1: 60.65% – precision: 60.31% – recall: 60.98% – roc_auc: 57.61%
# Validation Fairness Metrics - DPD: 0.0047 – DPR: 0.9914
# Epoch 03
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6800 – acc: 57.12% – f1: 62.12% – precision: 58.65% – recall: 66.02% – roc_auc: 56.50%
# Training Fairness Metrics - DPD: 0.0244 – DPR: 0.9608
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6724 acc: 58.32% – f1: 62.08% – precision: 60.24% – recall: 64.04% – roc_auc: 57.92%
# Validation Fairness Metrics - DPD: 0.0088 – DPR: 0.9844
# Epoch 04
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6768 – acc: 57.70% – f1: 64.28% – precision: 58.40% – recall: 71.49% – roc_auc: 56.74%
# Training Fairness Metrics - DPD: 0.0262 – DPR: 0.9614
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6731 acc: 57.19% – f1: 65.03% – precision: 57.57% – recall: 74.70% – roc_auc: 55.95%
# Validation Fairness Metrics - DPD: 0.0359 – DPR: 0.9503
# Epoch 05
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6759 – acc: 57.76% – f1: 64.49% – precision: 58.38% – recall: 72.04% – roc_auc: 56.76%
# Training Fairness Metrics - DPD: 0.0404 – DPR: 0.9421
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6765 acc: 57.58% – f1: 62.01% – precision: 59.31% – recall: 64.97% – roc_auc: 57.06%
# Validation Fairness Metrics - DPD: 0.0476 – DPR: 0.9220
# Epoch 06
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6756 – acc: 58.14% – f1: 64.53% – precision: 58.80% – recall: 71.49% – roc_auc: 57.21%
# Training Fairness Metrics - DPD: 0.0267 – DPR: 0.9603
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6712 acc: 57.78% – f1: 64.89% – precision: 58.26% – recall: 73.22% – roc_auc: 56.69%
# Validation Fairness Metrics - DPD: 0.0051 – DPR: 0.9924
# Epoch 07
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6740 – acc: 58.26% – f1: 65.06% – precision: 58.70% – recall: 72.97% – roc_auc: 57.24%
# Training Fairness Metrics - DPD: 0.0273 – DPR: 0.9604
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6714 acc: 57.38% – f1: 65.74% – precision: 57.50% – recall: 76.74% – roc_auc: 56.02%
# Validation Fairness Metrics - DPD: 0.0061 – DPR: 0.9915
# Epoch 08
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6738 – acc: 58.46% – f1: 64.64% – precision: 59.12% – recall: 71.30% – roc_auc: 57.57%
# Training Fairness Metrics - DPD: 0.0199 – DPR: 0.9700
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6718 acc: 57.48% – f1: 65.27% – precision: 57.79% – recall: 74.98% – roc_auc: 56.25%
# Validation Fairness Metrics - DPD: 0.0117 – DPR: 0.9834
# Epoch 09
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6735 – acc: 58.42% – f1: 65.21% – precision: 58.81% – recall: 73.16% – roc_auc: 57.40%
# Training Fairness Metrics - DPD: 0.0223 – DPR: 0.9674
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6719 acc: 57.58% – f1: 65.24% – precision: 57.90% – recall: 74.70% – roc_auc: 56.38%
# Validation Fairness Metrics - DPD: 0.0126 – DPR: 0.9820
# Epoch 10
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6732 – acc: 59.01% – f1: 64.94% – precision: 59.62% – recall: 71.30% – roc_auc: 58.15%
# Training Fairness Metrics - DPD: 0.0037 – DPR: 0.9942
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6711 acc: 58.47% – f1: 63.73% – precision: 59.60% – recall: 68.49% – roc_auc: 57.76%
# Validation Fairness Metrics - DPD: 0.0103 – DPR: 0.9831
# Epoch 11
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6693 – acc: 59.05% – f1: 65.33% – precision: 59.49% – recall: 72.44% – roc_auc: 58.12%
# Training Fairness Metrics - DPD: 0.0016 – DPR: 0.9975
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6702 acc: 57.73% – f1: 65.48% – precision: 57.96% – recall: 75.25% – roc_auc: 56.50%
# Validation Fairness Metrics - DPD: 0.0041 – DPR: 0.9941
# Epoch 12
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6684 – acc: 59.04% – f1: 65.23% – precision: 59.53% – recall: 72.14% – roc_auc: 58.13%
# Training Fairness Metrics - DPD: 0.0080 – DPR: 0.9877
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6702 acc: 58.37% – f1: 65.58% – precision: 58.61% – recall: 74.42% – roc_auc: 57.24%
# Validation Fairness Metrics - DPD: 0.0022 – DPR: 0.9967
# Epoch 13
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6682 – acc: 59.21% – f1: 65.15% – precision: 59.78% – recall: 71.58% – roc_auc: 58.35%
# Training Fairness Metrics - DPD: 0.0085 – DPR: 0.9868
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6702 acc: 58.17% – f1: 65.30% – precision: 58.52% – recall: 73.86% – roc_auc: 57.07%
# Validation Fairness Metrics - DPD: 0.0042 – DPR: 0.9938
# Epoch 14
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6679 – acc: 59.04% – f1: 64.90% – precision: 59.69% – recall: 71.09% – roc_auc: 58.20%
# Training Fairness Metrics - DPD: 0.0081 – DPR: 0.9874
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6702 acc: 58.22% – f1: 65.41% – precision: 58.52% – recall: 74.14% – roc_auc: 57.10%
# Validation Fairness Metrics - DPD: 0.0037 – DPR: 0.9945
# Epoch 15
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6677 – acc: 59.02% – f1: 64.90% – precision: 59.66% – recall: 71.16% – roc_auc: 58.17%
# Training Fairness Metrics - DPD: 0.0084 – DPR: 0.9869
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6701 acc: 58.22% – f1: 65.36% – precision: 58.55% – recall: 73.96% – roc_auc: 57.12%
# Validation Fairness Metrics - DPD: 0.0017 – DPR: 0.9975
# Epoch 16
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6675 – acc: 59.12% – f1: 65.03% – precision: 59.72% – recall: 71.37% – roc_auc: 58.26%
# Training Fairness Metrics - DPD: 0.0087 – DPR: 0.9865
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6700 acc: 58.12% – f1: 65.30% – precision: 58.46% – recall: 73.96% – roc_auc: 57.01%
# Validation Fairness Metrics - DPD: 0.0027 – DPR: 0.9960
# Epoch 17
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6674 – acc: 59.20% – f1: 65.16% – precision: 59.75% – recall: 71.65% – roc_auc: 58.34%
# Training Fairness Metrics - DPD: 0.0069 – DPR: 0.9893
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6700 acc: 58.27% – f1: 65.30% – precision: 58.63% – recall: 73.68% – roc_auc: 57.19%
# Validation Fairness Metrics - DPD: 0.0011 – DPR: 0.9984
# Epoch 18
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6672 – acc: 59.29% – f1: 65.17% – precision: 59.85% – recall: 71.53% – roc_auc: 58.44%
# Training Fairness Metrics - DPD: 0.0067 – DPR: 0.9896
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6701 acc: 58.12% – f1: 65.16% – precision: 58.52% – recall: 73.49% – roc_auc: 57.04%
# Validation Fairness Metrics - DPD: 0.0026 – DPR: 0.9962
# Epoch 19
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6671 – acc: 59.24% – f1: 65.14% – precision: 59.81% – recall: 71.51% – roc_auc: 58.39%
# Training Fairness Metrics - DPD: 0.0087 – DPR: 0.9865
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6699 acc: 57.98% – f1: 65.02% – precision: 58.42% – recall: 73.31% – roc_auc: 56.90%
# Validation Fairness Metrics - DPD: 0.0021 – DPR: 0.9969
# Epoch 20
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6670 – acc: 59.25% – f1: 65.16% – precision: 59.81% – recall: 71.56% – roc_auc: 58.40%
# Training Fairness Metrics - DPD: 0.0084 – DPR: 0.9870
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6698 acc: 58.12% – f1: 65.07% – precision: 58.56% – recall: 73.22% – roc_auc: 57.06%
# Validation Fairness Metrics - DPD: 0.0015 – DPR: 0.9977
# Fold 3
# f_ESCS
# Epoch 01
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6901 – acc: 54.20% – f1: 64.65% – precision: 54.89% – recall: 78.65% – roc_auc: 52.50%
# Training Fairness Metrics - DPD: 0.0066 – DPR: 0.9914
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6835 acc: 54.96% – f1: 66.96% – precision: 54.97% – recall: 85.63% – roc_auc: 52.81%
# Validation Fairness Metrics - DPD: 0.0134 – DPR: 0.9841
# Epoch 02
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6797 – acc: 57.56% – f1: 62.80% – precision: 58.89% – recall: 67.27% – roc_auc: 56.89%
# Training Fairness Metrics - DPD: 0.0099 – DPR: 0.9841
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6805 acc: 55.51% – f1: 64.32% – precision: 56.15% – recall: 75.25% – roc_auc: 54.12%
# Validation Fairness Metrics - DPD: 0.0164 – DPR: 0.9776
# Epoch 03
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6774 – acc: 57.98% – f1: 62.85% – precision: 59.39% – recall: 66.74% – roc_auc: 57.37%
# Training Fairness Metrics - DPD: 0.0015 – DPR: 0.9976
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6795 acc: 55.65% – f1: 62.86% – precision: 56.76% – recall: 70.44% – roc_auc: 54.62%
# Validation Fairness Metrics - DPD: 0.0111 – DPR: 0.9835
# Epoch 04
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6759 – acc: 58.25% – f1: 63.18% – precision: 59.56% – recall: 67.27% – roc_auc: 57.62%
# Training Fairness Metrics - DPD: 0.0092 – DPR: 0.9850
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6806 acc: 56.05% – f1: 63.82% – precision: 56.84% – recall: 72.75% – roc_auc: 54.88%
# Validation Fairness Metrics - DPD: 0.0305 – DPR: 0.9572
# Epoch 05
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6738 – acc: 58.84% – f1: 64.84% – precision: 59.48% – recall: 71.26% – roc_auc: 57.98%
# Training Fairness Metrics - DPD: 0.0046 – DPR: 0.9928
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6807 acc: 56.30% – f1: 63.35% – precision: 57.26% – recall: 70.90% – roc_auc: 55.27%
# Validation Fairness Metrics - DPD: 0.0274 – DPR: 0.9602
# Epoch 06
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6730 – acc: 58.76% – f1: 64.48% – precision: 59.55% – recall: 70.31% – roc_auc: 57.95%
# Training Fairness Metrics - DPD: 0.0083 – DPR: 0.9870
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6799 acc: 55.95% – f1: 65.45% – precision: 56.22% – recall: 78.31% – roc_auc: 54.38%
# Validation Fairness Metrics - DPD: 0.0178 – DPR: 0.9766
# Epoch 07
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6721 – acc: 58.98% – f1: 64.38% – precision: 59.88% – recall: 69.61% – roc_auc: 58.24%
# Training Fairness Metrics - DPD: 0.0027 – DPR: 0.9957
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6809 acc: 56.94% – f1: 64.55% – precision: 57.49% – recall: 73.59% – roc_auc: 55.77%
# Validation Fairness Metrics - DPD: 0.0326 – DPR: 0.9544
# Epoch 08
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6717 – acc: 58.78% – f1: 64.37% – precision: 59.64% – recall: 69.91% – roc_auc: 58.01%
# Training Fairness Metrics - DPD: 0.0074 – DPR: 0.9883
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6798 acc: 57.19% – f1: 64.51% – precision: 57.77% – recall: 73.03% – roc_auc: 56.07%
# Validation Fairness Metrics - DPD: 0.0230 – DPR: 0.9669
# Epoch 09
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6710 – acc: 58.78% – f1: 64.32% – precision: 59.66% – recall: 69.77% – roc_auc: 58.02%
# Training Fairness Metrics - DPD: 0.0106 – DPR: 0.9832
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6804 acc: 57.09% – f1: 63.19% – precision: 58.19% – recall: 69.14% – roc_auc: 56.24%
# Validation Fairness Metrics - DPD: 0.0339 – DPR: 0.9491
# Epoch 10
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6707 – acc: 58.99% – f1: 64.33% – precision: 59.92% – recall: 69.45% – roc_auc: 58.27%
# Training Fairness Metrics - DPD: 0.0048 – DPR: 0.9923
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6806 acc: 56.84% – f1: 61.26% – precision: 58.71% – recall: 64.04% – roc_auc: 56.33%
# Validation Fairness Metrics - DPD: 0.0276 – DPR: 0.9546
# Epoch 11
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6674 – acc: 58.91% – f1: 65.39% – precision: 59.28% – recall: 72.90% – roc_auc: 57.93%
# Training Fairness Metrics - DPD: 0.0288 – DPR: 0.9578
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6810 acc: 57.19% – f1: 63.12% – precision: 58.33% – recall: 68.77% – roc_auc: 56.37%
# Validation Fairness Metrics - DPD: 0.0389 – DPR: 0.9417
# Epoch 12
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6660 – acc: 59.03% – f1: 65.50% – precision: 59.37% – recall: 73.04% – roc_auc: 58.05%
# Training Fairness Metrics - DPD: 0.0298 – DPR: 0.9564
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6815 acc: 57.04% – f1: 62.44% – precision: 58.45% – recall: 67.01% – roc_auc: 56.34%
# Validation Fairness Metrics - DPD: 0.0318 – DPR: 0.9505
# Epoch 13
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6657 – acc: 58.98% – f1: 65.25% – precision: 59.44% – recall: 72.32% – roc_auc: 58.05%
# Training Fairness Metrics - DPD: 0.0276 – DPR: 0.9591
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6818 acc: 56.94% – f1: 62.28% – precision: 58.39% – recall: 66.73% – roc_auc: 56.25%
# Validation Fairness Metrics - DPD: 0.0275 – DPR: 0.9568
# Epoch 14
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6654 – acc: 59.03% – f1: 65.19% – precision: 59.53% – recall: 72.04% – roc_auc: 58.12%
# Training Fairness Metrics - DPD: 0.0245 – DPR: 0.9634
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6819 acc: 57.14% – f1: 62.26% – precision: 58.64% – recall: 66.36% – roc_auc: 56.49%
# Validation Fairness Metrics - DPD: 0.0271 – DPR: 0.9571
# Epoch 15
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6652 – acc: 59.13% – f1: 65.11% – precision: 59.69% – recall: 71.60% – roc_auc: 58.26%
# Training Fairness Metrics - DPD: 0.0230 – DPR: 0.9652
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6820 acc: 57.19% – f1: 62.19% – precision: 58.73% – recall: 66.08% – roc_auc: 56.56%
# Validation Fairness Metrics - DPD: 0.0273 – DPR: 0.9564
# Epoch 16
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6650 – acc: 59.07% – f1: 64.97% – precision: 59.69% – recall: 71.28% – roc_auc: 58.22%
# Training Fairness Metrics - DPD: 0.0243 – DPR: 0.9631
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6822 acc: 57.19% – f1: 62.09% – precision: 58.77% – recall: 65.80% – roc_auc: 56.58%
# Validation Fairness Metrics - DPD: 0.0282 – DPR: 0.9549
# Epoch 17
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6648 – acc: 59.01% – f1: 64.85% – precision: 59.67% – recall: 71.00% – roc_auc: 58.17%
# Training Fairness Metrics - DPD: 0.0242 – DPR: 0.9633
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6824 acc: 57.09% – f1: 61.84% – precision: 58.76% – recall: 65.25% – roc_auc: 56.51%
# Validation Fairness Metrics - DPD: 0.0278 – DPR: 0.9550
# Epoch 18
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6647 – acc: 58.92% – f1: 64.73% – precision: 59.63% – recall: 70.79% – roc_auc: 58.09%
# Training Fairness Metrics - DPD: 0.0248 – DPR: 0.9623
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6825 acc: 57.04% – f1: 61.78% – precision: 58.73% – recall: 65.15% – roc_auc: 56.47%
# Validation Fairness Metrics - DPD: 0.0294 – DPR: 0.9526
# Epoch 19
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6646 – acc: 59.01% – f1: 64.79% – precision: 59.70% – recall: 70.84% – roc_auc: 58.18%
# Training Fairness Metrics - DPD: 0.0244 – DPR: 0.9629
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6826 acc: 57.09% – f1: 61.90% – precision: 58.74% – recall: 65.43% – roc_auc: 56.50%
# Validation Fairness Metrics - DPD: 0.0280 – DPR: 0.9550
# Epoch 20
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6645 – acc: 58.99% – f1: 64.82% – precision: 59.67% – recall: 70.93% – roc_auc: 58.16%
# Training Fairness Metrics - DPD: 0.0250 – DPR: 0.9620
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6826 acc: 57.09% – f1: 61.90% – precision: 58.74% – recall: 65.43% – roc_auc: 56.50%
# Validation Fairness Metrics - DPD: 0.0280 – DPR: 0.9550
# Fold 4
# f_ESCS
# Epoch 01
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6909 – acc: 54.33% – f1: 67.92% – precision: 54.26% – recall: 90.75% – roc_auc: 51.78%
# Training Fairness Metrics - DPD: 0.0149 – DPR: 0.9833
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6793 acc: 57.28% – f1: 68.49% – precision: 56.39% – recall: 87.20% – roc_auc: 55.21%
# Validation Fairness Metrics - DPD: 0.0276 – DPR: 0.9664
# Epoch 02
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6807 – acc: 56.91% – f1: 62.17% – precision: 58.38% – recall: 66.49% – roc_auc: 56.24%
# Training Fairness Metrics - DPD: 0.0074 – DPR: 0.9878
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6766 acc: 58.12% – f1: 63.91% – precision: 59.04% – recall: 69.67% – roc_auc: 57.33%
# Validation Fairness Metrics - DPD: 0.0179 – DPR: 0.9715
# Epoch 03
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6771 – acc: 57.28% – f1: 63.18% – precision: 58.40% – recall: 68.83% – roc_auc: 56.47%
# Training Fairness Metrics - DPD: 0.0161 – DPR: 0.9750
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6745 acc: 57.98% – f1: 64.32% – precision: 58.68% – recall: 71.15% – roc_auc: 57.06%
# Validation Fairness Metrics - DPD: 0.0152 – DPR: 0.9765
# Epoch 04
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6747 – acc: 57.76% – f1: 64.31% – precision: 58.47% – recall: 71.45% – roc_auc: 56.80%
# Training Fairness Metrics - DPD: 0.0154 – DPR: 0.9769
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6733 acc: 57.93% – f1: 65.28% – precision: 58.21% – recall: 74.30% – roc_auc: 56.79%
# Validation Fairness Metrics - DPD: 0.0009 – DPR: 0.9987
# Epoch 05
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6735 – acc: 57.94% – f1: 63.86% – precision: 58.88% – recall: 69.76% – roc_auc: 57.12%
# Training Fairness Metrics - DPD: 0.0168 – DPR: 0.9741
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6727 acc: 57.58% – f1: 65.54% – precision: 57.74% – recall: 75.79% – roc_auc: 56.32%
# Validation Fairness Metrics - DPD: 0.0034 – DPR: 0.9952
# Epoch 06
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6730 – acc: 58.39% – f1: 64.47% – precision: 59.13% – recall: 70.87% – roc_auc: 57.52%
# Training Fairness Metrics - DPD: 0.0137 – DPR: 0.9789
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6724 acc: 57.58% – f1: 65.07% – precision: 57.93% – recall: 74.21% – roc_auc: 56.43%
# Validation Fairness Metrics - DPD: 0.0056 – DPR: 0.9918
# Epoch 07
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6730 – acc: 58.18% – f1: 64.24% – precision: 58.98% – recall: 70.52% – roc_auc: 57.32%
# Training Fairness Metrics - DPD: 0.0146 – DPR: 0.9776
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6721 acc: 57.93% – f1: 65.11% – precision: 58.28% – recall: 73.75% – roc_auc: 56.83%
# Validation Fairness Metrics - DPD: 0.0072 – DPR: 0.9892
# Epoch 08
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6729 – acc: 58.10% – f1: 64.57% – precision: 58.75% – recall: 71.68% – roc_auc: 57.16%
# Training Fairness Metrics - DPD: 0.0131 – DPR: 0.9803
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6735 acc: 57.73% – f1: 63.45% – precision: 58.78% – recall: 68.92% – roc_auc: 56.95%
# Validation Fairness Metrics - DPD: 0.0120 – DPR: 0.9808
# Epoch 09
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6727 – acc: 58.34% – f1: 64.81% – precision: 58.91% – recall: 72.03% – roc_auc: 57.38%
# Training Fairness Metrics - DPD: 0.0102 – DPR: 0.9846
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6739 acc: 58.07% – f1: 63.04% – precision: 59.39% – recall: 67.16% – roc_auc: 57.45%
# Validation Fairness Metrics - DPD: 0.0278 – DPR: 0.9538
# Epoch 10
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6719 – acc: 58.78% – f1: 64.55% – precision: 59.56% – recall: 70.45% – roc_auc: 57.97%
# Training Fairness Metrics - DPD: 0.0051 – DPR: 0.9919
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6728 acc: 57.83% – f1: 64.45% – precision: 58.46% – recall: 71.80% – roc_auc: 56.86%
# Validation Fairness Metrics - DPD: 0.0055 – DPR: 0.9915
# Epoch 11
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6693 – acc: 59.18% – f1: 66.15% – precision: 59.24% – recall: 74.90% – roc_auc: 58.08%
# Training Fairness Metrics - DPD: 0.0103 – DPR: 0.9849
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6713 acc: 57.78% – f1: 65.43% – precision: 57.99% – recall: 75.05% – roc_auc: 56.58%
# Validation Fairness Metrics - DPD: 0.0045 – DPR: 0.9934
# Epoch 12
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6679 – acc: 59.31% – f1: 65.92% – precision: 59.51% – recall: 73.86% – roc_auc: 58.30%
# Training Fairness Metrics - DPD: 0.0102 – DPR: 0.9848
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6714 acc: 57.73% – f1: 65.23% – precision: 58.02% – recall: 74.49% – roc_auc: 56.57%
# Validation Fairness Metrics - DPD: 0.0051 – DPR: 0.9925
# Epoch 13
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6675 – acc: 59.25% – f1: 65.81% – precision: 59.49% – recall: 73.63% – roc_auc: 58.25%
# Training Fairness Metrics - DPD: 0.0107 – DPR: 0.9840
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6715 acc: 57.83% – f1: 65.34% – precision: 58.08% – recall: 74.68% – roc_auc: 56.66%
# Validation Fairness Metrics - DPD: 0.0041 – DPR: 0.9940
# Epoch 14
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6672 – acc: 59.13% – f1: 65.71% – precision: 59.40% – recall: 73.51% – roc_auc: 58.12%
# Training Fairness Metrics - DPD: 0.0110 – DPR: 0.9836
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6714 acc: 57.83% – f1: 65.31% – precision: 58.09% – recall: 74.58% – roc_auc: 56.67%
# Validation Fairness Metrics - DPD: 0.0031 – DPR: 0.9955
# Epoch 15
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6671 – acc: 59.18% – f1: 65.71% – precision: 59.46% – recall: 73.42% – roc_auc: 58.18%
# Training Fairness Metrics - DPD: 0.0107 – DPR: 0.9840
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6714 acc: 57.83% – f1: 65.28% – precision: 58.10% – recall: 74.49% – roc_auc: 56.67%
# Validation Fairness Metrics - DPD: 0.0031 – DPR: 0.9954
# Epoch 16
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6669 – acc: 59.20% – f1: 65.72% – precision: 59.48% – recall: 73.42% – roc_auc: 58.21%
# Training Fairness Metrics - DPD: 0.0104 – DPR: 0.9844
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6714 acc: 57.78% – f1: 65.20% – precision: 58.09% – recall: 74.30% – roc_auc: 56.63%
# Validation Fairness Metrics - DPD: 0.0036 – DPR: 0.9947
# Epoch 17
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6668 – acc: 59.24% – f1: 65.80% – precision: 59.49% – recall: 73.60% – roc_auc: 58.24%
# Training Fairness Metrics - DPD: 0.0114 – DPR: 0.9830
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6714 acc: 57.83% – f1: 65.43% – precision: 58.05% – recall: 74.95% – roc_auc: 56.64%
# Validation Fairness Metrics - DPD: 0.0010 – DPR: 0.9985
# Epoch 18
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6666 – acc: 59.29% – f1: 65.88% – precision: 59.50% – recall: 73.79% – roc_auc: 58.28%
# Training Fairness Metrics - DPD: 0.0114 – DPR: 0.9830
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6714 acc: 57.93% – f1: 65.51% – precision: 58.12% – recall: 75.05% – roc_auc: 56.74%
# Validation Fairness Metrics - DPD: 0.0010 – DPR: 0.9985
# Epoch 19
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6664 – acc: 59.35% – f1: 65.95% – precision: 59.54% – recall: 73.90% – roc_auc: 58.33%
# Training Fairness Metrics - DPD: 0.0113 – DPR: 0.9831
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6714 acc: 57.93% – f1: 65.56% – precision: 58.09% – recall: 75.23% – roc_auc: 56.73%
# Validation Fairness Metrics - DPD: 0.0000 – DPR: 1.0000
# Epoch 20
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6663 – acc: 59.30% – f1: 65.95% – precision: 59.48% – recall: 74.00% – roc_auc: 58.27%
# Training Fairness Metrics - DPD: 0.0106 – DPR: 0.9842
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6713 acc: 57.88% – f1: 65.54% – precision: 58.05% – recall: 75.23% – roc_auc: 56.68%
# Validation Fairness Metrics - DPD: 0.0005 – DPR: 0.9993
# Fold 5
# f_ESCS
# Epoch 01
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6926 – acc: 53.04% – f1: 67.40% – precision: 53.47% – recall: 91.12% – roc_auc: 50.38%
# Training Fairness Metrics - DPD: 0.0035 – DPR: 0.9961
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6843 acc: 53.23% – f1: 69.48% – precision: 53.23% – recall: 100.00% – roc_auc: 50.00%
# Validation Fairness Metrics - DPD: 0.0000 – DPR: 1.0000
# Epoch 02
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6851 – acc: 56.08% – f1: 62.04% – precision: 57.48% – recall: 67.37% – roc_auc: 55.29%
# Training Fairness Metrics - DPD: 0.0171 – DPR: 0.9726
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6696 acc: 58.57% – f1: 68.06% – precision: 57.71% – recall: 82.93% – roc_auc: 56.88%
# Validation Fairness Metrics - DPD: 0.0125 – DPR: 0.9839
# Epoch 03
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6803 – acc: 56.44% – f1: 61.99% – precision: 57.91% – recall: 66.70% – roc_auc: 55.72%
# Training Fairness Metrics - DPD: 0.0066 – DPR: 0.9892
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6678 acc: 58.77% – f1: 68.09% – precision: 57.89% – recall: 82.65% – roc_auc: 57.11%
# Validation Fairness Metrics - DPD: 0.0154 – DPR: 0.9801
# Epoch 04
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6783 – acc: 57.47% – f1: 63.82% – precision: 58.35% – recall: 70.43% – roc_auc: 56.57%
# Training Fairness Metrics - DPD: 0.0072 – DPR: 0.9890
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6697 acc: 57.93% – f1: 67.97% – precision: 57.14% – recall: 83.86% – roc_auc: 56.13%
# Validation Fairness Metrics - DPD: 0.0274 – DPR: 0.9661
# Epoch 05
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6780 – acc: 57.23% – f1: 63.10% – precision: 58.37% – recall: 68.67% – roc_auc: 56.43%
# Training Fairness Metrics - DPD: 0.0199 – DPR: 0.9693
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6672 acc: 60.54% – f1: 65.84% – precision: 61.06% – recall: 71.43% – roc_auc: 59.79%
# Validation Fairness Metrics - DPD: 0.0288 – DPR: 0.9554
# Epoch 06
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6772 – acc: 57.78% – f1: 63.94% – precision: 58.66% – recall: 70.27% – roc_auc: 56.91%
# Training Fairness Metrics - DPD: 0.0143 – DPR: 0.9781
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6672 acc: 59.46% – f1: 68.44% – precision: 58.44% – recall: 82.56% – roc_auc: 57.86%
# Validation Fairness Metrics - DPD: 0.0304 – DPR: 0.9611
# Epoch 07
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6760 – acc: 57.70% – f1: 64.07% – precision: 58.50% – recall: 70.82% – roc_auc: 56.78%
# Training Fairness Metrics - DPD: 0.0219 – DPR: 0.9672
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6684 acc: 58.96% – f1: 68.61% – precision: 57.87% – recall: 84.23% – roc_auc: 57.22%
# Validation Fairness Metrics - DPD: 0.0288 – DPR: 0.9641
# Epoch 08
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6758 – acc: 57.91% – f1: 64.58% – precision: 58.52% – recall: 72.03% – roc_auc: 56.92%
# Training Fairness Metrics - DPD: 0.0158 – DPR: 0.9765
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6655 acc: 59.65% – f1: 68.76% – precision: 58.49% – recall: 83.40% – roc_auc: 58.01%
# Validation Fairness Metrics - DPD: 0.0184 – DPR: 0.9763
# Epoch 09
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6746 – acc: 58.14% – f1: 64.77% – precision: 58.70% – recall: 72.24% – roc_auc: 57.16%
# Training Fairness Metrics - DPD: 0.0113 – DPR: 0.9831
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6669 acc: 58.96% – f1: 68.79% – precision: 57.79% – recall: 84.97% – roc_auc: 57.16%
# Validation Fairness Metrics - DPD: 0.0259 – DPR: 0.9679
# Epoch 10
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6757 – acc: 57.92% – f1: 64.28% – precision: 58.66% – recall: 71.08% – roc_auc: 57.00%
# Training Fairness Metrics - DPD: 0.0407 – DPR: 0.9407
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6674 acc: 59.51% – f1: 68.99% – precision: 58.24% – recall: 84.60% – roc_auc: 57.77%
# Validation Fairness Metrics - DPD: 0.0232 – DPR: 0.9708
# Epoch 11
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6722 – acc: 57.98% – f1: 66.33% – precision: 57.86% – recall: 77.71% – roc_auc: 56.60%
# Training Fairness Metrics - DPD: 0.0285 – DPR: 0.9617
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6643 acc: 59.56% – f1: 67.87% – precision: 58.80% – recall: 80.24% – roc_auc: 58.12%
# Validation Fairness Metrics - DPD: 0.0309 – DPR: 0.9591
# Epoch 12
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6713 – acc: 58.12% – f1: 65.65% – precision: 58.29% – recall: 75.13% – roc_auc: 56.93%
# Training Fairness Metrics - DPD: 0.0308 – DPR: 0.9571
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6640 acc: 59.65% – f1: 67.97% – precision: 58.86% – recall: 80.43% – roc_auc: 58.22%
# Validation Fairness Metrics - DPD: 0.0289 – DPR: 0.9618
# Epoch 13
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6710 – acc: 58.15% – f1: 65.75% – precision: 58.28% – recall: 75.41% – roc_auc: 56.95%
# Training Fairness Metrics - DPD: 0.0308 – DPR: 0.9573
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6642 acc: 59.85% – f1: 68.40% – precision: 58.86% – recall: 81.63% – roc_auc: 58.35%
# Validation Fairness Metrics - DPD: 0.0261 – DPR: 0.9659
# Epoch 14
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6707 – acc: 58.41% – f1: 66.06% – precision: 58.43% – recall: 75.99% – roc_auc: 57.18%
# Training Fairness Metrics - DPD: 0.0305 – DPR: 0.9578
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6640 acc: 59.80% – f1: 68.30% – precision: 58.86% – recall: 81.35% – roc_auc: 58.31%
# Validation Fairness Metrics - DPD: 0.0265 – DPR: 0.9652
# Epoch 15
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6705 – acc: 58.31% – f1: 66.01% – precision: 58.35% – recall: 75.99% – roc_auc: 57.08%
# Training Fairness Metrics - DPD: 0.0303 – DPR: 0.9581
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6640 acc: 59.90% – f1: 68.45% – precision: 58.89% – recall: 81.73% – roc_auc: 58.39%
# Validation Fairness Metrics - DPD: 0.0246 – DPR: 0.9678
# Epoch 16
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6703 – acc: 58.33% – f1: 66.12% – precision: 58.31% – recall: 76.36% – roc_auc: 57.07%
# Training Fairness Metrics - DPD: 0.0291 – DPR: 0.9600
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6639 acc: 59.85% – f1: 68.45% – precision: 58.84% – recall: 81.82% – roc_auc: 58.33%
# Validation Fairness Metrics - DPD: 0.0251 – DPR: 0.9672
# Epoch 17
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6702 – acc: 58.40% – f1: 66.13% – precision: 58.39% – recall: 76.25% – roc_auc: 57.15%
# Training Fairness Metrics - DPD: 0.0274 – DPR: 0.9621
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6637 acc: 59.75% – f1: 68.37% – precision: 58.77% – recall: 81.73% – roc_auc: 58.23%
# Validation Fairness Metrics - DPD: 0.0241 – DPR: 0.9685
# Epoch 18
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6701 – acc: 58.46% – f1: 66.07% – precision: 58.48% – recall: 75.92% – roc_auc: 57.24%
# Training Fairness Metrics - DPD: 0.0261 – DPR: 0.9636
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6637 acc: 59.80% – f1: 68.40% – precision: 58.81% – recall: 81.73% – roc_auc: 58.29%
# Validation Fairness Metrics - DPD: 0.0226 – DPR: 0.9704
# Epoch 19
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6700 – acc: 58.51% – f1: 66.07% – precision: 58.53% – recall: 75.85% – roc_auc: 57.30%
# Training Fairness Metrics - DPD: 0.0253 – DPR: 0.9647
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6636 acc: 59.60% – f1: 68.20% – precision: 58.70% – recall: 81.35% – roc_auc: 58.10%
# Validation Fairness Metrics - DPD: 0.0236 – DPR: 0.9691
# Epoch 20
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6699 – acc: 58.52% – f1: 65.99% – precision: 58.58% – recall: 75.55% – roc_auc: 57.33%
# Training Fairness Metrics - DPD: 0.0245 – DPR: 0.9656
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6632 acc: 60.40% – f1: 68.50% – precision: 59.40% – recall: 80.89% – roc_auc: 58.98%
# Validation Fairness Metrics - DPD: 0.0193 – DPR: 0.9741
# FINAL RESULTS ACROSS ALL FOLDS:
# Accuracy:  58.404094914262735 ± 1.1023141803179726
# F1-Score:  65.40073459053338 ± 2.112520155610042
# Precision:  58.668359202563536 ± 0.43281093322974556
# Recall:  74.06044901741976 ± 5.007432911301775
# ROC-AUC:  57.31411867991035 ± 0.8833769219162761
# FINAL FAIRNESS RESULTS ACROSS ALL FOLDS:
# Demographic Parity Difference:  0.013456389408370063 ± 0.010735939649520293
# Demographic Parity Ratio:  0.9801054648297935 ± 0.016602146599511782

# %% [markdown]
# #### Disparate Impact Remover

# %%
dir_res, dir_fair_res = kfold_cross_validation(5, X, Y, sensitive_feature=SENSITIVE, preprocessing='dir')
# Out:
# Fold 1
# Epoch 01
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6928 – acc: 52.00% – f1: 51.67% – precision: 55.71% – recall: 48.17% – roc_auc: 52.27%
# Training Fairness Metrics - DPD: 0.0000 – DPR: 1.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6856 acc: 55.73% – f1: 42.46% – precision: 68.96% – recall: 30.68% – roc_auc: 57.47%
# Validation Fairness Metrics - DPD: 0.1325 – DPR: 0.4406
# Epoch 02
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6849 – acc: 56.02% – f1: 54.87% – precision: 60.51% – recall: 50.19% – roc_auc: 56.43%
# Training Fairness Metrics - DPD: 0.0000 – DPR: 1.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6827 acc: 56.02% – f1: 44.07% – precision: 68.29% – recall: 32.53% – roc_auc: 57.66%
# Validation Fairness Metrics - DPD: 0.1368 – DPR: 0.4608
# Epoch 03
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6832 – acc: 56.37% – f1: 56.26% – precision: 60.36% – recall: 52.69% – roc_auc: 56.63%
# Training Fairness Metrics - DPD: 0.0000 – DPR: 1.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6770 acc: 58.14% – f1: 53.66% – precision: 65.38% – recall: 45.51% – roc_auc: 59.02%
# Validation Fairness Metrics - DPD: 0.1703 – DPR: 0.5407
# Epoch 04
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6819 – acc: 56.98% – f1: 57.76% – precision: 60.53% – recall: 55.24% – roc_auc: 57.10%
# Training Fairness Metrics - DPD: 0.0000 – DPR: 1.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6786 acc: 56.96% – f1: 49.83% – precision: 65.71% – recall: 40.13% – roc_auc: 58.13%
# Validation Fairness Metrics - DPD: 0.1583 – DPR: 0.5135
# Epoch 05
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6819 – acc: 56.88% – f1: 56.55% – precision: 61.02% – recall: 52.69% – roc_auc: 57.17%
# Training Fairness Metrics - DPD: 0.0000 – DPR: 1.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6769 acc: 57.45% – f1: 51.57% – precision: 65.48% – recall: 42.54% – roc_auc: 58.49%
# Validation Fairness Metrics - DPD: 0.1644 – DPR: 0.5249
# Epoch 06
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6805 – acc: 57.17% – f1: 57.50% – precision: 60.98% – recall: 54.40% – roc_auc: 57.37%
# Training Fairness Metrics - DPD: 0.0000 – DPR: 1.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6735 acc: 58.00% – f1: 54.76% – precision: 64.21% – recall: 47.73% – roc_auc: 58.71%
# Validation Fairness Metrics - DPD: 0.1787 – DPR: 0.5485
# Epoch 07
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6795 – acc: 57.23% – f1: 57.48% – precision: 61.09% – recall: 54.27% – roc_auc: 57.44%
# Training Fairness Metrics - DPD: 0.0000 – DPR: 1.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6735 acc: 58.05% – f1: 54.79% – precision: 64.29% – recall: 47.73% – roc_auc: 58.76%
# Validation Fairness Metrics - DPD: 0.1772 – DPR: 0.5518
# Epoch 08
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6785 – acc: 57.49% – f1: 58.18% – precision: 61.11% – recall: 55.52% – roc_auc: 57.63%
# Training Fairness Metrics - DPD: 0.0000 – DPR: 1.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6721 acc: 57.90% – f1: 54.99% – precision: 63.85% – recall: 48.29% – roc_auc: 58.57%
# Validation Fairness Metrics - DPD: 0.1731 – DPR: 0.5702
# Epoch 09
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6780 – acc: 57.85% – f1: 58.22% – precision: 61.66% – recall: 55.15% – roc_auc: 58.04%
# Training Fairness Metrics - DPD: 0.0000 – DPR: 1.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6706 acc: 58.29% – f1: 56.29% – precision: 63.70% – recall: 50.42% – roc_auc: 58.84%
# Validation Fairness Metrics - DPD: 0.1689 – DPR: 0.5993
# Epoch 10
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6777 – acc: 57.85% – f1: 58.33% – precision: 61.60% – recall: 55.38% – roc_auc: 58.02%
# Training Fairness Metrics - DPD: 0.0000 – DPR: 1.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6711 acc: 58.09% – f1: 55.71% – precision: 63.72% – recall: 49.49% – roc_auc: 58.69%
# Validation Fairness Metrics - DPD: 0.1725 – DPR: 0.5830
# Epoch 11
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6740 – acc: 58.68% – f1: 60.80% – precision: 61.44% – recall: 60.18% – roc_auc: 58.57%
# Training Fairness Metrics - DPD: 0.0000 – DPR: 1.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6697 acc: 58.69% – f1: 57.10% – precision: 63.88% – recall: 51.62% – roc_auc: 59.18%
# Validation Fairness Metrics - DPD: 0.1747 – DPR: 0.5942
# Epoch 12
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6737 – acc: 58.85% – f1: 60.68% – precision: 61.78% – recall: 59.62% – roc_auc: 58.80%
# Training Fairness Metrics - DPD: 0.0000 – DPR: 1.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6692 acc: 58.84% – f1: 57.54% – precision: 63.84% – recall: 52.36% – roc_auc: 59.29%
# Validation Fairness Metrics - DPD: 0.1727 – DPR: 0.6046
# Epoch 13
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6735 – acc: 58.78% – f1: 60.44% – precision: 61.81% – recall: 59.13% – roc_auc: 58.75%
# Training Fairness Metrics - DPD: 0.0000 – DPR: 1.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6691 acc: 58.74% – f1: 57.35% – precision: 63.79% – recall: 52.09% – roc_auc: 59.20%
# Validation Fairness Metrics - DPD: 0.1739 – DPR: 0.6001
# Epoch 14
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6733 – acc: 58.81% – f1: 60.52% – precision: 61.82% – recall: 59.27% – roc_auc: 58.78%
# Training Fairness Metrics - DPD: 0.0000 – DPR: 1.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6691 acc: 58.64% – f1: 57.11% – precision: 63.77% – recall: 51.71% – roc_auc: 59.12%
# Validation Fairness Metrics - DPD: 0.1730 – DPR: 0.5994
# Epoch 15
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6731 – acc: 58.67% – f1: 60.36% – precision: 61.69% – recall: 59.09% – roc_auc: 58.64%
# Training Fairness Metrics - DPD: 0.0000 – DPR: 1.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6687 acc: 58.64% – f1: 57.24% – precision: 63.68% – recall: 51.99% – roc_auc: 59.10%
# Validation Fairness Metrics - DPD: 0.1728 – DPR: 0.6025
# Epoch 16
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6730 – acc: 58.68% – f1: 60.38% – precision: 61.70% – recall: 59.11% – roc_auc: 58.65%
# Training Fairness Metrics - DPD: 0.0000 – DPR: 1.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6684 acc: 58.84% – f1: 57.58% – precision: 63.81% – recall: 52.46% – roc_auc: 59.28%
# Validation Fairness Metrics - DPD: 0.1716 – DPR: 0.6080
# Epoch 17
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6728 – acc: 58.59% – f1: 60.30% – precision: 61.61% – recall: 59.04% – roc_auc: 58.56%
# Training Fairness Metrics - DPD: 0.0000 – DPR: 1.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6683 acc: 58.88% – f1: 57.65% – precision: 63.85% – recall: 52.55% – roc_auc: 59.33%
# Validation Fairness Metrics - DPD: 0.1711 – DPR: 0.6097
# Epoch 18
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6727 – acc: 58.65% – f1: 60.46% – precision: 61.61% – recall: 59.34% – roc_auc: 58.61%
# Training Fairness Metrics - DPD: 0.0000 – DPR: 1.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6683 acc: 58.79% – f1: 57.51% – precision: 63.77% – recall: 52.36% – roc_auc: 59.23%
# Validation Fairness Metrics - DPD: 0.1701 – DPR: 0.6111
# Epoch 19
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6726 – acc: 58.58% – f1: 60.39% – precision: 61.53% – recall: 59.30% – roc_auc: 58.53%
# Training Fairness Metrics - DPD: 0.0000 – DPR: 1.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6682 acc: 58.79% – f1: 57.51% – precision: 63.77% – recall: 52.36% – roc_auc: 59.23%
# Validation Fairness Metrics - DPD: 0.1701 – DPR: 0.6111
# Epoch 20
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6725 – acc: 58.65% – f1: 60.48% – precision: 61.60% – recall: 59.41% – roc_auc: 58.60%
# Training Fairness Metrics - DPD: 0.0000 – DPR: 1.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6681 acc: 58.59% – f1: 57.22% – precision: 63.61% – recall: 51.99% – roc_auc: 59.05%
# Validation Fairness Metrics - DPD: 0.1692 – DPR: 0.6114
# Fold 2
# Epoch 01
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6960 – acc: 51.55% – f1: 58.85% – precision: 53.72% – recall: 65.07% – roc_auc: 50.61%
# Training Fairness Metrics - DPD: 0.0000 – DPR: 1.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6924 acc: 53.58% – f1: 69.58% – precision: 53.46% – recall: 99.63% – roc_auc: 50.34%
# Validation Fairness Metrics - DPD: 0.0072 – DPR: 0.9927
# Epoch 02
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6957 – acc: 50.93% – f1: 52.82% – precision: 54.12% – recall: 51.58% – roc_auc: 50.89%
# Training Fairness Metrics - DPD: 0.0000 – DPR: 1.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6920 acc: 55.80% – f1: 40.53% – precision: 71.60% – recall: 28.27% – roc_auc: 57.74%
# Validation Fairness Metrics - DPD: 0.1336 – DPR: 0.3649
# Epoch 03
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6905 – acc: 54.91% – f1: 60.56% – precision: 56.68% – recall: 65.00% – roc_auc: 54.20%
# Training Fairness Metrics - DPD: 0.0000 – DPR: 1.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6899 acc: 55.90% – f1: 40.90% – precision: 71.53% – recall: 28.64% – roc_auc: 57.82%
# Validation Fairness Metrics - DPD: 0.1315 – DPR: 0.3835
# Epoch 04
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6823 – acc: 56.78% – f1: 58.71% – precision: 59.76% – recall: 57.70% – roc_auc: 56.72%
# Training Fairness Metrics - DPD: 0.0000 – DPR: 1.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6785 acc: 56.99% – f1: 50.71% – precision: 65.12% – recall: 41.52% – roc_auc: 58.07%
# Validation Fairness Metrics - DPD: 0.1832 – DPR: 0.4608
# Epoch 05
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6791 – acc: 57.47% – f1: 58.92% – precision: 60.67% – recall: 57.28% – roc_auc: 57.49%
# Training Fairness Metrics - DPD: 0.0000 – DPR: 1.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6763 acc: 56.74% – f1: 50.62% – precision: 64.60% – recall: 41.61% – roc_auc: 57.80%
# Validation Fairness Metrics - DPD: 0.1846 – DPR: 0.4621
# Epoch 06
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6781 – acc: 57.50% – f1: 59.01% – precision: 60.66% – recall: 57.44% – roc_auc: 57.50%
# Training Fairness Metrics - DPD: 0.0000 – DPR: 1.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6708 acc: 57.68% – f1: 53.75% – precision: 64.34% – recall: 46.15% – roc_auc: 58.49%
# Validation Fairness Metrics - DPD: 0.1943 – DPR: 0.4915
# Epoch 07
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6773 – acc: 57.45% – f1: 58.51% – precision: 60.85% – recall: 56.35% – roc_auc: 57.53%
# Training Fairness Metrics - DPD: 0.0000 – DPR: 1.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6707 acc: 57.93% – f1: 52.77% – precision: 65.66% – recall: 44.11% – roc_auc: 58.90%
# Validation Fairness Metrics - DPD: 0.1944 – DPR: 0.4571
# Epoch 08
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6771 – acc: 57.66% – f1: 58.78% – precision: 61.03% – recall: 56.70% – roc_auc: 57.73%
# Training Fairness Metrics - DPD: 0.0000 – DPR: 1.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6702 acc: 58.17% – f1: 53.44% – precision: 65.68% – recall: 45.04% – roc_auc: 59.10%
# Validation Fairness Metrics - DPD: 0.1957 – DPR: 0.4644
# Epoch 09
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6762 – acc: 57.83% – f1: 59.27% – precision: 61.03% – recall: 57.60% – roc_auc: 57.85%
# Training Fairness Metrics - DPD: 0.0000 – DPR: 1.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6693 acc: 58.67% – f1: 54.49% – precision: 65.92% – recall: 46.43% – roc_auc: 59.53%
# Validation Fairness Metrics - DPD: 0.1955 – DPR: 0.4791
# Epoch 10
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6758 – acc: 58.26% – f1: 59.90% – precision: 61.33% – recall: 58.53% – roc_auc: 58.25%
# Training Fairness Metrics - DPD: 0.0000 – DPR: 1.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6697 acc: 58.37% – f1: 53.91% – precision: 65.73% – recall: 45.69% – roc_auc: 59.26%
# Validation Fairness Metrics - DPD: 0.1946 – DPR: 0.4745
# Epoch 11
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6730 – acc: 58.75% – f1: 60.57% – precision: 61.68% – recall: 59.50% – roc_auc: 58.69%
# Training Fairness Metrics - DPD: 0.0000 – DPR: 1.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6631 acc: 58.62% – f1: 57.68% – precision: 63.37% – recall: 52.92% – roc_auc: 59.02%
# Validation Fairness Metrics - DPD: 0.1934 – DPR: 0.5653
# Epoch 12
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6726 – acc: 58.93% – f1: 61.06% – precision: 61.66% – recall: 60.48% – roc_auc: 58.82%
# Training Fairness Metrics - DPD: 0.0000 – DPR: 1.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6630 acc: 58.62% – f1: 57.55% – precision: 63.46% – recall: 52.64% – roc_auc: 59.04%
# Validation Fairness Metrics - DPD: 0.1955 – DPR: 0.5576
# Epoch 13
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6725 – acc: 59.04% – f1: 61.12% – precision: 61.80% – recall: 60.45% – roc_auc: 58.94%
# Training Fairness Metrics - DPD: 0.0000 – DPR: 1.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6627 acc: 58.77% – f1: 57.81% – precision: 63.56% – recall: 53.01% – roc_auc: 59.17%
# Validation Fairness Metrics - DPD: 0.1939 – DPR: 0.5636
# Epoch 14
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6725 – acc: 59.05% – f1: 61.09% – precision: 61.84% – recall: 60.36% – roc_auc: 58.96%
# Training Fairness Metrics - DPD: 0.0000 – DPR: 1.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6628 acc: 58.72% – f1: 57.65% – precision: 63.58% – recall: 52.73% – roc_auc: 59.14%
# Validation Fairness Metrics - DPD: 0.1945 – DPR: 0.5599
# Epoch 15
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6724 – acc: 59.02% – f1: 60.97% – precision: 61.86% – recall: 60.11% – roc_auc: 58.94%
# Training Fairness Metrics - DPD: 0.0000 – DPR: 1.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6625 acc: 58.62% – f1: 57.51% – precision: 63.49% – recall: 52.55% – roc_auc: 59.04%
# Validation Fairness Metrics - DPD: 0.1945 – DPR: 0.5589
# Epoch 16
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6723 – acc: 59.02% – f1: 60.93% – precision: 61.88% – recall: 60.01% – roc_auc: 58.95%
# Training Fairness Metrics - DPD: 0.0000 – DPR: 1.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6625 acc: 58.67% – f1: 57.58% – precision: 63.53% – recall: 52.64% – roc_auc: 59.09%
# Validation Fairness Metrics - DPD: 0.1940 – DPR: 0.5606
# Epoch 17
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6723 – acc: 59.09% – f1: 60.96% – precision: 61.98% – recall: 59.97% – roc_auc: 59.03%
# Training Fairness Metrics - DPD: 0.0000 – DPR: 1.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6625 acc: 58.81% – f1: 57.58% – precision: 63.81% – recall: 52.46% – roc_auc: 59.26%
# Validation Fairness Metrics - DPD: 0.1946 – DPR: 0.5558
# Epoch 18
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6723 – acc: 59.14% – f1: 60.97% – precision: 62.05% – recall: 59.92% – roc_auc: 59.09%
# Training Fairness Metrics - DPD: 0.0000 – DPR: 1.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6624 acc: 58.86% – f1: 57.61% – precision: 63.88% – recall: 52.46% – roc_auc: 59.31%
# Validation Fairness Metrics - DPD: 0.1941 – DPR: 0.5564
# Epoch 19
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6722 – acc: 59.13% – f1: 60.93% – precision: 62.05% – recall: 59.85% – roc_auc: 59.08%
# Training Fairness Metrics - DPD: 0.0000 – DPR: 1.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6624 acc: 58.86% – f1: 57.56% – precision: 63.91% – recall: 52.36% – roc_auc: 59.32%
# Validation Fairness Metrics - DPD: 0.1941 – DPR: 0.5553
# Epoch 20
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6722 – acc: 59.10% – f1: 60.85% – precision: 62.06% – recall: 59.69% – roc_auc: 59.06%
# Training Fairness Metrics - DPD: 0.0000 – DPR: 1.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6624 acc: 58.96% – f1: 57.58% – precision: 64.09% – recall: 52.27% – roc_auc: 59.43%
# Validation Fairness Metrics - DPD: 0.1942 – DPR: 0.5532
# Fold 3
# Epoch 01
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6911 – acc: 53.49% – f1: 54.29% – precision: 56.95% – recall: 51.88% – roc_auc: 53.60%
# Training Fairness Metrics - DPD: 0.0000 – DPR: 1.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6878 acc: 53.04% – f1: 32.12% – precision: 69.88% – recall: 20.85% – roc_auc: 55.30%
# Validation Fairness Metrics - DPD: 0.1072 – DPR: 0.3257
# Epoch 02
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6848 – acc: 55.98% – f1: 53.56% – precision: 61.12% – recall: 47.66% – roc_auc: 56.56%
# Training Fairness Metrics - DPD: 0.0000 – DPR: 1.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6799 acc: 56.10% – f1: 46.80% – precision: 66.05% – recall: 36.24% – roc_auc: 57.49%
# Validation Fairness Metrics - DPD: 0.1570 – DPR: 0.4628
# Epoch 03
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6828 – acc: 56.84% – f1: 56.71% – precision: 60.87% – recall: 53.08% – roc_auc: 57.11%
# Training Fairness Metrics - DPD: 0.0000 – DPR: 1.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6762 acc: 57.19% – f1: 51.48% – precision: 64.97% – recall: 42.63% – roc_auc: 58.21%
# Validation Fairness Metrics - DPD: 0.1773 – DPR: 0.4928
# Epoch 04
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6802 – acc: 57.04% – f1: 56.53% – precision: 61.29% – recall: 52.46% – roc_auc: 57.36%
# Training Fairness Metrics - DPD: 0.0000 – DPR: 1.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6744 acc: 58.27% – f1: 55.36% – precision: 64.37% – recall: 48.56% – roc_auc: 58.95%
# Validation Fairness Metrics - DPD: 0.1863 – DPR: 0.5365
# Epoch 05
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6792 – acc: 57.10% – f1: 57.41% – precision: 60.91% – recall: 54.29% – roc_auc: 57.30%
# Training Fairness Metrics - DPD: 0.0000 – DPR: 1.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6753 acc: 58.12% – f1: 54.65% – precision: 64.60% – recall: 47.36% – roc_auc: 58.88%
# Validation Fairness Metrics - DPD: 0.1803 – DPR: 0.5385
# Epoch 06
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6779 – acc: 57.28% – f1: 57.98% – precision: 60.87% – recall: 55.35% – roc_auc: 57.41%
# Training Fairness Metrics - DPD: 0.0000 – DPR: 1.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6757 acc: 58.07% – f1: 54.33% – precision: 64.74% – recall: 46.80% – roc_auc: 58.87%
# Validation Fairness Metrics - DPD: 0.1759 – DPR: 0.5434
# Epoch 07
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6778 – acc: 57.34% – f1: 58.00% – precision: 60.96% – recall: 55.31% – roc_auc: 57.48%
# Training Fairness Metrics - DPD: 0.0000 – DPR: 1.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6758 acc: 58.52% – f1: 55.22% – precision: 64.99% – recall: 48.01% – roc_auc: 59.26%
# Validation Fairness Metrics - DPD: 0.1727 – DPR: 0.5613
# Epoch 08
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6774 – acc: 57.28% – f1: 58.33% – precision: 60.69% – recall: 56.14% – roc_auc: 57.36%
# Training Fairness Metrics - DPD: 0.0000 – DPR: 1.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6755 acc: 58.27% – f1: 55.64% – precision: 64.16% – recall: 49.12% – roc_auc: 58.91%
# Validation Fairness Metrics - DPD: 0.1785 – DPR: 0.5624
# Epoch 09
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6767 – acc: 57.38% – f1: 58.28% – precision: 60.86% – recall: 55.91% – roc_auc: 57.48%
# Training Fairness Metrics - DPD: 0.0000 – DPR: 1.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6756 acc: 57.73% – f1: 54.71% – precision: 63.75% – recall: 47.91% – roc_auc: 58.42%
# Validation Fairness Metrics - DPD: 0.1753 – DPR: 0.5622
# Epoch 10
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6760 – acc: 57.70% – f1: 58.56% – precision: 61.21% – recall: 56.12% – roc_auc: 57.81%
# Training Fairness Metrics - DPD: 0.0000 – DPR: 1.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6762 acc: 57.68% – f1: 53.40% – precision: 64.61% – recall: 45.51% – roc_auc: 58.53%
# Validation Fairness Metrics - DPD: 0.1713 – DPR: 0.5436
# Epoch 11
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6717 – acc: 58.72% – f1: 60.74% – precision: 61.54% – recall: 59.97% – roc_auc: 58.63%
# Training Fairness Metrics - DPD: 0.0000 – DPR: 1.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6771 acc: 57.53% – f1: 52.64% – precision: 64.86% – recall: 44.30% – roc_auc: 58.46%
# Validation Fairness Metrics - DPD: 0.1768 – DPR: 0.5141
# Epoch 12
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6711 – acc: 58.93% – f1: 60.65% – precision: 61.92% – recall: 59.43% – roc_auc: 58.90%
# Training Fairness Metrics - DPD: 0.0000 – DPR: 1.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6781 acc: 57.58% – f1: 52.62% – precision: 64.99% – recall: 44.21% – roc_auc: 58.52%
# Validation Fairness Metrics - DPD: 0.1764 – DPR: 0.5133
# Epoch 13
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6707 – acc: 58.94% – f1: 60.60% – precision: 61.97% – recall: 59.30% – roc_auc: 58.92%
# Training Fairness Metrics - DPD: 0.0000 – DPR: 1.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6785 acc: 57.33% – f1: 52.37% – precision: 64.63% – recall: 44.02% – roc_auc: 58.27%
# Validation Fairness Metrics - DPD: 0.1759 – DPR: 0.5155
# Epoch 14
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6705 – acc: 58.99% – f1: 60.55% – precision: 62.08% – recall: 59.09% – roc_auc: 58.99%
# Training Fairness Metrics - DPD: 0.0000 – DPR: 1.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6789 acc: 57.53% – f1: 52.54% – precision: 64.94% – recall: 44.11% – roc_auc: 58.47%
# Validation Fairness Metrics - DPD: 0.1749 – DPR: 0.5169
# Epoch 15
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6703 – acc: 58.91% – f1: 60.48% – precision: 61.99% – recall: 59.04% – roc_auc: 58.90%
# Training Fairness Metrics - DPD: 0.0000 – DPR: 1.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6791 acc: 57.53% – f1: 52.43% – precision: 65.02% – recall: 43.93% – roc_auc: 58.49%
# Validation Fairness Metrics - DPD: 0.1729 – DPR: 0.5197
# Epoch 16
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6701 – acc: 58.92% – f1: 60.51% – precision: 61.98% – recall: 59.11% – roc_auc: 58.91%
# Training Fairness Metrics - DPD: 0.0000 – DPR: 1.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6790 acc: 57.53% – f1: 52.54% – precision: 64.94% – recall: 44.11% – roc_auc: 58.47%
# Validation Fairness Metrics - DPD: 0.1738 – DPR: 0.5198
# Epoch 17
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6699 – acc: 58.96% – f1: 60.52% – precision: 62.04% – recall: 59.06% – roc_auc: 58.95%
# Training Fairness Metrics - DPD: 0.0000 – DPR: 1.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6795 acc: 57.38% – f1: 52.19% – precision: 64.88% – recall: 43.65% – roc_auc: 58.35%
# Validation Fairness Metrics - DPD: 0.1725 – DPR: 0.5189
# Epoch 18
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6698 – acc: 58.94% – f1: 60.59% – precision: 61.97% – recall: 59.27% – roc_auc: 58.92%
# Training Fairness Metrics - DPD: 0.0000 – DPR: 1.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6797 acc: 57.53% – f1: 52.33% – precision: 65.10% – recall: 43.74% – roc_auc: 58.50%
# Validation Fairness Metrics - DPD: 0.1741 – DPR: 0.5137
# Epoch 19
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6697 – acc: 58.93% – f1: 60.50% – precision: 62.01% – recall: 59.06% – roc_auc: 58.92%
# Training Fairness Metrics - DPD: 0.0000 – DPR: 1.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6800 acc: 57.48% – f1: 52.09% – precision: 65.18% – recall: 43.37% – roc_auc: 58.47%
# Validation Fairness Metrics - DPD: 0.1727 – DPR: 0.5128
# Epoch 20
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6696 – acc: 58.91% – f1: 60.40% – precision: 62.03% – recall: 58.85% – roc_auc: 58.91%
# Training Fairness Metrics - DPD: 0.0000 – DPR: 1.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6802 acc: 57.53% – f1: 52.06% – precision: 65.31% – recall: 43.28% – roc_auc: 58.53%
# Validation Fairness Metrics - DPD: 0.1744 – DPR: 0.5060
# Fold 4
# Epoch 01
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6940 – acc: 52.57% – f1: 55.91% – precision: 55.38% – recall: 56.45% – roc_auc: 52.30%
# Training Fairness Metrics - DPD: 0.0000 – DPR: 1.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6950 acc: 50.27% – f1: 18.72% – precision: 72.05% – recall: 10.76% – roc_auc: 53.00%
# Validation Fairness Metrics - DPD: 0.0595 – DPR: 0.2521
# Epoch 02
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6868 – acc: 54.51% – f1: 50.99% – precision: 59.83% – recall: 44.43% – roc_auc: 55.22%
# Training Fairness Metrics - DPD: 0.0000 – DPR: 1.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6742 acc: 57.33% – f1: 48.75% – precision: 67.60% – recall: 38.13% – roc_auc: 58.66%
# Validation Fairness Metrics - DPD: 0.1570 – DPR: 0.4772
# Epoch 03
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6819 – acc: 56.02% – f1: 53.52% – precision: 61.22% – recall: 47.53% – roc_auc: 56.61%
# Training Fairness Metrics - DPD: 0.0000 – DPR: 1.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6745 acc: 57.83% – f1: 48.12% – precision: 69.72% – recall: 36.73% – roc_auc: 59.29%
# Validation Fairness Metrics - DPD: 0.1552 – DPR: 0.4465
# Epoch 04
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6803 – acc: 56.70% – f1: 55.93% – precision: 61.07% – recall: 51.59% – roc_auc: 57.05%
# Training Fairness Metrics - DPD: 0.0000 – DPR: 1.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6755 acc: 58.12% – f1: 50.87% – precision: 67.75% – recall: 40.72% – roc_auc: 59.33%
# Validation Fairness Metrics - DPD: 0.1667 – DPR: 0.4791
# Epoch 05
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6790 – acc: 56.84% – f1: 56.55% – precision: 60.98% – recall: 52.72% – roc_auc: 57.13%
# Training Fairness Metrics - DPD: 0.0000 – DPR: 1.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6808 acc: 58.52% – f1: 50.24% – precision: 69.51% – recall: 39.33% – roc_auc: 59.85%
# Validation Fairness Metrics - DPD: 0.1650 – DPR: 0.4524
# Epoch 06
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6777 – acc: 56.99% – f1: 57.21% – precision: 60.86% – recall: 53.97% – roc_auc: 57.20%
# Training Fairness Metrics - DPD: 0.0000 – DPR: 1.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6751 acc: 58.81% – f1: 51.62% – precision: 68.89% – recall: 41.28% – roc_auc: 60.03%
# Validation Fairness Metrics - DPD: 0.1767 – DPR: 0.4460
# Epoch 07
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6769 – acc: 57.26% – f1: 57.56% – precision: 61.10% – recall: 54.41% – roc_auc: 57.46%
# Training Fairness Metrics - DPD: 0.0000 – DPR: 1.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6682 acc: 58.17% – f1: 54.14% – precision: 65.02% – recall: 46.38% – roc_auc: 58.99%
# Validation Fairness Metrics - DPD: 0.1874 – DPR: 0.5066
# Epoch 08
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6768 – acc: 56.47% – f1: 54.54% – precision: 61.46% – recall: 49.02% – roc_auc: 57.00%
# Training Fairness Metrics - DPD: 0.0000 – DPR: 1.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6765 acc: 59.21% – f1: 53.96% – precision: 67.60% – recall: 44.90% – roc_auc: 60.20%
# Validation Fairness Metrics - DPD: 0.1882 – DPR: 0.4676
# Epoch 09
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6756 – acc: 57.20% – f1: 57.93% – precision: 60.80% – recall: 55.32% – roc_auc: 57.33%
# Training Fairness Metrics - DPD: 0.0000 – DPR: 1.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6774 acc: 56.89% – f1: 44.92% – precision: 70.22% – recall: 33.02% – roc_auc: 58.54%
# Validation Fairness Metrics - DPD: 0.1472 – DPR: 0.4122
# Epoch 10
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6761 – acc: 57.15% – f1: 56.40% – precision: 61.57% – recall: 52.03% – roc_auc: 57.51%
# Training Fairness Metrics - DPD: 0.0000 – DPR: 1.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6685 acc: 59.46% – f1: 57.48% – precision: 65.06% – recall: 51.48% – roc_auc: 60.01%
# Validation Fairness Metrics - DPD: 0.1898 – DPR: 0.5495
# Epoch 11
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6725 – acc: 58.01% – f1: 60.96% – precision: 60.38% – recall: 61.55% – roc_auc: 57.76%
# Training Fairness Metrics - DPD: 0.0000 – DPR: 1.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6675 acc: 59.56% – f1: 58.02% – precision: 64.83% – recall: 52.50% – roc_auc: 60.04%
# Validation Fairness Metrics - DPD: 0.1886 – DPR: 0.5625
# Epoch 12
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6718 – acc: 58.07% – f1: 60.72% – precision: 60.59% – recall: 60.86% – roc_auc: 57.87%
# Training Fairness Metrics - DPD: 0.0000 – DPR: 1.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6675 acc: 59.26% – f1: 57.45% – precision: 64.69% – recall: 51.67% – roc_auc: 59.78%
# Validation Fairness Metrics - DPD: 0.1927 – DPR: 0.5467
# Epoch 13
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6715 – acc: 58.01% – f1: 60.52% – precision: 60.61% – recall: 60.42% – roc_auc: 57.84%
# Training Fairness Metrics - DPD: 0.0000 – DPR: 1.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6675 acc: 59.26% – f1: 57.45% – precision: 64.69% – recall: 51.67% – roc_auc: 59.78%
# Validation Fairness Metrics - DPD: 0.1927 – DPR: 0.5467
# Epoch 14
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6711 – acc: 57.94% – f1: 60.16% – precision: 60.72% – recall: 59.61% – roc_auc: 57.83%
# Training Fairness Metrics - DPD: 0.0000 – DPR: 1.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6678 acc: 59.41% – f1: 57.14% – precision: 65.24% – recall: 50.83% – roc_auc: 60.00%
# Validation Fairness Metrics - DPD: 0.1934 – DPR: 0.5338
# Epoch 15
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6708 – acc: 57.92% – f1: 59.99% – precision: 60.77% – recall: 59.24% – roc_auc: 57.83%
# Training Fairness Metrics - DPD: 0.0000 – DPR: 1.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6673 acc: 59.56% – f1: 57.50% – precision: 65.25% – recall: 51.39% – roc_auc: 60.12%
# Validation Fairness Metrics - DPD: 0.1958 – DPR: 0.5330
# Epoch 16
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6706 – acc: 57.96% – f1: 59.90% – precision: 60.88% – recall: 58.96% – roc_auc: 57.89%
# Training Fairness Metrics - DPD: 0.0000 – DPR: 1.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6674 acc: 59.60% – f1: 57.31% – precision: 65.51% – recall: 50.93% – roc_auc: 60.21%
# Validation Fairness Metrics - DPD: 0.1944 – DPR: 0.5303
# Epoch 17
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6703 – acc: 58.03% – f1: 59.57% – precision: 61.17% – recall: 58.05% – roc_auc: 58.03%
# Training Fairness Metrics - DPD: 0.0000 – DPR: 1.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6674 acc: 59.26% – f1: 56.60% – precision: 65.37% – recall: 49.91% – roc_auc: 59.91%
# Validation Fairness Metrics - DPD: 0.1940 – DPR: 0.5227
# Epoch 18
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6700 – acc: 57.97% – f1: 59.27% – precision: 61.25% – recall: 57.40% – roc_auc: 58.01%
# Training Fairness Metrics - DPD: 0.0000 – DPR: 1.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6676 acc: 59.56% – f1: 56.23% – precision: 66.33% – recall: 48.79% – roc_auc: 60.30%
# Validation Fairness Metrics - DPD: 0.1902 – DPR: 0.5143
# Epoch 19
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6698 – acc: 57.96% – f1: 58.92% – precision: 61.43% – recall: 56.62% – roc_auc: 58.05%
# Training Fairness Metrics - DPD: 0.0000 – DPR: 1.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6676 acc: 59.56% – f1: 56.23% – precision: 66.33% – recall: 48.79% – roc_auc: 60.30%
# Validation Fairness Metrics - DPD: 0.1902 – DPR: 0.5143
# Epoch 20
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6695 – acc: 57.71% – f1: 58.33% – precision: 61.38% – recall: 55.57% – roc_auc: 57.86%
# Training Fairness Metrics - DPD: 0.0000 – DPR: 1.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6677 acc: 59.26% – f1: 55.62% – precision: 66.20% – recall: 47.96% – roc_auc: 60.04%
# Validation Fairness Metrics - DPD: 0.1873 – DPR: 0.5144
# Fold 5
# Epoch 01
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6961 – acc: 50.64% – f1: 52.48% – precision: 53.85% – recall: 51.17% – roc_auc: 50.60%
# Training Fairness Metrics - DPD: 0.0000 – DPR: 1.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6915 acc: 55.36% – f1: 40.21% – precision: 70.05% – recall: 28.20% – roc_auc: 57.24%
# Validation Fairness Metrics - DPD: 0.1247 – DPR: 0.4182
# Epoch 02
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6923 – acc: 53.03% – f1: 50.59% – precision: 57.53% – recall: 45.14% – roc_auc: 53.58%
# Training Fairness Metrics - DPD: 0.0000 – DPR: 1.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6727 acc: 59.80% – f1: 61.53% – precision: 62.72% – recall: 60.39% – roc_auc: 59.76%
# Validation Fairness Metrics - DPD: 0.1611 – DPR: 0.6857
# Epoch 03
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6884 – acc: 54.34% – f1: 49.08% – precision: 60.44% – recall: 41.32% – roc_auc: 55.25%
# Training Fairness Metrics - DPD: 0.0000 – DPR: 1.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6739 acc: 59.46% – f1: 58.51% – precision: 64.26% – recall: 53.71% – roc_auc: 59.85%
# Validation Fairness Metrics - DPD: 0.1680 – DPR: 0.6224
# Epoch 04
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6851 – acc: 55.22% – f1: 53.76% – precision: 59.73% – recall: 48.88% – roc_auc: 55.66%
# Training Fairness Metrics - DPD: 0.0000 – DPR: 1.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6736 acc: 59.31% – f1: 53.50% – precision: 68.30% – recall: 43.97% – roc_auc: 60.37%
# Validation Fairness Metrics - DPD: 0.1534 – DPR: 0.5524
# Epoch 05
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6824 – acc: 56.15% – f1: 55.64% – precision: 60.33% – recall: 51.63% – roc_auc: 56.47%
# Training Fairness Metrics - DPD: 0.0000 – DPR: 1.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6669 acc: 59.75% – f1: 57.13% – precision: 65.98% – recall: 50.37% – roc_auc: 60.40%
# Validation Fairness Metrics - DPD: 0.1637 – DPR: 0.5972
# Epoch 06
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6818 – acc: 56.60% – f1: 56.95% – precision: 60.37% – recall: 53.90% – roc_auc: 56.79%
# Training Fairness Metrics - DPD: 0.0000 – DPR: 1.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6655 acc: 60.00% – f1: 56.96% – precision: 66.67% – recall: 49.72% – roc_auc: 60.71%
# Validation Fairness Metrics - DPD: 0.1664 – DPR: 0.5808
# Epoch 07
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6801 – acc: 56.92% – f1: 57.26% – precision: 60.71% – recall: 54.18% – roc_auc: 57.11%
# Training Fairness Metrics - DPD: 0.0000 – DPR: 1.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6623 acc: 60.00% – f1: 57.55% – precision: 66.14% – recall: 50.93% – roc_auc: 60.63%
# Validation Fairness Metrics - DPD: 0.1652 – DPR: 0.5970
# Epoch 08
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6795 – acc: 56.65% – f1: 57.20% – precision: 60.32% – recall: 54.39% – roc_auc: 56.80%
# Training Fairness Metrics - DPD: 0.0000 – DPR: 1.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6649 acc: 59.56% – f1: 55.46% – precision: 67.02% – recall: 47.31% – roc_auc: 60.40%
# Validation Fairness Metrics - DPD: 0.1653 – DPR: 0.5601
# Epoch 09
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6788 – acc: 57.55% – f1: 57.90% – precision: 61.36% – recall: 54.81% – roc_auc: 57.74%
# Training Fairness Metrics - DPD: 0.0000 – DPR: 1.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6623 acc: 59.51% – f1: 56.38% – precision: 66.08% – recall: 49.17% – roc_auc: 60.22%
# Validation Fairness Metrics - DPD: 0.1634 – DPR: 0.5874
# Epoch 10
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6786 – acc: 57.14% – f1: 57.53% – precision: 60.92% – recall: 54.51% – roc_auc: 57.33%
# Training Fairness Metrics - DPD: 0.0000 – DPR: 1.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6598 acc: 59.95% – f1: 58.22% – precision: 65.47% – recall: 52.41% – roc_auc: 60.47%
# Validation Fairness Metrics - DPD: 0.1664 – DPR: 0.6097
# Epoch 11
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6756 – acc: 57.88% – f1: 59.58% – precision: 60.94% – recall: 58.29% – roc_auc: 57.85%
# Training Fairness Metrics - DPD: 0.0000 – DPR: 1.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6583 acc: 60.10% – f1: 58.65% – precision: 65.41% – recall: 53.15% – roc_auc: 60.58%
# Validation Fairness Metrics - DPD: 0.1687 – DPR: 0.6099
# Epoch 12
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6753 – acc: 57.93% – f1: 59.48% – precision: 61.07% – recall: 57.96% – roc_auc: 57.93%
# Training Fairness Metrics - DPD: 0.0000 – DPR: 1.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6580 acc: 60.05% – f1: 58.53% – precision: 65.41% – recall: 52.97% – roc_auc: 60.54%
# Validation Fairness Metrics - DPD: 0.1663 – DPR: 0.6144
# Epoch 13
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6751 – acc: 58.01% – f1: 59.30% – precision: 61.29% – recall: 57.43% – roc_auc: 58.05%
# Training Fairness Metrics - DPD: 0.0000 – DPR: 1.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6582 acc: 60.10% – f1: 58.26% – precision: 65.73% – recall: 52.32% – roc_auc: 60.64%
# Validation Fairness Metrics - DPD: 0.1659 – DPR: 0.6085
# Epoch 14
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6749 – acc: 58.20% – f1: 59.43% – precision: 61.52% – recall: 57.47% – roc_auc: 58.25%
# Training Fairness Metrics - DPD: 0.0000 – DPR: 1.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6583 acc: 59.95% – f1: 58.13% – precision: 65.54% – recall: 52.23% – roc_auc: 60.48%
# Validation Fairness Metrics - DPD: 0.1654 – DPR: 0.6101
# Epoch 15
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6748 – acc: 58.23% – f1: 59.42% – precision: 61.57% – recall: 57.43% – roc_auc: 58.28%
# Training Fairness Metrics - DPD: 0.0000 – DPR: 1.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6582 acc: 59.95% – f1: 58.04% – precision: 65.61% – recall: 52.04% – roc_auc: 60.50%
# Validation Fairness Metrics - DPD: 0.1654 – DPR: 0.6082
# Epoch 16
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6747 – acc: 58.29% – f1: 59.46% – precision: 61.64% – recall: 57.43% – roc_auc: 58.35%
# Training Fairness Metrics - DPD: 0.0000 – DPR: 1.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6584 acc: 60.00% – f1: 57.94% – precision: 65.80% – recall: 51.76% – roc_auc: 60.57%
# Validation Fairness Metrics - DPD: 0.1640 – DPR: 0.6084
# Epoch 17
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6746 – acc: 58.29% – f1: 59.50% – precision: 61.62% – recall: 57.52% – roc_auc: 58.34%
# Training Fairness Metrics - DPD: 0.0000 – DPR: 1.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6585 acc: 60.05% – f1: 57.97% – precision: 65.88% – recall: 51.76% – roc_auc: 60.62%
# Validation Fairness Metrics - DPD: 0.1635 – DPR: 0.6091
# Epoch 18
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6745 – acc: 58.34% – f1: 59.57% – precision: 61.66% – recall: 57.61% – roc_auc: 58.39%
# Training Fairness Metrics - DPD: 0.0000 – DPR: 1.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6586 acc: 60.15% – f1: 57.95% – precision: 66.11% – recall: 51.58% – roc_auc: 60.74%
# Validation Fairness Metrics - DPD: 0.1646 – DPR: 0.6038
# Epoch 19
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6744 – acc: 58.45% – f1: 59.71% – precision: 61.75% – recall: 57.80% – roc_auc: 58.50%
# Training Fairness Metrics - DPD: 0.0000 – DPR: 1.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6587 acc: 60.25% – f1: 58.05% – precision: 66.23% – recall: 51.67% – roc_auc: 60.84%
# Validation Fairness Metrics - DPD: 0.1646 – DPR: 0.6038
# Epoch 20
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6743 – acc: 58.40% – f1: 59.65% – precision: 61.70% – recall: 57.73% – roc_auc: 58.45%
# Training Fairness Metrics - DPD: 0.0000 – DPR: 1.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6586 acc: 60.20% – f1: 57.93% – precision: 66.23% – recall: 51.48% – roc_auc: 60.80%
# Validation Fairness Metrics - DPD: 0.1671 – DPR: 0.5962
# FINAL RESULTS ACROSS ALL FOLDS:
# Accuracy:  58.907793743068495 ± 0.8703989725840645
# F1-Score:  56.082606137514816 ± 2.1599346363059277
# Precision:  65.08746732523284 ± 1.0748011743301944
# Recall:  49.397487194389086 ± 3.430053016958185
# ROC-AUC:  59.57101187065631 ± 0.7877045409434373
# FINAL FAIRNESS RESULTS ACROSS ALL FOLDS:
# Demographic Parity Difference:  0.17842933351892323 ± 0.010546292465021766
# Demographic Parity Ratio:  0.556241206071631 ± 0.04226230751509537

# %% [markdown]
# #### Learning Fair Representations

# %%
lfr_res, lfr_fair_res = kfold_cross_validation(5, X, Y, sensitive_feature=SENSITIVE, preprocessing='lfr')
# Out:
# Fold 1
# Epoch 01
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6958 – acc: 51.96% – f1: 61.02% – precision: 53.73% – recall: 70.58% – roc_auc: 50.66%
# Training Fairness Metrics - DPD: 0.6996 – DPR: 0.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6916 acc: 53.26% – f1: 69.50% – precision: 53.26% – recall: 100.00% – roc_auc: 50.00%
# Validation Fairness Metrics - DPD: 0.0000 – DPR: 1.0000
# Epoch 02
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6917 – acc: 53.93% – f1: 55.00% – precision: 57.31% – recall: 52.87% – roc_auc: 54.00%
# Training Fairness Metrics - DPD: 0.5086 – DPR: 0.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6867 acc: 55.13% – f1: 57.98% – precision: 57.84% – recall: 58.11% – roc_auc: 54.93%
# Validation Fairness Metrics - DPD: 0.5350 – DPR: 0.0000
# Epoch 03
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6889 – acc: 55.07% – f1: 56.58% – precision: 58.30% – recall: 54.96% – roc_auc: 55.08%
# Training Fairness Metrics - DPD: 0.5021 – DPR: 0.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6903 acc: 50.94% – f1: 32.38% – precision: 60.87% – recall: 22.06% – roc_auc: 52.95%
# Validation Fairness Metrics - DPD: 0.8070 – DPR: 0.0000
# Epoch 04
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6874 – acc: 55.67% – f1: 56.86% – precision: 59.01% – recall: 54.87% – roc_auc: 55.72%
# Training Fairness Metrics - DPD: 0.5048 – DPR: 0.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6869 acc: 53.80% – f1: 49.62% – precision: 59.18% – recall: 42.72% – roc_auc: 54.57%
# Validation Fairness Metrics - DPD: 0.6155 – DPR: 0.0000
# Epoch 05
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6858 – acc: 55.52% – f1: 54.54% – precision: 59.84% – recall: 50.09% – roc_auc: 55.90%
# Training Fairness Metrics - DPD: 0.5542 – DPR: 0.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6880 acc: 53.75% – f1: 47.57% – precision: 60.03% – recall: 39.39% – roc_auc: 54.75%
# Validation Fairness Metrics - DPD: 0.6505 – DPR: 0.0000
# Epoch 06
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6859 – acc: 55.63% – f1: 53.36% – precision: 60.61% – recall: 47.66% – roc_auc: 56.19%
# Training Fairness Metrics - DPD: 0.5812 – DPR: 0.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6879 acc: 53.60% – f1: 44.38% – precision: 61.37% – recall: 34.75% – roc_auc: 54.92%
# Validation Fairness Metrics - DPD: 0.6984 – DPR: 0.0000
# Epoch 07
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6848 – acc: 55.98% – f1: 55.75% – precision: 59.99% – recall: 52.06% – roc_auc: 56.25%
# Training Fairness Metrics - DPD: 0.5378 – DPR: 0.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6854 acc: 54.74% – f1: 51.04% – precision: 60.20% – recall: 44.30% – roc_auc: 55.47%
# Validation Fairness Metrics - DPD: 0.6081 – DPR: 0.0000
# Epoch 08
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6842 – acc: 56.26% – f1: 56.20% – precision: 60.21% – recall: 52.69% – roc_auc: 56.51%
# Training Fairness Metrics - DPD: 0.5340 – DPR: 0.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6843 acc: 55.63% – f1: 54.16% – precision: 60.20% – recall: 49.21% – roc_auc: 56.07%
# Validation Fairness Metrics - DPD: 0.5647 – DPR: 0.0000
# Epoch 09
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6840 – acc: 56.31% – f1: 55.90% – precision: 60.44% – recall: 51.99% – roc_auc: 56.61%
# Training Fairness Metrics - DPD: 0.5419 – DPR: 0.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6843 acc: 55.18% – f1: 52.76% – precision: 60.14% – recall: 46.99% – roc_auc: 55.75%
# Validation Fairness Metrics - DPD: 0.5839 – DPR: 0.0000
# Epoch 10
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6831 – acc: 56.26% – f1: 55.13% – precision: 60.76% – recall: 50.46% – roc_auc: 56.66%
# Training Fairness Metrics - DPD: 0.5577 – DPR: 0.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6829 acc: 55.63% – f1: 55.95% – precision: 59.36% – recall: 52.92% – roc_auc: 55.82%
# Validation Fairness Metrics - DPD: 0.5252 – DPR: 0.0000
# Epoch 11
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6795 – acc: 57.30% – f1: 56.91% – precision: 61.51% – recall: 52.94% – roc_auc: 57.60%
# Training Fairness Metrics - DPD: 0.5416 – DPR: 0.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6832 acc: 55.77% – f1: 57.01% – precision: 59.10% – recall: 55.05% – roc_auc: 55.83%
# Validation Fairness Metrics - DPD: 0.5039 – DPR: 0.0000
# Epoch 12
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6791 – acc: 57.32% – f1: 56.80% – precision: 61.62% – recall: 52.69% – roc_auc: 57.64%
# Training Fairness Metrics - DPD: 0.5446 – DPR: 0.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6835 acc: 55.97% – f1: 57.12% – precision: 59.34% – recall: 55.05% – roc_auc: 56.04%
# Validation Fairness Metrics - DPD: 0.5059 – DPR: 0.0000
# Epoch 13
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6789 – acc: 57.25% – f1: 56.95% – precision: 61.40% – recall: 53.11% – roc_auc: 57.54%
# Training Fairness Metrics - DPD: 0.5394 – DPR: 0.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6835 acc: 56.07% – f1: 57.38% – precision: 59.37% – recall: 55.51% – roc_auc: 56.11%
# Validation Fairness Metrics - DPD: 0.5020 – DPR: 0.0000
# Epoch 14
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6788 – acc: 57.37% – f1: 57.39% – precision: 61.36% – recall: 53.89% – roc_auc: 57.61%
# Training Fairness Metrics - DPD: 0.5322 – DPR: 0.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6833 acc: 56.12% – f1: 57.69% – precision: 59.30% – recall: 56.16% – roc_auc: 56.12%
# Validation Fairness Metrics - DPD: 0.5044 – DPR: 0.0000
# Epoch 15
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6786 – acc: 57.47% – f1: 57.67% – precision: 61.36% – recall: 54.40% – roc_auc: 57.68%
# Training Fairness Metrics - DPD: 0.5278 – DPR: 0.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6832 acc: 55.97% – f1: 57.60% – precision: 59.12% – recall: 56.16% – roc_auc: 55.96%
# Validation Fairness Metrics - DPD: 0.5059 – DPR: 0.0000
# Epoch 16
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6785 – acc: 57.49% – f1: 57.80% – precision: 61.33% – recall: 54.66% – roc_auc: 57.69%
# Training Fairness Metrics - DPD: 0.5253 – DPR: 0.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6833 acc: 55.97% – f1: 57.48% – precision: 59.18% – recall: 55.89% – roc_auc: 55.98%
# Validation Fairness Metrics - DPD: 0.5030 – DPR: 0.0000
# Epoch 17
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6784 – acc: 57.48% – f1: 57.75% – precision: 61.33% – recall: 54.57% – roc_auc: 57.68%
# Training Fairness Metrics - DPD: 0.5262 – DPR: 0.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6832 acc: 55.92% – f1: 57.50% – precision: 59.10% – recall: 55.98% – roc_auc: 55.92%
# Validation Fairness Metrics - DPD: 0.5044 – DPR: 0.0000
# Epoch 18
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6783 – acc: 57.52% – f1: 57.86% – precision: 61.33% – recall: 54.75% – roc_auc: 57.71%
# Training Fairness Metrics - DPD: 0.5246 – DPR: 0.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6832 acc: 55.82% – f1: 57.20% – precision: 59.09% – recall: 55.42% – roc_auc: 55.85%
# Validation Fairness Metrics - DPD: 0.5005 – DPR: 0.0000
# Epoch 19
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6782 – acc: 57.62% – f1: 57.99% – precision: 61.42% – recall: 54.91% – roc_auc: 57.81%
# Training Fairness Metrics - DPD: 0.5238 – DPR: 0.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6830 acc: 55.97% – f1: 57.36% – precision: 59.23% – recall: 55.61% – roc_auc: 56.00%
# Validation Fairness Metrics - DPD: 0.5000 – DPR: 0.0000
# Epoch 20
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6780 – acc: 57.72% – f1: 58.09% – precision: 61.52% – recall: 55.03% – roc_auc: 57.90%
# Training Fairness Metrics - DPD: 0.5236 – DPR: 0.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6829 acc: 56.07% – f1: 57.50% – precision: 59.31% – recall: 55.79% – roc_auc: 56.09%
# Validation Fairness Metrics - DPD: 0.5010 – DPR: 0.0000
# Fold 2
# Epoch 01
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6953 – acc: 51.86% – f1: 55.18% – precision: 54.72% – recall: 55.66% – roc_auc: 51.59%
# Training Fairness Metrics - DPD: 0.5417 – DPR: 0.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6956 acc: 49.28% – f1: 12.89% – precision: 76.00% – recall: 7.04% – roc_auc: 52.25%
# Validation Fairness Metrics - DPD: 0.9506 – DPR: 0.0000
# Epoch 02
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6911 – acc: 55.46% – f1: 59.92% – precision: 57.53% – recall: 62.52% – roc_auc: 54.97%
# Training Fairness Metrics - DPD: 0.5787 – DPR: 0.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6835 acc: 53.63% – f1: 42.22% – precision: 62.82% – recall: 31.79% – roc_auc: 55.16%
# Validation Fairness Metrics - DPD: 0.7304 – DPR: 0.0000
# Epoch 03
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6851 – acc: 54.78% – f1: 50.77% – precision: 60.41% – recall: 43.79% – roc_auc: 55.55%
# Training Fairness Metrics - DPD: 0.6140 – DPR: 0.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6771 acc: 56.25% – f1: 52.57% – precision: 62.23% – recall: 45.51% – roc_auc: 57.00%
# Validation Fairness Metrics - DPD: 0.6104 – DPR: 0.0000
# Epoch 04
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6835 – acc: 55.92% – f1: 57.16% – precision: 59.24% – recall: 55.22% – roc_auc: 55.97%
# Training Fairness Metrics - DPD: 0.5036 – DPR: 0.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6765 acc: 55.36% – f1: 48.75% – precision: 62.77% – recall: 39.85% – roc_auc: 56.45%
# Validation Fairness Metrics - DPD: 0.6617 – DPR: 0.0000
# Epoch 05
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6826 – acc: 55.86% – f1: 55.24% – precision: 60.04% – recall: 51.16% – roc_auc: 56.18%
# Training Fairness Metrics - DPD: 0.5462 – DPR: 0.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6756 acc: 57.38% – f1: 56.74% – precision: 61.79% – recall: 52.46% – roc_auc: 57.73%
# Validation Fairness Metrics - DPD: 0.5477 – DPR: 0.0000
# Epoch 06
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6819 – acc: 56.04% – f1: 54.86% – precision: 60.53% – recall: 50.16% – roc_auc: 56.45%
# Training Fairness Metrics - DPD: 0.5587 – DPR: 0.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6831 acc: 54.02% – f1: 41.34% – precision: 64.57% – recall: 30.40% – roc_auc: 55.69%
# Validation Fairness Metrics - DPD: 0.7491 – DPR: 0.0000
# Epoch 07
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6817 – acc: 56.50% – f1: 56.42% – precision: 60.47% – recall: 52.87% – roc_auc: 56.75%
# Training Fairness Metrics - DPD: 0.5344 – DPR: 0.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6769 acc: 57.04% – f1: 54.97% – precision: 62.25% – recall: 49.21% – roc_auc: 57.59%
# Validation Fairness Metrics - DPD: 0.5788 – DPR: 0.0000
# Epoch 08
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6806 – acc: 56.29% – f1: 56.39% – precision: 60.16% – recall: 53.06% – roc_auc: 56.51%
# Training Fairness Metrics - DPD: 0.5303 – DPR: 0.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6758 acc: 57.33% – f1: 56.58% – precision: 61.80% – recall: 52.18% – roc_auc: 57.70%
# Validation Fairness Metrics - DPD: 0.5501 – DPR: 0.0000
# Epoch 09
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6810 – acc: 56.20% – f1: 55.13% – precision: 60.66% – recall: 50.53% – roc_auc: 56.60%
# Training Fairness Metrics - DPD: 0.5564 – DPR: 0.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6781 acc: 56.00% – f1: 50.20% – precision: 63.24% – recall: 41.61% – roc_auc: 57.01%
# Validation Fairness Metrics - DPD: 0.6494 – DPR: 0.0000
# Epoch 10
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6802 – acc: 56.22% – f1: 55.05% – precision: 60.72% – recall: 50.35% – roc_auc: 56.62%
# Training Fairness Metrics - DPD: 0.5584 – DPR: 0.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6776 acc: 55.85% – f1: 48.56% – precision: 64.04% – recall: 39.11% – roc_auc: 57.03%
# Validation Fairness Metrics - DPD: 0.6746 – DPR: 0.0000
# Epoch 11
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6778 – acc: 55.98% – f1: 52.88% – precision: 61.49% – recall: 46.38% – roc_auc: 56.65%
# Training Fairness Metrics - DPD: 0.5983 – DPR: 0.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6745 acc: 57.14% – f1: 55.07% – precision: 62.37% – recall: 49.30% – roc_auc: 57.69%
# Validation Fairness Metrics - DPD: 0.5788 – DPR: 0.0000
# Epoch 12
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6773 – acc: 56.28% – f1: 54.44% – precision: 61.16% – recall: 49.05% – roc_auc: 56.78%
# Training Fairness Metrics - DPD: 0.5729 – DPR: 0.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6744 acc: 57.28% – f1: 55.89% – precision: 62.13% – recall: 50.79% – roc_auc: 57.74%
# Validation Fairness Metrics - DPD: 0.5644 – DPR: 0.0000
# Epoch 13
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6771 – acc: 56.46% – f1: 54.97% – precision: 61.18% – recall: 49.91% – roc_auc: 56.92%
# Training Fairness Metrics - DPD: 0.5656 – DPR: 0.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6742 acc: 57.28% – f1: 56.38% – precision: 61.84% – recall: 51.81% – roc_auc: 57.67%
# Validation Fairness Metrics - DPD: 0.5536 – DPR: 0.0000
# Epoch 14
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6771 – acc: 56.65% – f1: 55.60% – precision: 61.15% – recall: 50.97% – roc_auc: 57.04%
# Training Fairness Metrics - DPD: 0.5561 – DPR: 0.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6741 acc: 57.43% – f1: 56.81% – precision: 61.83% – recall: 52.55% – roc_auc: 57.78%
# Validation Fairness Metrics - DPD: 0.5472 – DPR: 0.0000
# Epoch 15
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6770 – acc: 56.78% – f1: 55.96% – precision: 61.18% – recall: 51.55% – roc_auc: 57.15%
# Training Fairness Metrics - DPD: 0.5513 – DPR: 0.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6741 acc: 57.58% – f1: 57.03% – precision: 61.96% – recall: 52.83% – roc_auc: 57.91%
# Validation Fairness Metrics - DPD: 0.5457 – DPR: 0.0000
# Epoch 16
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6770 – acc: 56.88% – f1: 56.16% – precision: 61.24% – recall: 51.85% – roc_auc: 57.23%
# Training Fairness Metrics - DPD: 0.5491 – DPR: 0.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6740 acc: 57.48% – f1: 57.01% – precision: 61.80% – recall: 52.92% – roc_auc: 57.80%
# Validation Fairness Metrics - DPD: 0.5437 – DPR: 0.0000
# Epoch 17
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6769 – acc: 56.82% – f1: 56.11% – precision: 61.16% – recall: 51.83% – roc_auc: 57.17%
# Training Fairness Metrics - DPD: 0.5487 – DPR: 0.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6740 acc: 57.58% – f1: 57.16% – precision: 61.88% – recall: 53.10% – roc_auc: 57.89%
# Validation Fairness Metrics - DPD: 0.5427 – DPR: 0.0000
# Epoch 18
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6769 – acc: 56.82% – f1: 56.20% – precision: 61.11% – recall: 52.02% – roc_auc: 57.15%
# Training Fairness Metrics - DPD: 0.5467 – DPR: 0.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6739 acc: 57.68% – f1: 57.47% – precision: 61.86% – recall: 53.66% – roc_auc: 57.96%
# Validation Fairness Metrics - DPD: 0.5378 – DPR: 0.0000
# Epoch 19
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6769 – acc: 56.83% – f1: 56.28% – precision: 61.09% – recall: 52.18% – roc_auc: 57.16%
# Training Fairness Metrics - DPD: 0.5451 – DPR: 0.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6739 acc: 57.63% – f1: 57.40% – precision: 61.82% – recall: 53.57% – roc_auc: 57.92%
# Validation Fairness Metrics - DPD: 0.5383 – DPR: 0.0000
# Epoch 20
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6768 – acc: 56.87% – f1: 56.35% – precision: 61.11% – recall: 52.27% – roc_auc: 57.19%
# Training Fairness Metrics - DPD: 0.5445 – DPR: 0.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6739 acc: 57.63% – f1: 57.40% – precision: 61.82% – recall: 53.57% – roc_auc: 57.92%
# Validation Fairness Metrics - DPD: 0.5383 – DPR: 0.0000
# Fold 3
# Epoch 01
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6956 – acc: 51.66% – f1: 54.85% – precision: 54.56% – recall: 55.15% – roc_auc: 51.42%
# Training Fairness Metrics - DPD: 0.5382 – DPR: 0.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6937 acc: 48.69% – f1: 12.76% – precision: 67.86% – recall: 7.04% – roc_auc: 51.62%
# Validation Fairness Metrics - DPD: 0.9447 – DPR: 0.0000
# Epoch 02
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6926 – acc: 52.18% – f1: 51.47% – precision: 56.00% – recall: 47.61% – roc_auc: 52.50%
# Training Fairness Metrics - DPD: 0.5472 – DPR: 0.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6882 acc: 52.35% – f1: 54.50% – precision: 55.47% – recall: 53.57% – roc_auc: 52.26%
# Validation Fairness Metrics - DPD: 0.5146 – DPR: 0.0000
# Epoch 03
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6900 – acc: 54.55% – f1: 51.53% – precision: 59.63% – recall: 45.36% – roc_auc: 55.19%
# Training Fairness Metrics - DPD: 0.5949 – DPR: 0.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6907 acc: 51.65% – f1: 41.34% – precision: 58.47% – recall: 31.97% – roc_auc: 53.04%
# Validation Fairness Metrics - DPD: 0.7086 – DPR: 0.0000
# Epoch 04
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6881 – acc: 54.61% – f1: 52.54% – precision: 59.28% – recall: 47.17% – roc_auc: 55.13%
# Training Fairness Metrics - DPD: 0.5762 – DPR: 0.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6910 acc: 51.26% – f1: 32.07% – precision: 62.30% – recall: 21.59% – roc_auc: 53.34%
# Validation Fairness Metrics - DPD: 0.8153 – DPR: 0.0000
# Epoch 05
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6869 – acc: 54.44% – f1: 51.63% – precision: 59.39% – recall: 45.67% – roc_auc: 55.05%
# Training Fairness Metrics - DPD: 0.5905 – DPR: 0.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6847 acc: 53.48% – f1: 55.57% – precision: 56.58% – recall: 54.59% – roc_auc: 53.40%
# Validation Fairness Metrics - DPD: 0.5141 – DPR: 0.0000
# Epoch 06
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6856 – acc: 55.67% – f1: 54.49% – precision: 60.11% – recall: 49.84% – roc_auc: 56.08%
# Training Fairness Metrics - DPD: 0.5584 – DPR: 0.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6861 acc: 52.69% – f1: 49.68% – precision: 57.33% – recall: 43.84% – roc_auc: 53.31%
# Validation Fairness Metrics - DPD: 0.5926 – DPR: 0.0000
# Epoch 07
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6844 – acc: 55.77% – f1: 54.30% – precision: 60.36% – recall: 49.35% – roc_auc: 56.22%
# Training Fairness Metrics - DPD: 0.5646 – DPR: 0.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6862 acc: 52.54% – f1: 46.04% – precision: 58.40% – recall: 38.00% – roc_auc: 53.57%
# Validation Fairness Metrics - DPD: 0.6533 – DPR: 0.0000
# Epoch 08
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6838 – acc: 55.38% – f1: 53.56% – precision: 60.07% – recall: 48.33% – roc_auc: 55.87%
# Training Fairness Metrics - DPD: 0.5715 – DPR: 0.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6867 acc: 52.79% – f1: 47.65% – precision: 58.23% – recall: 40.32% – roc_auc: 53.67%
# Validation Fairness Metrics - DPD: 0.6311 – DPR: 0.0000
# Epoch 09
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6834 – acc: 55.89% – f1: 55.50% – precision: 59.97% – recall: 51.65% – roc_auc: 56.19%
# Training Fairness Metrics - DPD: 0.5414 – DPR: 0.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6872 acc: 52.59% – f1: 46.49% – precision: 58.32% – recall: 38.65% – roc_auc: 53.57%
# Validation Fairness Metrics - DPD: 0.6469 – DPR: 0.0000
# Epoch 10
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6829 – acc: 56.01% – f1: 55.52% – precision: 60.14% – recall: 51.55% – roc_auc: 56.32%
# Training Fairness Metrics - DPD: 0.5435 – DPR: 0.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6862 acc: 52.44% – f1: 47.12% – precision: 57.82% – recall: 39.76% – roc_auc: 53.34%
# Validation Fairness Metrics - DPD: 0.6336 – DPR: 0.0000
# Epoch 11
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6793 – acc: 55.92% – f1: 52.93% – precision: 61.35% – recall: 46.55% – roc_auc: 56.57%
# Training Fairness Metrics - DPD: 0.5960 – DPR: 0.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6863 acc: 52.59% – f1: 47.25% – precision: 58.03% – recall: 39.85% – roc_auc: 53.49%
# Validation Fairness Metrics - DPD: 0.6341 – DPR: 0.0000
# Epoch 12
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6790 – acc: 55.93% – f1: 53.12% – precision: 61.27% – recall: 46.89% – roc_auc: 56.56%
# Training Fairness Metrics - DPD: 0.5924 – DPR: 0.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6861 acc: 52.69% – f1: 47.82% – precision: 57.99% – recall: 40.69% – roc_auc: 53.54%
# Validation Fairness Metrics - DPD: 0.6262 – DPR: 0.0000
# Epoch 13
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6787 – acc: 56.10% – f1: 53.37% – precision: 61.44% – recall: 47.17% – roc_auc: 56.73%
# Training Fairness Metrics - DPD: 0.5912 – DPR: 0.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6859 acc: 53.33% – f1: 48.89% – precision: 58.70% – recall: 41.89% – roc_auc: 54.14%
# Validation Fairness Metrics - DPD: 0.6198 – DPR: 0.0000
# Epoch 14
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6785 – acc: 56.07% – f1: 53.34% – precision: 61.39% – recall: 47.15% – roc_auc: 56.69%
# Training Fairness Metrics - DPD: 0.5910 – DPR: 0.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6858 acc: 53.63% – f1: 49.33% – precision: 59.04% – recall: 42.35% – roc_auc: 54.42%
# Validation Fairness Metrics - DPD: 0.6178 – DPR: 0.0000
# Epoch 15
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6783 – acc: 56.09% – f1: 53.47% – precision: 61.36% – recall: 47.38% – roc_auc: 56.70%
# Training Fairness Metrics - DPD: 0.5888 – DPR: 0.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6858 acc: 53.53% – f1: 49.33% – precision: 58.87% – recall: 42.45% – roc_auc: 54.31%
# Validation Fairness Metrics - DPD: 0.6158 – DPR: 0.0000
# Epoch 16
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6782 – acc: 56.20% – f1: 53.69% – precision: 61.44% – recall: 47.68% – roc_auc: 56.80%
# Training Fairness Metrics - DPD: 0.5867 – DPR: 0.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6859 acc: 53.63% – f1: 49.33% – precision: 59.04% – recall: 42.35% – roc_auc: 54.42%
# Validation Fairness Metrics - DPD: 0.6178 – DPR: 0.0000
# Epoch 17
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6780 – acc: 56.40% – f1: 53.82% – precision: 61.73% – recall: 47.71% – roc_auc: 57.01%
# Training Fairness Metrics - DPD: 0.5884 – DPR: 0.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6855 acc: 53.68% – f1: 50.32% – precision: 58.71% – recall: 44.02% – roc_auc: 54.36%
# Validation Fairness Metrics - DPD: 0.6005 – DPR: 0.0000
# Epoch 18
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6779 – acc: 56.30% – f1: 53.74% – precision: 61.59% – recall: 47.66% – roc_auc: 56.90%
# Training Fairness Metrics - DPD: 0.5880 – DPR: 0.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6854 acc: 53.83% – f1: 50.66% – precision: 58.82% – recall: 44.49% – roc_auc: 54.48%
# Validation Fairness Metrics - DPD: 0.5970 – DPR: 0.0000
# Epoch 19
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6778 – acc: 56.28% – f1: 53.90% – precision: 61.45% – recall: 48.01% – roc_auc: 56.85%
# Training Fairness Metrics - DPD: 0.5840 – DPR: 0.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6853 acc: 53.98% – f1: 51.00% – precision: 58.93% – recall: 44.95% – roc_auc: 54.61%
# Validation Fairness Metrics - DPD: 0.5936 – DPR: 0.0000
# Epoch 20
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6777 – acc: 56.24% – f1: 53.75% – precision: 61.47% – recall: 47.75% – roc_auc: 56.83%
# Training Fairness Metrics - DPD: 0.5863 – DPR: 0.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6854 acc: 54.07% – f1: 50.64% – precision: 59.25% – recall: 44.21% – roc_auc: 54.77%
# Validation Fairness Metrics - DPD: 0.6025 – DPR: 0.0000
# Fold 4
# Epoch 01
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6954 – acc: 51.22% – f1: 52.64% – precision: 54.50% – recall: 50.89% – roc_auc: 51.24%
# Training Fairness Metrics - DPD: 0.5027 – DPR: 0.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6937 acc: 46.91% – f1: 2.01% – precision: 57.89% – recall: 1.02% – roc_auc: 50.09%
# Validation Fairness Metrics - DPD: 0.9906 – DPR: 0.0000
# Epoch 02
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6946 – acc: 51.70% – f1: 52.47% – precision: 55.13% – recall: 50.06% – roc_auc: 51.81%
# Training Fairness Metrics - DPD: 0.5164 – DPR: 0.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6909 acc: 54.27% – f1: 44.22% – precision: 63.06% – recall: 34.04% – roc_auc: 55.67%
# Validation Fairness Metrics - DPD: 0.7126 – DPR: 0.0000
# Epoch 03
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6936 – acc: 51.19% – f1: 42.51% – precision: 57.04% – recall: 33.88% – roc_auc: 52.40%
# Training Fairness Metrics - DPD: 0.6836 – DPR: 0.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6894 acc: 54.37% – f1: 43.17% – precision: 64.05% – recall: 32.56% – roc_auc: 55.88%
# Validation Fairness Metrics - DPD: 0.7294 – DPR: 0.0000
# Epoch 04
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6926 – acc: 51.41% – f1: 40.81% – precision: 58.12% – recall: 31.45% – roc_auc: 52.81%
# Training Fairness Metrics - DPD: 0.7118 – DPR: 0.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6914 acc: 51.90% – f1: 29.83% – precision: 66.77% – recall: 19.20% – roc_auc: 54.16%
# Validation Fairness Metrics - DPD: 0.8469 – DPR: 0.0000
# Epoch 05
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6915 – acc: 52.67% – f1: 46.27% – precision: 58.53% – recall: 38.26% – roc_auc: 53.68%
# Training Fairness Metrics - DPD: 0.6518 – DPR: 0.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6883 acc: 54.72% – f1: 44.79% – precision: 63.81% – recall: 34.51% – roc_auc: 56.11%
# Validation Fairness Metrics - DPD: 0.7121 – DPR: 0.0000
# Epoch 06
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6908 – acc: 53.23% – f1: 47.83% – precision: 58.92% – recall: 40.25% – roc_auc: 54.13%
# Training Fairness Metrics - DPD: 0.6361 – DPR: 0.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6890 acc: 53.38% – f1: 37.65% – precision: 65.37% – recall: 26.44% – roc_auc: 55.25%
# Validation Fairness Metrics - DPD: 0.7847 – DPR: 0.0000
# Epoch 07
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6892 – acc: 53.71% – f1: 49.34% – precision: 59.15% – recall: 42.32% – roc_auc: 54.51%
# Training Fairness Metrics - DPD: 0.6189 – DPR: 0.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6879 acc: 54.27% – f1: 41.69% – precision: 64.90% – recall: 30.71% – roc_auc: 55.90%
# Validation Fairness Metrics - DPD: 0.7481 – DPR: 0.0000
# Epoch 08
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6883 – acc: 54.23% – f1: 50.81% – precision: 59.42% – recall: 44.38% – roc_auc: 54.92%
# Training Fairness Metrics - DPD: 0.6021 – DPR: 0.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6857 acc: 55.60% – f1: 48.95% – precision: 63.10% – recall: 39.98% – roc_auc: 56.69%
# Validation Fairness Metrics - DPD: 0.6627 – DPR: 0.0000
# Epoch 09
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6870 – acc: 54.43% – f1: 52.40% – precision: 59.05% – recall: 47.09% – roc_auc: 54.94%
# Training Fairness Metrics - DPD: 0.5752 – DPR: 0.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6838 acc: 55.31% – f1: 52.19% – precision: 60.61% – recall: 45.83% – roc_auc: 55.96%
# Validation Fairness Metrics - DPD: 0.5975 – DPR: 0.0000
# Epoch 10
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6858 – acc: 54.91% – f1: 53.49% – precision: 59.35% – recall: 48.69% – roc_auc: 55.34%
# Training Fairness Metrics - DPD: 0.5630 – DPR: 0.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6818 acc: 54.72% – f1: 55.85% – precision: 58.06% – recall: 53.80% – roc_auc: 54.78%
# Validation Fairness Metrics - DPD: 0.5067 – DPR: 0.0000
# Epoch 11
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6835 – acc: 56.35% – f1: 57.33% – precision: 59.81% – recall: 55.04% – roc_auc: 56.44%
# Training Fairness Metrics - DPD: 0.5098 – DPR: 0.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6811 acc: 54.81% – f1: 54.73% – precision: 58.64% – recall: 51.30% – roc_auc: 55.06%
# Validation Fairness Metrics - DPD: 0.5343 – DPR: 0.0000
# Epoch 12
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6826 – acc: 56.39% – f1: 56.28% – precision: 60.38% – recall: 52.70% – roc_auc: 56.65%
# Training Fairness Metrics - DPD: 0.5351 – DPR: 0.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6808 acc: 55.11% – f1: 54.39% – precision: 59.23% – recall: 50.28% – roc_auc: 55.45%
# Validation Fairness Metrics - DPD: 0.5481 – DPR: 0.0000
# Epoch 13
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6822 – acc: 56.33% – f1: 55.90% – precision: 60.48% – recall: 51.96% – roc_auc: 56.63%
# Training Fairness Metrics - DPD: 0.5424 – DPR: 0.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6807 acc: 55.11% – f1: 54.02% – precision: 59.40% – recall: 49.54% – roc_auc: 55.50%
# Validation Fairness Metrics - DPD: 0.5560 – DPR: 0.0000
# Epoch 14
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6819 – acc: 56.43% – f1: 56.03% – precision: 60.57% – recall: 52.12% – roc_auc: 56.73%
# Training Fairness Metrics - DPD: 0.5417 – DPR: 0.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6807 acc: 55.11% – f1: 54.11% – precision: 59.36% – recall: 49.72% – roc_auc: 55.48%
# Validation Fairness Metrics - DPD: 0.5541 – DPR: 0.0000
# Epoch 15
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6816 – acc: 56.52% – f1: 56.18% – precision: 60.65% – recall: 52.33% – roc_auc: 56.82%
# Training Fairness Metrics - DPD: 0.5404 – DPR: 0.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6808 acc: 55.01% – f1: 53.97% – precision: 59.27% – recall: 49.54% – roc_auc: 55.39%
# Validation Fairness Metrics - DPD: 0.5551 – DPR: 0.0000
# Epoch 16
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6814 – acc: 56.63% – f1: 56.48% – precision: 60.67% – recall: 52.84% – roc_auc: 56.90%
# Training Fairness Metrics - DPD: 0.5361 – DPR: 0.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6807 acc: 55.21% – f1: 54.35% – precision: 59.41% – recall: 50.09% – roc_auc: 55.56%
# Validation Fairness Metrics - DPD: 0.5511 – DPR: 0.0000
# Epoch 17
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6812 – acc: 56.67% – f1: 56.67% – precision: 60.63% – recall: 53.19% – roc_auc: 56.92%
# Training Fairness Metrics - DPD: 0.5328 – DPR: 0.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6807 acc: 55.21% – f1: 54.67% – precision: 59.26% – recall: 50.74% – roc_auc: 55.52%
# Validation Fairness Metrics - DPD: 0.5442 – DPR: 0.0000
# Epoch 18
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6810 – acc: 56.84% – f1: 57.05% – precision: 60.71% – recall: 53.81% – roc_auc: 57.06%
# Training Fairness Metrics - DPD: 0.5278 – DPR: 0.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6806 acc: 55.46% – f1: 55.30% – precision: 59.36% – recall: 51.76% – roc_auc: 55.71%
# Validation Fairness Metrics - DPD: 0.5358 – DPR: 0.0000
# Epoch 19
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6808 – acc: 56.84% – f1: 57.15% – precision: 60.66% – recall: 54.02% – roc_auc: 57.04%
# Training Fairness Metrics - DPD: 0.5256 – DPR: 0.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6807 acc: 55.11% – f1: 55.02% – precision: 58.96% – recall: 51.58% – roc_auc: 55.36%
# Validation Fairness Metrics - DPD: 0.5343 – DPR: 0.0000
# Epoch 20
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6806 – acc: 56.80% – f1: 57.09% – precision: 60.61% – recall: 53.95% – roc_auc: 56.99%
# Training Fairness Metrics - DPD: 0.5259 – DPR: 0.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6808 acc: 55.21% – f1: 54.85% – precision: 59.18% – recall: 51.11% – roc_auc: 55.49%
# Validation Fairness Metrics - DPD: 0.5402 – DPR: 0.0000
# Fold 5
# Epoch 01
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6960 – acc: 50.69% – f1: 54.01% – precision: 53.66% – recall: 54.37% – roc_auc: 50.43%
# Training Fairness Metrics - DPD: 0.5397 – DPR: 0.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6904 acc: 56.40% – f1: 50.86% – precision: 63.56% – recall: 42.39% – roc_auc: 57.36%
# Validation Fairness Metrics - DPD: 0.6449 – DPR: 0.0000
# Epoch 02
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6941 – acc: 51.96% – f1: 50.09% – precision: 56.07% – recall: 45.26% – roc_auc: 52.42%
# Training Fairness Metrics - DPD: 0.5701 – DPR: 0.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6859 acc: 52.99% – f1: 36.36% – precision: 65.07% – recall: 25.23% – roc_auc: 54.91%
# Validation Fairness Metrics - DPD: 0.7936 – DPR: 0.0000
# Epoch 03
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6911 – acc: 53.44% – f1: 53.25% – precision: 57.23% – recall: 49.78% – roc_auc: 53.69%
# Training Fairness Metrics - DPD: 0.5367 – DPR: 0.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6922 acc: 51.70% – f1: 29.03% – precision: 66.67% – recall: 18.55% – roc_auc: 54.00%
# Validation Fairness Metrics - DPD: 0.8519 – DPR: 0.0000
# Epoch 04
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6895 – acc: 54.26% – f1: 55.19% – precision: 57.71% – recall: 52.89% – roc_auc: 54.36%
# Training Fairness Metrics - DPD: 0.5119 – DPR: 0.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6809 acc: 56.00% – f1: 49.40% – precision: 63.69% – recall: 40.35% – roc_auc: 57.08%
# Validation Fairness Metrics - DPD: 0.6627 – DPR: 0.0000
# Epoch 05
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6878 – acc: 54.87% – f1: 54.98% – precision: 58.66% – recall: 51.73% – roc_auc: 55.09%
# Training Fairness Metrics - DPD: 0.5303 – DPR: 0.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6787 acc: 57.33% – f1: 54.38% – precision: 63.11% – recall: 47.77% – roc_auc: 57.99%
# Validation Fairness Metrics - DPD: 0.5970 – DPR: 0.0000
# Epoch 06
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6869 – acc: 55.04% – f1: 56.20% – precision: 58.41% – recall: 54.16% – roc_auc: 55.10%
# Training Fairness Metrics - DPD: 0.5061 – DPR: 0.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6769 acc: 57.53% – f1: 56.21% – precision: 62.30% – recall: 51.21% – roc_auc: 57.97%
# Validation Fairness Metrics - DPD: 0.5625 – DPR: 0.0000
# Epoch 07
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6862 – acc: 55.59% – f1: 56.67% – precision: 58.99% – recall: 54.53% – roc_auc: 55.66%
# Training Fairness Metrics - DPD: 0.5076 – DPR: 0.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6773 acc: 57.38% – f1: 54.79% – precision: 62.94% – recall: 48.52% – roc_auc: 58.00%
# Validation Fairness Metrics - DPD: 0.5896 – DPR: 0.0000
# Epoch 08
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6862 – acc: 55.55% – f1: 56.72% – precision: 58.91% – recall: 54.69% – roc_auc: 55.61%
# Training Fairness Metrics - DPD: 0.5055 – DPR: 0.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6735 acc: 59.11% – f1: 61.45% – precision: 61.68% – recall: 61.22% – roc_auc: 58.96%
# Validation Fairness Metrics - DPD: 0.5284 – DPR: 0.0000
# Epoch 09
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6860 – acc: 55.41% – f1: 56.45% – precision: 58.83% – recall: 54.25% – roc_auc: 55.49%
# Training Fairness Metrics - DPD: 0.5088 – DPR: 0.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6776 acc: 57.23% – f1: 54.61% – precision: 62.77% – recall: 48.33% – roc_auc: 57.85%
# Validation Fairness Metrics - DPD: 0.5901 – DPR: 0.0000
# Epoch 10
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6859 – acc: 55.73% – f1: 57.47% – precision: 58.85% – recall: 56.15% – roc_auc: 55.70%
# Training Fairness Metrics - DPD: 0.5082 – DPR: 0.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6768 acc: 57.68% – f1: 55.98% – precision: 62.72% – recall: 50.56% – roc_auc: 58.17%
# Validation Fairness Metrics - DPD: 0.5709 – DPR: 0.0000
# Epoch 11
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6836 – acc: 56.28% – f1: 57.22% – precision: 59.75% – recall: 54.90% – roc_auc: 56.37%
# Training Fairness Metrics - DPD: 0.5106 – DPR: 0.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6745 acc: 58.81% – f1: 60.51% – precision: 61.80% – recall: 59.28% – roc_auc: 58.78%
# Validation Fairness Metrics - DPD: 0.5106 – DPR: 0.0000
# Epoch 12
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6835 – acc: 56.29% – f1: 57.41% – precision: 59.67% – recall: 55.32% – roc_auc: 56.36%
# Training Fairness Metrics - DPD: 0.5062 – DPR: 0.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6744 acc: 58.81% – f1: 60.47% – precision: 61.82% – recall: 59.18% – roc_auc: 58.79%
# Validation Fairness Metrics - DPD: 0.5096 – DPR: 0.0000
# Epoch 13
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6835 – acc: 56.33% – f1: 57.55% – precision: 59.67% – recall: 55.57% – roc_auc: 56.38%
# Training Fairness Metrics - DPD: 0.5039 – DPR: 0.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6744 acc: 58.86% – f1: 60.54% – precision: 61.86% – recall: 59.28% – roc_auc: 58.84%
# Validation Fairness Metrics - DPD: 0.5101 – DPR: 0.0000
# Epoch 14
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6835 – acc: 56.33% – f1: 57.57% – precision: 59.66% – recall: 55.62% – roc_auc: 56.38%
# Training Fairness Metrics - DPD: 0.5034 – DPR: 0.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6743 acc: 58.77% – f1: 60.63% – precision: 61.65% – recall: 59.65% – roc_auc: 58.70%
# Validation Fairness Metrics - DPD: 0.5151 – DPR: 0.0000
# Epoch 15
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6834 – acc: 56.35% – f1: 57.60% – precision: 59.68% – recall: 55.67% – roc_auc: 56.40%
# Training Fairness Metrics - DPD: 0.5031 – DPR: 0.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6743 acc: 58.81% – f1: 60.66% – precision: 61.71% – recall: 59.65% – roc_auc: 58.76%
# Validation Fairness Metrics - DPD: 0.5146 – DPR: 0.0000
# Epoch 16
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6834 – acc: 56.35% – f1: 57.65% – precision: 59.65% – recall: 55.78% – roc_auc: 56.39%
# Training Fairness Metrics - DPD: 0.5019 – DPR: 0.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6743 acc: 58.77% – f1: 60.59% – precision: 61.67% – recall: 59.55% – roc_auc: 58.71%
# Validation Fairness Metrics - DPD: 0.5141 – DPR: 0.0000
# Epoch 17
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6834 – acc: 56.36% – f1: 57.67% – precision: 59.66% – recall: 55.81% – roc_auc: 56.40%
# Training Fairness Metrics - DPD: 0.5018 – DPR: 0.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6743 acc: 58.77% – f1: 60.59% – precision: 61.67% – recall: 59.55% – roc_auc: 58.71%
# Validation Fairness Metrics - DPD: 0.5141 – DPR: 0.0000
# Epoch 18
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6833 – acc: 56.30% – f1: 57.60% – precision: 59.60% – recall: 55.74% – roc_auc: 56.34%
# Training Fairness Metrics - DPD: 0.5019 – DPR: 0.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6743 acc: 58.72% – f1: 60.53% – precision: 61.63% – recall: 59.46% – roc_auc: 58.66%
# Validation Fairness Metrics - DPD: 0.5136 – DPR: 0.0000
# Epoch 19
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6833 – acc: 56.33% – f1: 57.63% – precision: 59.63% – recall: 55.76% – roc_auc: 56.37%
# Training Fairness Metrics - DPD: 0.5019 – DPR: 0.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6743 acc: 58.72% – f1: 60.45% – precision: 61.68% – recall: 59.28% – roc_auc: 58.68%
# Validation Fairness Metrics - DPD: 0.5116 – DPR: 0.0000
# Epoch 20
# Sensitive feature is f_ESCS
# Training General Metrics - loss: 0.6833 – acc: 56.36% – f1: 57.69% – precision: 59.65% – recall: 55.85% – roc_auc: 56.40%
# Training Fairness Metrics - DPD: 0.5013 – DPR: 0.0000
# Sensitive feature is f_ESCS
# Validation General Metrics - loss: 0.6743 acc: 58.72% – f1: 60.42% – precision: 61.70% – recall: 59.18% – roc_auc: 58.68%
# Validation Fairness Metrics - DPD: 0.5106 – DPR: 0.0000
# FINAL RESULTS ACROSS ALL FOLDS:
# Accuracy:  56.34014112829512 ± 1.660883776301832
# F1-Score:  56.16051897123013 ± 3.275777081104498
# Precision:  60.253797231964676 ± 1.2311381647094801
# Recall:  52.77299292789827 ± 5.039183212872771
# ROC-AUC:  56.59004343881803 ± 1.4773606313991334
# FINAL FAIRNESS RESULTS ACROSS ALL FOLDS:
# Demographic Parity Difference:  0.5385184210205598 ± 0.0354395570419467
# Demographic Parity Ratio:  0.0 ± 0.0

# %% [markdown]
# ### In-Processing Mitigation

# %% [markdown]
# #### Adversarial Debiasing

# %%
ad_res, ad_fair_res = kfold_cross_validation(5, X, Y, sensitive_feature=SENSITIVE, inprocessing='adversarial_debiasing')
# Out:
# Fold 1
# Sensitive feature is f_ESCS
# Validation General Metrics -  acc: 59.03% – f1: 61.86% – precision: 61.35% – recall: 62.37% – roc_auc: 58.80%
# Validation Fairness Metrics - DPD: 0.1615 – DPR: 0.7017
# Fold 2
# Sensitive feature is f_ESCS
# Validation General Metrics -  acc: 59.70% – f1: 63.34% – precision: 61.46% – recall: 65.34% – roc_auc: 59.31%
# Validation Fairness Metrics - DPD: 0.1927 – DPR: 0.6598
# Fold 3
# Sensitive feature is f_ESCS
# Validation General Metrics -  acc: 61.38% – f1: 63.63% – precision: 63.87% – recall: 63.39% – roc_auc: 61.24%
# Validation Fairness Metrics - DPD: 0.1885 – DPR: 0.6436
# Fold 4
# Sensitive feature is f_ESCS
# Validation General Metrics -  acc: 60.54% – f1: 64.54% – precision: 61.87% – recall: 67.44% – roc_auc: 60.07%
# Validation Fairness Metrics - DPD: 0.1724 – DPR: 0.7028
# Fold 5
# Sensitive feature is f_ESCS
# Validation General Metrics -  acc: 61.98% – f1: 63.40% – precision: 65.01% – recall: 61.87% – roc_auc: 61.98%
# Validation Fairness Metrics - DPD: 0.1592 – DPR: 0.6857
# FINAL RESULTS ACROSS ALL FOLDS:
# Accuracy:  60.527502955406874 ± 1.0715622004800414
# F1-Score:  63.3532116996865 ± 0.8622357852997972
# Precision:  62.712291546297 ± 1.464822225761881
# Recall:  64.08328332596835 ± 2.0555573598955466
# ROC-AUC:  60.279484098537864 ± 1.183601982664302
# FINAL FAIRNESS RESULTS ACROSS ALL FOLDS:
# Demographic Parity Difference:  0.1748718807867753 ± 0.013655621369977384
# Demographic Parity Ratio:  0.6787361641393092 ± 0.023459896879666115

# %% [markdown]
# #### FaUCI

# %%
fauci_res, fauci_fair_res = kfold_cross_validation(5, X, Y, sensitive_feature=SENSITIVE, inprocessing='FaUCI')
# Out:
# Fold 1
# Sensitive feature is f_ESCS
# Validation General Metrics -  acc: 55.97% – f1: 44.11% – precision: 68.09% – recall: 32.62% – roc_auc: 57.60%
# Validation Fairness Metrics - DPD: 0.1926 – DPR: 0.2454
# Fold 2
# Sensitive feature is f_ESCS
# Validation General Metrics -  acc: 56.94% – f1: 43.96% – precision: 71.70% – recall: 31.70% – roc_auc: 58.71%
# Validation Fairness Metrics - DPD: 0.1790 – DPR: 0.2401
# Fold 3
# Sensitive feature is f_ESCS
# Validation General Metrics -  acc: 56.15% – f1: 43.08% – precision: 69.85% – recall: 31.14% – roc_auc: 57.91%
# Validation Fairness Metrics - DPD: 0.1995 – DPR: 0.1602
# Fold 4
# Sensitive feature is f_ESCS
# Validation General Metrics -  acc: 56.74% – f1: 41.60% – precision: 73.93% – recall: 28.94% – roc_auc: 58.66%
# Validation Fairness Metrics - DPD: 0.1563 – DPR: 0.2500
# Fold 5
# Sensitive feature is f_ESCS
# Validation General Metrics -  acc: 56.74% – f1: 40.65% – precision: 75.38% – recall: 27.83% – roc_auc: 58.74%
# Validation Fairness Metrics - DPD: 0.1563 – DPR: 0.2050
# FINAL RESULTS ACROSS ALL FOLDS:
# Accuracy:  56.50805211265889 ± 0.37679554913562274
# F1-Score:  42.67929483296255 ± 1.3508804090810331
# Precision:  71.78964463124117 ± 2.6435554974741784
# Recall:  30.446111547660603 ± 1.78270307851565
# ROC-AUC:  58.32447094714941 ± 0.4772774539543017
# FINAL FAIRNESS RESULTS ACROSS ALL FOLDS:
# Demographic Parity Difference:  0.17671400599360948 ± 0.017941855835958313
# Demographic Parity Ratio:  0.22015203403851694 ± 0.03392653762634277

# %% [markdown]
# #### Prejudice Remover

# %%
pr_res, pr_fair_res = kfold_cross_validation(5, X, Y, sensitive_feature=SENSITIVE, inprocessing='prejudice_remover')
# Out:
# Fold 1
# Sensitive feature is f_ESCS
# Validation General Metrics -  acc: 54.74% – f1: 35.83% – precision: 73.14% – recall: 23.73% – roc_auc: 56.90%
# Validation Fairness Metrics - DPD: 0.1373 – DPR: 0.2054
# Fold 2
# Sensitive feature is f_ESCS
# Validation General Metrics -  acc: 59.46% – f1: 58.39% – precision: 64.43% – recall: 53.38% – roc_auc: 59.88%
# Validation Fairness Metrics - DPD: 0.2829 – DPR: 0.3592
# Fold 3
# Sensitive feature is f_ESCS
# Validation General Metrics -  acc: 53.48% – f1: 34.40% – precision: 69.19% – recall: 22.89% – roc_auc: 55.63%
# Validation Fairness Metrics - DPD: 0.1541 – DPR: 0.1259
# Fold 4
# Sensitive feature is f_ESCS
# Validation General Metrics -  acc: 59.75% – f1: 54.03% – precision: 68.92% – recall: 44.43% – roc_auc: 60.81%
# Validation Fairness Metrics - DPD: 0.2310 – DPR: 0.3270
# Fold 5
# Sensitive feature is f_ESCS
# Validation General Metrics -  acc: 59.01% – f1: 50.77% – precision: 70.39% – recall: 39.70% – roc_auc: 60.35%
# Validation Fairness Metrics - DPD: 0.2398 – DPR: 0.2012
# FINAL RESULTS ACROSS ALL FOLDS:
# Accuracy:  57.288420898687434 ± 2.636046591250653
# F1-Score:  46.68447507139073 ± 9.761062677045029
# Precision:  69.21513251313704 ± 2.8216245285992225
# Recall:  36.827458256029686 ± 11.883393107123387
# ROC-AUC:  58.715181807110504 ± 2.060742574427634
# FINAL FAIRNESS RESULTS ACROSS ALL FOLDS:
# Demographic Parity Difference:  0.20901323164450109 ± 0.05487153581368892
# Demographic Parity Ratio:  0.2437598309579278 ± 0.08650863123288426
